# Raw results (which gives the best reduction in which DS?)
# DS0: raw 2305421  bcMax 1862514 (0.81)  noiseWeight 1713347 (0.74)  pol2 2128426 (0.92)  pol3 2123633 (0.92)
# DS1: raw 42039  bcMax 37654 (0.90)  noiseWeight 21983 (0.52)  pol2 29367 (0.70)  pol3 28835 (0.69)
# DS2: none yet
# DS3: raw 2081200  bcMax 1612826 (0.77)  noiseWeight 692444 (0.33)  pol2 2055909 (0.99)  pol3 2054380 (0.99)
# DS4: raw 753553  bcMax 695941 (0.92)  noiseWeight 149562 (0.20)  pol2 654206 (0.87)  pol3 652343 (0.87) 
# DS5: raw 42408424  bcMax 27547135 (0.65)  noiseWeight 7204942 (0.17)  pol2 41390014 (0.98)  pol3 41120985 (0.97)

# looks like noiseWeight is the winner.
# Order -- noiseWeight, bcMax, pol2+pol3

import ROOT
ROOT.gROOT.ProcessLine("gErrorIgnoreLevel = 3001;"); # suppress ROOT messages
ROOT.disableJSVis()
ROOT.gStyle.SetOptStat(0)

dsBcMax = [599,537,0,521,421,1119]
deDen = [(189,453),(183,397),(0,0),(189,395),(189,407),(189,395)]
dsTimecut = [(0.925,1.069),(0.851,1.070),(0,0),(0.922,1.064),(0.796,1.061),(0.599,1.066)]
dsNoiseWt = [(0.418,0.887),(0.487,1.018),(0,0),(0.492,0.992),(0.,0.992),(0.208,0.902)]
dsPol2 = [(-4.55e-6,1.16e-6),(-4.73e-6,1.09e-6),(0,0),(-4.37e-6,1.14e-6),(-4.46e-6,0.948e-6),(-5.29e-6,1.28e-6)]
dsPol3 = [(-2.38e-11,5.74e-11),(-2.24e-11,5.76e-11),(0,0),(-2.34e-11,5.56e-11),(-1.96e-11,5.84e-11),(-2.74e-11,6.02e-11)]

EnrList0 = [644,642,630,628,626,624,632,674,576,680,692,690,688,640,616,614,610,662,656,696]
NatList0 = [646,584,676,664,608,598,600,594,592]
EnrList1 = [598,594,592,632,630,626,690,648,640,642,584,582,580,587,610,608,664,678,672,696]
NatList1 = [600,692,616,680,624,628,688,694,614]
EnrList3 = [598,594,592,632,630,626,690,648,640,642,584,582,580,578,610,608,664,678,672,696]
NatList3 = [600,692,616,680,624,628,688,694,614]
EnrList4 = [1204,1110,1142,1202,1172,1176,1236,1238,1234,1328,1298,1296,1302,1332,1304]
NatList4 = [1138,1108,1106,1144,1140,1170,1174,1168,1136,1206,1208,1232,1268,1330]


def H1D(tree,nameStr,bins,xlo,xhi,drawStr,cutStr):
    h1 = ROOT.TH1D(nameStr,nameStr,bins,xlo,xhi)
    tree.Project(nameStr,drawStr,cutStr)
    return h1
# Out:
# Welcome to JupyROOT 6.08/06

# %%
# Nat
ds = 0
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()
bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# Make a gigantic canvas
c = ROOT.TCanvas("c","c",1900,1500)
c.Divide(3,3)

noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
totalCut = theCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+denCut+timeCut
for idx,ch in enumerate(NatList0):
    c.cd(idx); ROOT.gPad.SetLogy(1)
    print totalCut+"&& channel==%d"%(ch)
    h0 = H1D(bkg,"h0-Ch%d"%(ch),bins,lower,upper,"trapENFCal",totalCut+"&& channel==%d"%(ch))
#     h1 = H1D(bkg,"h1-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut"&& channel==%d"%(ch) )
#     h2 = H1D(bkg,"h2-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut"&& channel==%d"%(ch) )
#     h3 = H1D(bkg,"h3-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+"&& channel==%d"%(ch) )
#     h4 = H1D(bkg,"h4-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+denCut+"&& channel==%d"%(ch) )
#     h5 = H1D(bkg,"h5-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+denCut+timeCut+"&& channel==%d"%(ch) )
    h0.SetLineColor(ROOT.kBlack)
#     h1.SetLineColor(ROOT.kRed)
#     h2.SetLineColor(ROOT.kBlue)
#     h3.SetLineColor(ROOT.kMagenta)
#     h4.SetLineColor(ROOT.kCyan)
#     h5.SetLineColor(ROOT.kYellow+1)
    h0.Draw("hist")
#     h1.Draw("hist same")
#     h2.Draw("hist same")
#     h3.Draw("hist same")
#     h4.Draw("hist same")
#     h5.Draw("hist same")

# l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
# l1.AddEntry(h0,"basic","l")
# l1.AddEntry(h1,"+noiseWeight","l")
# l1.AddEntry(h2,"+bcMax","l")
# l1.AddEntry(h3,"+pol2&pol3","l")
# l1.AddEntry(h4,"+(den90-den50)","l")
# l1.AddEntry(h5,"+timecut","l")
# l1.Draw("same")

c.Draw()

# %%
# Enr
ds = 0
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()
bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# Make a gigantic canvas
c = ROOT.TCanvas("c","c",2500,1800)
c.Divide(5,4)

noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])

for idx,ch in enumerate(EnrList0):
    c.cd(idx); ROOT.gPad.SetLogy(1)
    print theCut+"&& channel==%d"%(ch)
    h0 = H1D(bkg,"h0-Ch%d"%(ch),bins,lower,upper,"trapENFCal",theCut+"&& channel==%d"%(ch))
#     h1 = H1D(bkg,"h1-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut"&& channel==%d"%(ch) )
#     h2 = H1D(bkg,"h2-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut"&& channel==%d"%(ch) )
#     h3 = H1D(bkg,"h3-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+"&& channel==%d"%(ch) )
#     h4 = H1D(bkg,"h4-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+denCut+"&& channel==%d"%(ch) )
#     h5 = H1D(bkg,"h5-Ch%d"%(ch),bins,lower,upper,"trapENFCal",thisCut+noiseWtCut+bcMaxCut+pol2Cut+pol3Cut+denCut+timeCut+"&& channel==%d"%(ch) )
    h0.SetLineColor(ROOT.kBlack)
#     h1.SetLineColor(ROOT.kRed)
#     h2.SetLineColor(ROOT.kBlue)
#     h3.SetLineColor(ROOT.kMagenta)
#     h4.SetLineColor(ROOT.kCyan)
#     h5.SetLineColor(ROOT.kYellow+1)
    h0.Draw("hist")
#     h1.Draw("hist same")
#     h2.Draw("hist same")
#     h3.Draw("hist same")
#     h4.Draw("hist same")
#     h5.Draw("hist same")

# raw
# h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
# h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
# h0cts = h0.Integral()
# # noiseWeight
# noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
# thisCut = theCut + noiseWtCut
# h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
# h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
# h1cts = h1.Integral()
# # bcMax
# bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
# thisCut = theCut + noiseWtCut + bcMaxCut
# h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
# h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
# h2cts = h2.Integral()
# # pol2 + pol3
# pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
# pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
# thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
# h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
# h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
# h3cts = h3.Integral()
# # den90-den50
# denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
# thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
# h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
# h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
# h4cts = h4.Integral()
# # timecut
# timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
# thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
# h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
# h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
# h5cts = h5.Integral()

# print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
# print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# # -- Plot --
# c = ROOT.TCanvas("c","c",1600,600)
# c.Divide(2,1)
# c.cd(1)
# ROOT.gPad.SetLogy(1)

# h0.SetLineColor(ROOT.kBlack)
# h1.SetLineColor(ROOT.kRed)
# h2.SetLineColor(ROOT.kBlue)
# h3.SetLineColor(ROOT.kMagenta)
# h4.SetLineColor(ROOT.kCyan)
# h5.SetLineColor(ROOT.kYellow+1)

# h0.Draw("hist")
# h1.Draw("hist same")
# h2.Draw("hist same")
# h3.Draw("hist same")
# h4.Draw("hist same")
# h5.Draw("hist same")

# l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
# l1.AddEntry(h0,"basic","l")
# l1.AddEntry(h1,"+noiseWeight","l")
# l1.AddEntry(h2,"+bcMax","l")
# l1.AddEntry(h3,"+pol2&pol3","l")
# l1.AddEntry(h4,"+(den90-den50)","l")
# l1.AddEntry(h5,"+timecut","l")
# l1.Draw("same")

# c.cd(2)
# ROOT.gPad.SetLogy(1)
# h0N.SetLineColor(ROOT.kBlack)
# h1N.SetLineColor(ROOT.kRed)
# h2N.SetLineColor(ROOT.kBlue)
# h3N.SetLineColor(ROOT.kMagenta)
# h4N.SetLineColor(ROOT.kCyan)
# h5N.SetLineColor(ROOT.kYellow+1)

# h0N.Draw("hist")
# h1N.Draw("hist same")
# h2N.Draw("hist same")
# h3N.Draw("hist same")
# h4N.Draw("hist same")
# h5N.Draw("hist same")
c.Draw()
# Out:
# raw 42039  bcMax 35002 (0.83)  noiseWeight 17303 (0.41)  pol2 29367 (0.70)
# pol3 28835 (0.69)  den90-den50 3403 (0.08)   timecut 11369 (0.27)

# %%
ds = 3
f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

c = ROOT.TCanvas("c","c",800,600)
ROOT.gPad.SetLogy(1)
bins,lower,upper = 100,0,20

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut)
h0cts = h0.Integral()

# bcMax
thisCut = theCut + " && bcMax < %d" % dsBcMax[ds]
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut)
h1cts = h1.Integral()

# noiseWeight
thisCut = theCut + " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut)
h2cts = h2.Integral()

# pol2
thisCut = theCut + " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut)
h3cts = h3.Integral()

# pol3
thisCut = theCut + " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut)
h4cts = h4.Integral()

# den90-den50
thisCut = theCut + " && (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut)
h5cts = h5.Integral()

# timecut
thisCut = theCut + " && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
h6 = H1D(bkg,"h6",bins,lower,upper,"trapENFCal",thisCut)
h6cts = h6.Integral()

print "raw %d  bcMax %d (%.2f)  noiseWeight %d (%.2f)  pol2 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h0cts,h3cts,h3cts/h0cts)
print "pol3 %d (%.2f)  den90-den50 %d (%.2f)   timecut %d (%.2f)" % (h4cts,h4cts/h0cts,h5cts,h5cts/h0cts,h6cts,h6cts/h0cts)

# -- Plot --
h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kGreen)
h6.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")
h6.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"bcMax","l")
l1.AddEntry(h2,"noiseWeight","l")
l1.AddEntry(h3,"pol2","l")
l1.AddEntry(h4,"pol3","l")
l1.AddEntry(h5,"den90-den50","l")
l1.AddEntry(h6,"time cut","l")
l1.Draw("same")

c.Draw()
# Out:
# raw 2081200  bcMax 1538533 (0.74)  noiseWeight 219480 (0.11)  pol2 2055909 (0.99)
# pol3 2054380 (0.99)  den90-den50 76428 (0.04)   timecut 827327 (0.40)

# %%
ds = 4
f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

c = ROOT.TCanvas("c","c",800,600)
ROOT.gPad.SetLogy(1)
bins,lower,upper = 100,0,20

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut)
h0cts = h0.Integral()
# bcMax
thisCut = theCut + " && bcMax < %d" % dsBcMax[ds]
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut)
h1cts = h1.Integral()
# noiseWeight
thisCut = theCut + " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut)
h2cts = h2.Integral()
# pol2
thisCut = theCut + " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut)
h3cts = h3.Integral()
# pol3
thisCut = theCut + " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut)
h4cts = h4.Integral()
# den90-den50
thisCut = theCut + " && (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut)
h5cts = h5.Integral()
# timecut
thisCut = theCut + " && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
h6 = H1D(bkg,"h6",bins,lower,upper,"trapENFCal",thisCut)
h6cts = h6.Integral()

print "raw %d  bcMax %d (%.2f)  noiseWeight %d (%.2f)  pol2 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h0cts,h3cts,h3cts/h0cts)
print "pol3 %d (%.2f)  den90-den50 %d (%.2f)   timecut %d (%.2f)" % (h4cts,h4cts/h0cts,h5cts,h5cts/h0cts,h6cts,h6cts/h0cts)

# -- Plot --
h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kGreen)
h6.SetLineColor(ROOT.kYellow+1)
h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")
h6.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"bcMax","l")
l1.AddEntry(h2,"noiseWeight","l")
l1.AddEntry(h3,"pol2","l")
l1.AddEntry(h4,"pol3","l")
l1.AddEntry(h5,"den90-den50","l")
l1.AddEntry(h6,"time cut","l")
l1.Draw("same")

c.Draw()
# Out:
# raw 753553  bcMax 679718 (0.90)  noiseWeight 572955 (0.76)  pol2 654206 (0.87)
# pol3 652343 (0.87)  den90-den50 23581 (0.03)   timecut 186381 (0.25)

# %%
ds = 5
f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

c = ROOT.TCanvas("c","c",800,600)
ROOT.gPad.SetLogy(1)
bins,lower,upper = 100,0,20

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut)
h0cts = h0.Integral()
# bcMax
thisCut = theCut + " && bcMax < %d" % dsBcMax[ds]
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut)
h1cts = h1.Integral()
# noiseWeight
thisCut = theCut + " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut)
h2cts = h2.Integral()
# pol2
thisCut = theCut + " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut)
h3cts = h3.Integral()
# pol3
thisCut = theCut + " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut)
h4cts = h4.Integral()
# den90-den50
thisCut = theCut + " && (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut)
h5cts = h5.Integral()
# timecut
thisCut = theCut + " && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
h6 = H1D(bkg,"h6",bins,lower,upper,"trapENFCal",thisCut)
h6cts = h6.Integral()

print "raw %d  bcMax %d (%.2f)  noiseWeight %d (%.2f)  pol2 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h0cts,h3cts,h3cts/h0cts)
print "pol3 %d (%.2f)  den90-den50 %d (%.2f)   timecut %d (%.2f)" % (h4cts,h4cts/h0cts,h5cts,h5cts/h0cts,h6cts,h6cts/h0cts)

# -- Plot --
h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kGreen)
h6.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")
h6.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"bcMax","l")
l1.AddEntry(h2,"noiseWeight","l")
l1.AddEntry(h3,"pol2","l")
l1.AddEntry(h4,"pol3","l")
l1.AddEntry(h5,"den90-den50","l")
l1.AddEntry(h6,"time cut","l")
l1.Draw("same")

c.Draw()

# %%
ds = 0
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
h0cts = h0.Integral()
# noiseWeight
noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
thisCut = theCut + noiseWtCut
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h1cts = h1.Integral()
# bcMax
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
thisCut = theCut + noiseWtCut + bcMaxCut
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h2cts = h2.Integral()
# pol2 + pol3
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h3cts = h3.Integral()

# den90-den50
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h4cts = h4.Integral()

# timecut
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h5cts = h5.Integral()


print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# -- Plot --
c = ROOT.TCanvas("c","c",1600,600)
c.Divide(2,1)
c.cd(1)
ROOT.gPad.SetLogy(1)

h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"+noiseWeight","l")
l1.AddEntry(h2,"+bcMax","l")
l1.AddEntry(h3,"+pol2&pol3","l")
l1.AddEntry(h4,"+(den90-den50)","l")
l1.AddEntry(h5,"+timecut","l")
l1.Draw("same")

c.cd(2)
ROOT.gPad.SetLogy(1)
h0N.SetLineColor(ROOT.kBlack)
h1N.SetLineColor(ROOT.kRed)
h2N.SetLineColor(ROOT.kBlue)
h3N.SetLineColor(ROOT.kMagenta)
h4N.SetLineColor(ROOT.kCyan)
h5N.SetLineColor(ROOT.kYellow+1)

h0N.Draw("hist")
h1N.Draw("hist same")
h2N.Draw("hist same")
h3N.Draw("hist same")
h4N.Draw("hist same")
h5N.Draw("hist same")

c.Draw()
# Out:
# raw 2084006  +noiseWeight 1223143 (0.59)  +bcMax 1169562 (0.96)  +pol2,pol3 1100170 (0.94)
# +(den90-den50) 74551 (0.07)  +timecut 63161 (0.85)

# %%
ds = 1
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
h0cts = h0.Integral()

# noiseWeight
noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
thisCut = theCut + noiseWtCut
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h1cts = h1.Integral()

# bcMax
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
thisCut = theCut + noiseWtCut + bcMaxCut
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h2cts = h2.Integral()

# pol2 + pol3
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h3cts = h3.Integral()

# den90-den50
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h4cts = h4.Integral()

# timecut
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h5cts = h5.Integral()


print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# -- Plot --
c = ROOT.TCanvas("c","c",1600,600)
c.Divide(2,1)
c.cd(1)
ROOT.gPad.SetLogy(1)

h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"+noiseWeight","l")
l1.AddEntry(h2,"+bcMax","l")
l1.AddEntry(h3,"+pol2&pol3","l")
l1.AddEntry(h4,"+(den90-den50)","l")
l1.AddEntry(h5,"+timecut","l")
l1.Draw("same")

c.cd(2)
ROOT.gPad.SetLogy(1)
h0N.SetLineColor(ROOT.kBlack)
h1N.SetLineColor(ROOT.kRed)
h2N.SetLineColor(ROOT.kBlue)
h3N.SetLineColor(ROOT.kMagenta)
h4N.SetLineColor(ROOT.kCyan)
h5N.SetLineColor(ROOT.kYellow+1)

h0N.Draw("hist")
h1N.Draw("hist same")
h2N.Draw("hist same")
h3N.Draw("hist same")
h4N.Draw("hist same")
h5N.Draw("hist same")

c.Draw()
# Out:
# raw 20326  +noiseWeight 5663 (0.28)  +bcMax 5348 (0.94)  +pol2,pol3 2894 (0.54)
# +(den90-den50) 769 (0.27)  +timecut 715 (0.93)

# %%
ds = 3
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
h0cts = h0.Integral()

# noiseWeight
noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
thisCut = theCut + noiseWtCut
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h1cts = h1.Integral()

# bcMax
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
thisCut = theCut + noiseWtCut + bcMaxCut
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h2cts = h2.Integral()

# pol2 + pol3
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h3cts = h3.Integral()

# den90-den50
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h4cts = h4.Integral()

# timecut
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h5cts = h5.Integral()


print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# -- Plot --
c = ROOT.TCanvas("c","c",1600,600)
c.Divide(2,1)
c.cd(1)
ROOT.gPad.SetLogy(1)

h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"+noiseWeight","l")
l1.AddEntry(h2,"+bcMax","l")
l1.AddEntry(h3,"+pol2&pol3","l")
l1.AddEntry(h4,"+(den90-den50)","l")
l1.AddEntry(h5,"+timecut","l")
l1.Draw("same")

c.cd(2)
ROOT.gPad.SetLogy(1)
h0N.SetLineColor(ROOT.kBlack)
h1N.SetLineColor(ROOT.kRed)
h2N.SetLineColor(ROOT.kBlue)
h3N.SetLineColor(ROOT.kMagenta)
h4N.SetLineColor(ROOT.kCyan)
h5N.SetLineColor(ROOT.kYellow+1)

h0N.Draw("hist")
h1N.Draw("hist same")
h2N.Draw("hist same")
h3N.Draw("hist same")
h4N.Draw("hist same")
h5N.Draw("hist same")

c.Draw()
# Out:
# raw 918351  +noiseWeight 156682 (0.17)  +bcMax 155772 (0.99)  +pol2,pol3 152461 (0.98)
# +(den90-den50) 8287 (0.05)  +timecut 6017 (0.73)

# %%
ds = 4
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
h0cts = h0.Integral()

# noiseWeight
noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
thisCut = theCut + noiseWtCut
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h1cts = h1.Integral()

# bcMax
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
thisCut = theCut + noiseWtCut + bcMaxCut
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h2cts = h2.Integral()

# pol2 + pol3
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h3cts = h3.Integral()

# den90-den50
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h4cts = h4.Integral()

# timecut
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h5cts = h5.Integral()


print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# -- Plot --
c = ROOT.TCanvas("c","c",1600,600)
c.Divide(2,1)
c.cd(1)
ROOT.gPad.SetLogy(1)

h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"+noiseWeight","l")
l1.AddEntry(h2,"+bcMax","l")
l1.AddEntry(h3,"+pol2&pol3","l")
l1.AddEntry(h4,"+(den90-den50)","l")
l1.AddEntry(h5,"+timecut","l")
l1.Draw("same")

c.cd(2)
ROOT.gPad.SetLogy(1)
h0N.SetLineColor(ROOT.kBlack)
h1N.SetLineColor(ROOT.kRed)
h2N.SetLineColor(ROOT.kBlue)
h3N.SetLineColor(ROOT.kMagenta)
h4N.SetLineColor(ROOT.kCyan)
h5N.SetLineColor(ROOT.kYellow+1)

h0N.Draw("hist")
h1N.Draw("hist same")
h2N.Draw("hist same")
h3N.Draw("hist same")
h4N.Draw("hist same")
h5N.Draw("hist same")

c.Draw()
# Out:
# raw 253069  +noiseWeight 177904 (0.70)  +bcMax 174007 (0.98)  +pol2,pol3 145025 (0.83)
# +(den90-den50) 4173 (0.03)  +timecut 2314 (0.55)

# %%
ds = 5
bins,lower,upper = 100,0,20

f1 = ROOT.TFile("~/project/lat/latSkimDS%d_0_0.root"%ds)
theCut = f1.Get("theCut").GetTitle()

bkg = ROOT.TChain("skimTree")
bkg.Add("~/project/lat/latSkimDS%d*.root"%ds)

# raw
h0 = H1D(bkg,"h0",bins,lower,upper,"trapENFCal",theCut+"&&isEnr")
h0N = H1D(bkg,"h0N",bins,lower,upper,"trapENFCal",theCut+"&&isNat")
h0cts = h0.Integral()

# noiseWeight
noiseWtCut = " && (waveS4-waveS1)/bcMax/trapENFCal > %.2f && (waveS4-waveS1)/bcMax/trapENFCal < %.2f" % (dsNoiseWt[ds][0],dsNoiseWt[ds][1])
thisCut = theCut + noiseWtCut
h1 = H1D(bkg,"h1",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h1N = H1D(bkg,"h1N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h1cts = h1.Integral()

# bcMax
bcMaxCut = " && bcMax < %d" % dsBcMax[ds]
thisCut = theCut + noiseWtCut + bcMaxCut
h2 = H1D(bkg,"h2",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h2N = H1D(bkg,"h2N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h2cts = h2.Integral()

# pol2 + pol3
pol2Cut = " && pol2 > %.3e && pol2 < %.3e" % (dsPol2[ds][0],dsPol2[ds][1])
pol3Cut = " && pol3 > %.3e && pol3 < %.3e" % (dsPol3[ds][0],dsPol3[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut
h3 = H1D(bkg,"h3",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h3N = H1D(bkg,"h3N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h3cts = h3.Integral()

# den90-den50
denCut = "&& (den90-den50) > %.2f && (den90-den50) < %.2f" % (deDen[ds][0],deDen[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut
h4 = H1D(bkg,"h4",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h4N = H1D(bkg,"h4N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h4cts = h4.Integral()

# timecut
timeCut = "&& (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) > %.2f && (bandTime-triggerTrapt0)/(matchTime-triggerTrapt0) < %.2f" % (dsTimecut[ds][0],dsTimecut[ds][1])
thisCut = theCut + noiseWtCut + bcMaxCut + pol2Cut + pol3Cut + denCut + timeCut
h5 = H1D(bkg,"h5",bins,lower,upper,"trapENFCal",thisCut+"&&isEnr")
h5N = H1D(bkg,"h5N",bins,lower,upper,"trapENFCal",thisCut+"&&isNat")
h5cts = h5.Integral()


print "raw %d  +noiseWeight %d (%.2f)  +bcMax %d (%.2f)  +pol2,pol3 %d (%.2f)" % (h0cts,h1cts,h1cts/h0cts,h2cts,h2cts/h1cts,h3cts,h3cts/h2cts)
print "+(den90-den50) %d (%.2f)  +timecut %d (%.2f)" % (h4cts,h4cts/h3cts,h5cts,h5cts/h4cts)

# -- Plot --
c = ROOT.TCanvas("c","c",1600,600)
c.Divide(2,1)
c.cd(1)
ROOT.gPad.SetLogy(1)

h0.SetLineColor(ROOT.kBlack)
h1.SetLineColor(ROOT.kRed)
h2.SetLineColor(ROOT.kBlue)
h3.SetLineColor(ROOT.kMagenta)
h4.SetLineColor(ROOT.kCyan)
h5.SetLineColor(ROOT.kYellow+1)

h0.Draw("hist")
h1.Draw("hist same")
h2.Draw("hist same")
h3.Draw("hist same")
h4.Draw("hist same")
h5.Draw("hist same")

l1 = ROOT.TLegend(0.6,0.6,0.85,0.85)
l1.AddEntry(h0,"basic","l")
l1.AddEntry(h1,"+noiseWeight","l")
l1.AddEntry(h2,"+bcMax","l")
l1.AddEntry(h3,"+pol2&pol3","l")
l1.AddEntry(h4,"+(den90-den50)","l")
l1.AddEntry(h5,"+timecut","l")
l1.Draw("same")

c.cd(2)
ROOT.gPad.SetLogy(1)
h0N.SetLineColor(ROOT.kBlack)
h1N.SetLineColor(ROOT.kRed)
h2N.SetLineColor(ROOT.kBlue)
h3N.SetLineColor(ROOT.kMagenta)
h4N.SetLineColor(ROOT.kCyan)
h5N.SetLineColor(ROOT.kYellow+1)

h0N.Draw("hist")
h1N.Draw("hist same")
h2N.Draw("hist same")
h3N.Draw("hist same")
h4N.Draw("hist same")
h5N.Draw("hist same")

c.Draw()
