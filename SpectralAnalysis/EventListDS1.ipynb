# %%
# Event list comparison
import numpy as np
import pandas as pd

# pd.options.display.max_rows = 999

import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('talk')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load files
extDir = '/Users/brianzhu/macros/code/MJDAnalysis/ROI/'
dfNew = pd.read_csv(extDir+'NewList_DS1_full.csv', sep=',', index_col=0)
dfOld = pd.read_csv(extDir+'OldList_DS1_full.csv', sep=',', index_col=0)

dfNewCut = pd.read_csv(extDir+'NewList_DS1_allcuts.csv', sep=',', index_col=0)
dfOldCut = pd.read_csv(extDir+'OldList_DS1_allcuts.csv', sep=',', index_col=0)

dfNewFull = pd.read_csv(extDir+'NewList_DS1_nocuts.csv', sep=',', index_col=0)
dfOldFull = pd.read_csv(extDir+'OldList_DS1_nocuts.csv', sep=',', index_col=0)

# %%
print dfNewFull.shape[0], dfNew.shape[0],dfNewCut.shape[0]
dfNewCut.head(10)
# Out:
# 9168 7824 6040
#        AvsE    ClockTime       DCR                 Date       DateSec  \
# 0  0.769360   165.767291 -0.000446  2016-01-13 00:01:08  1.452643e+09
# 1 -0.943519  1013.883899 -0.000497  2016-01-13 00:15:16  1.452644e+09
# 2  0.577846  1501.896750 -0.000252  2016-01-13 00:23:24  1.452645e+09
# 3 -0.023669  2691.145105 -0.000268  2016-01-13 00:43:13  1.452646e+09
# 4  0.949993  3336.091204 -0.000515  2016-01-13 00:53:58  1.452646e+09
# 5 -0.058129    26.145518 -0.000680  2016-01-13 00:58:51  1.452647e+09
# 6 -0.097852   839.703435 -0.000263  2016-01-13 01:12:25  1.452648e+09
# 7  2.677843  2071.086478 -0.000617  2016-01-13 01:32:56  1.452649e+09
# 8  0.496272  1551.978874 -0.000314  2016-01-13 02:27:38  1.452652e+09
# 9  1.108503  1727.785983 -0.000422  2016-01-13 02:30:34  1.452652e+09
#
#         Energy    LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 0   144.066708   164.566803   144.488413      664    2565       1          0
# 1   177.416239  1012.683410   177.535115      608   15795       1          0
# 2   914.400994  1500.696262   913.890484      598   23312       1          0
# 3  1253.466911  2689.944616  1254.303897      610   41774       1          0
# 4   267.134944  3334.890715   266.824089      632   51747       1          0
# 5   167.989804    23.852981   167.888488      592     208       1          0
# 6  1229.556965   837.410898  1227.366421      632    7451       1          0
# 7   992.519728  2068.793940   993.430127      626   22101       1          0
# 8   802.585536  1548.505728   802.187466      640   16324       1          0
# 9   780.439510  1724.312836   779.957278      632   18476       1          0
#
#    isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 0          0   1    1       0  9422         0
# 1          0   1    1       0  9422         0
# 2          0   1    1       0  9422         0
# 3          0   1    1       0  9422         0
# 4          0   1    1       0  9422         0
# 5          0   1    1       0  9423         0
# 6          0   1    1       0  9423         0
# 7          0   1    1       0  9423         0
# 8          0   1    1       0  9425         0
# 9          0   1    1       0  9425         0

# %%
print dfOldFull.shape[0], dfOld.shape[0],dfOldCut.shape[0]
dfOld.head(10)
# Out:
# 17660 7647 4864
#        AvsE     ClockTime       DCR                 Date       DateSec  \
# 0  1.065350  1.671758e+06 -0.000253  2016-02-01 08:21:01  1.454315e+09
# 1  0.938456  1.672541e+06 -0.000131  2016-02-01 08:34:04  1.454316e+09
# 2  0.894826  1.672606e+06 -0.000245  2016-02-01 08:35:09  1.454316e+09
# 3  1.011895  1.673094e+06  0.000075  2016-02-01 08:43:17  1.454316e+09
# 4  1.030725  1.673134e+06 -0.000020  2016-02-01 08:43:57  1.454316e+09
# 5  1.006003  1.674283e+06 -0.000158  2016-02-01 09:03:07  1.454317e+09
# 6  1.004428  1.674928e+06 -0.000253  2016-02-01 09:13:52  1.454318e+09
# 7  1.002387  1.675222e+06 -0.000206  2016-02-01 10:18:50  1.454322e+09
# 8  0.735459  1.675350e+06 -0.000266  2016-02-01 10:20:58  1.454322e+09
# 9  1.009173  1.676036e+06  0.000076  2016-02-01 10:32:23  1.454323e+09
#
#         Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 0   143.708914   144.470993      664       1          0   1       0  9422
# 1   808.177531   808.514844      610       1          0   1       0  9422
# 2   177.316742   178.028607      608       1          0   1       0  9422
# 3   914.263784   913.478791      598       1          0   1       0  9422
# 4   105.659226   106.082843      578       1          0   1       4  9422
# 5  1253.374844  1254.493479      610       1          0   1       0  9422
# 6   266.972745   266.555593      632       1          0   1       0  9422
# 7   167.716731   168.466309      592       1          0   1       0  9423
# 8   217.336722   217.848280      608       1          0   1       0  9423
# 9  1229.525508  1227.419853      632       1          0   1       0  9423
#
#    wfDCBits
# 0         0
# 1         0
# 2         0
# 3         0
# 4         4
# 5         0
# 6         0
# 7         0
# 8         0
# 9         0

# %%
# In old but not in new
# 104 - 27 
n = 0
chList0 = []
runList0 = []
energyList0 = []
chList = []
runList = []
energyList = []
for index, row in dfOld.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-10,row['Energy']+10)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfNew.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-10,row['OEnergy']+10)).empty:
        continue
    elif row['run'] in dfNew['run'].values and row['channel'] in dfNew['channel'].values: 
#     else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['ClockTime'])
        chList.append(row['channel'])
        runList.append(row['run'])
        energyList.append(row['Energy'])
        n += 1
print "Total mismatched events: ", n
# Out:
# run: 9864  channel: 582  Energy: 342.215  AvsE: 1.001  DCR: -0.00001  ClockTime: 2597256.42
# run: 10129  channel: 608  Energy: 637.509  AvsE: 1.150  DCR: -0.00056  ClockTime: 3093898.49
# run: 10139  channel: 578  Energy: 228.430  AvsE: 0.052  DCR: -14.99160  ClockTime: 3133469.47
# run: 11133  channel: 578  Energy: 224.782  AvsE: 0.056  DCR: -14.99173  ClockTime: 5641100.06
# run: 12678  channel: 672  Energy: 560.742  AvsE: 0.726  DCR: -0.00012  ClockTime: 7891177.93
# run: 12681  channel: 672  Energy: 275.452  AvsE: 1.025  DCR: -0.00010  ClockTime: 7903196.18
# run: 12682  channel: 672  Energy: 339.421  AvsE: 0.998  DCR: -0.00018  ClockTime: 7904497.12
# run: 12689  channel: 672  Energy: 1172.192  AvsE: 0.903  DCR: -0.00003  ClockTime: 7931221.86
# run: 12691  channel: 672  Energy: 1026.937  AvsE: 1.014  DCR: -0.00015  ClockTime: 7936627.00
# run: 12691  channel: 672  Energy: 906.785  AvsE: 1.019  DCR: -0.00014  ClockTime: 7937776.03
# run: 12703  channel: 672  Energy: 651.979  AvsE: 1.009  DCR: -0.00009  ClockTime: 7980784.47
# run: 12707  channel: 672  Energy: 605.029  AvsE: 1.015  DCR: -0.00014  ClockTime: 7995298.36
# run: 12717  channel: 672  Energy: 841.039  AvsE: 1.009  DCR: -0.00011  ClockTime: 8030942.54
# run: 12721  channel: 672  Energy: 693.860  AvsE: 1.040  DCR: -0.00010  ClockTime: 8044339.17
# run: 12721  channel: 672  Energy: 645.840  AvsE: 0.985  DCR: -0.00020  ClockTime: 8045243.14
# run: 12781  channel: 648  Energy: 290.082  AvsE: 0.979  DCR: -0.00008  ClockTime: 8225424.09
# run: 13011  channel: 672  Energy: 208.928  AvsE: 0.832  DCR: -0.00009  ClockTime: 8613491.25
# run: 13037  channel: 610  Energy: 706.731  AvsE: 0.817  DCR: -0.00023  ClockTime: 8704781.07
# run: 13042  channel: 664  Energy: 293.437  AvsE: 1.003  DCR: -0.00019  ClockTime: 8725565.73
# run: 13050  channel: 580  Energy: 102.002  AvsE: 1.032  DCR: -0.00016  ClockTime: 8753379.52
# run: 13235  channel: 690  Energy: 253.474  AvsE: 1.011  DCR: 0.00001  ClockTime: 9306701.86
# run: 13259  channel: 580  Energy: 1420.911  AvsE: 0.845  DCR: -0.00032  ClockTime: 9394488.56
# run: 13263  channel: 578  Energy: 204.862  AvsE: 0.998  DCR: -0.00016  ClockTime: 9408226.40
# run: 13365  channel: 608  Energy: 100.030  AvsE: 0.966  DCR: 0.00046  ClockTime: 9681993.20
# Total mismatched events:  24

# %%
# In new but not in old
# 22 - 20 : due to 594
n2 = 0
chList2 = []
runList2 = []
energyList2 = []
for index, row in dfNew.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-10,row['Energy']+10)).empty:
        continue
    elif not dfOld.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-10,row['OEnergy']+10)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif row['run'] in dfOld['run'].values and row['channel'] in dfOld['channel'].values:
#     else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'], row['ClockTime'])
        chList2.append(row['channel'])
        runList2.append(row['run'])
        energyList2.append(row['Energy'])
        n2 += 1
print "Total mismatch: ", n2
# Out:
# run: 9486  channel: 626  Energy: 832.229  AvsE: -0.938  DCR: -0.00036 LocalTime: 1985.12  ClockTime: 1985.72
# run: 9639  channel: 578  Energy: 290.651  AvsE: -1.621  DCR: -0.00036 LocalTime: 2923.41  ClockTime: 2924.45
# run: 9655  channel: 582  Energy: 280.457  AvsE: 0.268  DCR: -0.00038 LocalTime: 3388.21  ClockTime: 3389.39
# run: 9858  channel: 578  Energy: 183.509  AvsE: 0.691  DCR: -0.00011 LocalTime: 786.86  ClockTime: 787.35
# run: 10139  channel: 578  Energy: 203.505  AvsE: -11.640  DCR: 0.11486 LocalTime: 3552.56  ClockTime: 3553.47
# run: 10379  channel: 582  Energy: 112.290  AvsE: -1.808  DCR: -0.00035 LocalTime: 1770.27  ClockTime: 1771.26
# run: 10618  channel: 582  Energy: 105.083  AvsE: 0.274  DCR: -0.00037 LocalTime: 2906.02  ClockTime: 2907.44
# run: 10681  channel: 640  Energy: 645.122  AvsE: 0.284  DCR: -0.00039 LocalTime: 2200.02  ClockTime: 2200.58
# run: 10745  channel: 648  Energy: 235.645  AvsE: -0.686  DCR: -0.00105 LocalTime: 645.95  ClockTime: 661.31
# run: 11133  channel: 578  Energy: 200.352  AvsE: -11.383  DCR: 0.11277 LocalTime: 343.38  ClockTime: 357.06
# run: 11451  channel: 592  Energy: 116.747  AvsE: -0.012  DCR: -0.00068 LocalTime: 3548.25  ClockTime: 3548.69
# run: 12755  channel: 598  Energy: 104.719  AvsE: 0.526  DCR: -0.00026 LocalTime: 406.82  ClockTime: 406.86
# run: 12844  channel: 640  Energy: 176.739  AvsE: 0.184  DCR: -0.00077 LocalTime: 2567.36  ClockTime: 2567.36
# run: 13036  channel: 632  Energy: 213.782  AvsE: 0.927  DCR: -0.00040 LocalTime: 3495.96  ClockTime: 3496.05
# run: 13127  channel: 582  Energy: 337.207  AvsE: 0.469  DCR: -0.00043 LocalTime: 1712.73  ClockTime: 1712.82
# run: 13225  channel: 610  Energy: 400.659  AvsE: 0.215  DCR: -0.00037 LocalTime: 3133.98  ClockTime: 3134.07
# run: 13335  channel: 580  Energy: 406.766  AvsE: -4.067  DCR: -0.00053 LocalTime: 494.37  ClockTime: 494.41
# Total mismatch:  17

# %%
# Since mismatched events, look in full file
# In old but not in new
nfull1 = 0
chListfull1 = []
runListfull1 = []
energyListfull1 = []
for run,channel,energy in zip(runList, chList, energyList):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-10,energy+10)).empty:
#         print 'Found events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
#         print dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-10,energy+10)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfNewFull['run'].values and channel in dfNewFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull1.append(row['channel'])
        runListfull1.append(row['run'])
        energyListfull1.append(row['Energy'])
        nfull1 += 1
print "Total mismatch: ", nfull1
# Out:
# Mismatched events -- run: 10129  channel: 608  Energy: 637.509
# Mismatched events -- run: 10139  channel: 578  Energy: 228.430
# Mismatched events -- run: 11133  channel: 578  Energy: 224.782
# Mismatched events -- run: 12678  channel: 672  Energy: 560.742
# Mismatched events -- run: 12681  channel: 672  Energy: 275.452
# Mismatched events -- run: 12682  channel: 672  Energy: 339.421
# Mismatched events -- run: 12689  channel: 672  Energy: 1172.192
# Mismatched events -- run: 12691  channel: 672  Energy: 1026.937
# Mismatched events -- run: 12691  channel: 672  Energy: 906.785
# Mismatched events -- run: 12703  channel: 672  Energy: 651.979
# Mismatched events -- run: 12707  channel: 672  Energy: 605.029
# Mismatched events -- run: 12717  channel: 672  Energy: 841.039
# Mismatched events -- run: 12721  channel: 672  Energy: 693.860
# Mismatched events -- run: 12721  channel: 672  Energy: 645.840
# Mismatched events -- run: 13365  channel: 608  Energy: 100.030
# Total mismatch:  15

# %%
# Since mismatched events, look in full file
# In new but not in old
nfull2 = 0
chListfull2 = []
runListfull2 = []
energyListfull2 = []
for run,channel,energy in zip(runList2, chList2, energyList2):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).empty:
#         print 'Found events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
#         print dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfOldFull['run'].values and channel in dfOldFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull2.append(row['channel'])
        runListfull2.append(row['run'])
        energyListfull2.append(row['Energy'])
        nfull2 += 1
print "Total mismatch: ", nfull2
# Out:
# Mismatched events -- run: 10139  channel: 578  Energy: 203.505
# Mismatched events -- run: 11133  channel: 578  Energy: 200.352
# Mismatched events -- run: 11451  channel: 592  Energy: 116.747
# Total mismatch:  3

# %%
# Cut events in old but not in new
nCut2,nSwap2 = 0,0
chListCut2 = []
runListCut2 = []
energyListCut2 = []
nDC, nMu, nLN, nAvsE, nDCR = 0, 0, 0, 0, 0
for index, row in dfOldCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 100:
        continue
    if not dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfNewCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy','LocalTime'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values != 0 or dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= -1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        nSwap2 += 1
        chListCut2.append(row['channel'])
        runListCut2.append(row['run'])
        energyListCut2.append(row['Energy'])        
        continue
    elif row['run'] in dfNewCut['run'].values and row['channel'] in dfNewCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'])

        nCut2 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d"%(nLN, nMu, nDC, nAvsE, nDCR)
print "Total swapped: ", nSwap2
print "Total mismatch: ", nCut2
# Out:
# Untagged - run: 9864  channel: 582  Energy: 342.215  AvsE: 1.001  DCR: -0.00001
#         AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 978  0.57455 -0.000151  533.269955      672  252953       1          1
#
#      isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 978          0   1    1       0  9895         0
# AvsE:1.024  DCR:-0.00009  Energy:532.805  channel:672  run:9895
# Untagged - run: 10129  channel: 608  Energy: 637.509  AvsE: 1.150  DCR: -0.00056
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 1488  0.907717 -0.000359  647.438904      582   84795       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 1488          0   1    1       0  10140         0
# AvsE:1.011  DCR:-0.00016  Energy:647.384  channel:582  run:10140
#           AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 1838  0.509778 -0.000546  1529.501705      598   18635       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 1838          0   1    1       0  10204         0
# AvsE:1.010  DCR:-0.00016  Energy:1529.789  channel:598  run:10204
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 1839  0.116279 -0.001018  492.333033      648   20063       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 1839          0   1    1       0  10204         0
# AvsE:1.018  DCR:-0.00019  Energy:492.184  channel:648  run:10204
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 2895 -2.068289 -0.000393  910.772555      582    9329       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 2895          0   1    1       0  10700         0
# AvsE:1.005  DCR:-0.00021  Energy:910.538  channel:582  run:10700
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 2967 -1.444929 -0.000418  2118.99211      632    2091       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 2967          0   1    1       0  10712         0
# AvsE:1.001  DCR:-0.00010  Energy:2119.479  channel:632  run:10712
#           AvsE       DCR     Energy  channel  iEvent  isGood  isLNFill1  \
# 3053 -0.088237 -0.000128  915.08278      672  241811       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 3053          0   1    1       0  10753         0
# AvsE:1.007  DCR:-0.00002  Energy:915.018  channel:672  run:10753
#           AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 3698 -1.095471 -0.000396  1562.913105      632   16604       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 3698          0   1    1       0  11111         0
# AvsE:1.001  DCR:-0.00009  Energy:1563.023  channel:632  run:11111
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 3788  0.082605 -0.000436  1017.75586      664  255141       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 3788          0   1    1       0  11126         0
# AvsE:1.004  DCR:-0.00025  Energy:1017.328  channel:664  run:11126
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 3990  0.15256 -0.000373  781.855972      640  197296       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 3990          0   1    1       0  11163         0
# AvsE:1.020  DCR:-0.00012  Energy:781.921  channel:640  run:11163
#           AvsE       DCR     Energy  channel  iEvent  isGood  isLNFill1  \
# 3991  0.432726 -0.000245  631.32732      578  197756       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 3991          0   1    1       0  11163         0
# AvsE:1.011  DCR:-0.00011  Energy:631.091  channel:578  run:11163
#           AvsE     DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 4658  0.092958 -0.0012  226.907203      648  410922       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 4658          0   1    1       0  12617         0
# AvsE:1.019  DCR:-0.00039  Energy:226.733  channel:648  run:12617
# Untagged - run: 12681  channel: 672  Energy: 275.452  AvsE: 1.025  DCR: -0.00010
#           AvsE      DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 4899 -0.100743 -0.00032  870.191989      578    1028       1          1
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 4899          0   1    1       0  12688         0
# AvsE:1.004  DCR:-0.00016  Energy:870.013  channel:578  run:12688
# Untagged - run: 12691  channel: 672  Energy: 1026.937  AvsE: 1.014  DCR: -0.00015
# Untagged - run: 12691  channel: 672  Energy: 906.785  AvsE: 1.019  DCR: -0.00014
# Untagged - run: 12703  channel: 672  Energy: 651.979  AvsE: 1.009  DCR: -0.00009
# Untagged - run: 12707  channel: 672  Energy: 605.029  AvsE: 1.015  DCR: -0.00014
# Untagged - run: 12717  channel: 672  Energy: 841.039  AvsE: 1.009  DCR: -0.00011
# Untagged - run: 12721  channel: 672  Energy: 693.860  AvsE: 1.040  DCR: -0.00010
# Untagged - run: 13042  channel: 664  Energy: 293.437  AvsE: 1.003  DCR: -0.00019
# Untagged - run: 13050  channel: 580  Energy: 102.002  AvsE: 1.032  DCR: -0.00016
#           AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 5955 -1.291573 -0.000892  1556.183896      640   14834       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 5955          0   1    1       0  13084         0
# AvsE:1.003  DCR:-0.00028  Energy:1556.643  channel:640  run:13084
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 6307  0.595338 -0.000389  144.106622      610   58945       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 6307          0   1    1       1  13199         0
# AvsE:1.011  DCR:-0.00019  Energy:143.963  channel:610  run:13199
# Cut by LNFill: 10   muVeto: 1   wfDCBits: 0   AvsE: 4   DCR: 0
# Total swapped:  15
# Total mismatch:  11

# %%
# Cut events not rejected in new skim
nCut,nSwap = 0,0
chListCut = []
runListCut = []
energyListCut = []
energyListCutAvsE = []
energyListCutDCR = []
energyListBurst = []
nDC, nMu, nLN, nAvsE, nDCR, nBurst = 0, 0, 0, 0, 0, 0
for index, row in dfNewCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 100:
        continue
    if not dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfOldCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        print dfTemp.drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        if 7370e3<dfTemp['ClockTime'].values<7371e3 or 2192e3<dfTemp['ClockTime'].values<2195e3 or 7840e3<dfTemp['ClockTime'].values<7860e3:
            nBurst += 1
        elif 8384e3<dfTemp['ClockTime'].values<8387e3 or 8984e3<dfTemp['ClockTime'].values<8985e3 or 9002e3<dfTemp['ClockTime'].values<9005e3:
            nBurst += 1
            energyListCutBurst.append(row['Energy'])
        elif dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= 1:
            energyListCutAvsE.append(row['Energy'])
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            energyListCutDCR.append(row['Energy'])
            nDCR += 1
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCut.append(row['channel'])
        runListCut.append(row['run'])
        energyListCut.append(row['Energy'])
        nSwap += 1
        continue
    elif row['run'] in dfOldCut['run'].values and row['channel'] in dfOldCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCut += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d  Burst: %d"%(nLN, nMu, nDC, nAvsE, nDCR, nBurst)
print "Total swapped: ", nSwap
print "Total mismatch: ", nCut
# Out:
#        AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 2  0.894826 -0.000245  177.316742      608       1          0   1       0
#
#     run  wfDCBits
# 2  9422         0
# AvsE:-0.944  DCR:-0.00050  Energy:177.416  channel:608  run:9422
#        AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 3  1.011895  0.000075  914.263784      598       1          0   1       0
#
#     run  wfDCBits
# 3  9422         0
# AvsE:0.578  DCR:-0.00025  Energy:914.401  channel:598  run:9422
#        AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 9  1.009173  0.000076  1229.525508      632       1          0   1       0
#
#     run  wfDCBits
# 9  9423         0
# AvsE:-0.098  DCR:-0.00026  Energy:1229.557  channel:632  run:9423
#         AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 21  0.994768 -0.00016  155.547026      608       1          0   1       0
#
#      run  wfDCBits
# 21  9426         0
# AvsE:0.647  DCR:-0.00046  Energy:155.677  channel:608  run:9426
#        AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 24  0.96569 -0.000231  131.117769      664       1          0   1       0
#
#      run  wfDCBits
# 24  9426         0
# AvsE:-0.008  DCR:-0.00042  Energy:130.952  channel:664  run:9426
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 33  0.996549 -0.000195  325.599352      592       1          0   1       0
#
#      run  wfDCBits
# 33  9427         0
# AvsE:-0.279  DCR:-0.00069  Energy:325.942  channel:592  run:9427
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 42  0.997403 -0.000378  143.928714      608       1          0   1       0
#
#      run  wfDCBits
# 42  9429         0
# AvsE:0.714  DCR:-0.00068  Energy:143.939  channel:608  run:9429
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 43  0.989492 -0.000492  867.148612      626       1          0   1       0
#
#      run  wfDCBits
# 43  9429         0
# AvsE:-0.838  DCR:-0.00063  Energy:866.408  channel:626  run:9429
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 55  1.009994  0.000033  512.022582      598       1          0   1       0
#
#      run  wfDCBits
# 55  9432         0
# AvsE:0.337  DCR:-0.00022  Energy:512.315  channel:598  run:9432
#         AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 57  1.007599  0.000202  1191.974227      598       1          0   1       0
#
#      run  wfDCBits
# 57  9432         0
# AvsE:0.179  DCR:-0.00010  Energy:1192.046  channel:598  run:9432
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 59  0.932472 -0.000267  132.384775      608       1          0   1       0
#
#      run  wfDCBits
# 59  9432         0
# AvsE:0.170  DCR:-0.00053  Energy:132.582  channel:608  run:9432
#        AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 60  0.98931 -0.000324  816.917557      626       1          0   1       0
#
#      run  wfDCBits
# 60  9432         0
# AvsE:-0.772  DCR:-0.00049  Energy:816.283  channel:626  run:9432
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 65  0.863656 -0.000207  159.554409      648       1          0   1       0
#
#      run  wfDCBits
# 65  9433         0
# AvsE:-0.959  DCR:-0.00101  Energy:159.800  channel:648  run:9433
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 66  1.014337  0.000005  965.992586      672       1          0   1       0
#
#      run  wfDCBits
# 66  9433         0
# AvsE:0.243  DCR:-0.00010  Energy:966.278  channel:672  run:9433
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 68  1.008633  0.000092  643.953362      598       1          0   1       0
#
#      run  wfDCBits
# 68  9433         0
# AvsE:0.275  DCR:-0.00020  Energy:644.199  channel:598  run:9433
#         AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 77  1.010724  0.000232  1062.151608      598       1          0   1       0
#
#      run  wfDCBits
# 77  9435         0
# AvsE:0.508  DCR:-0.00011  Energy:1062.265  channel:598  run:9435
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 79  0.987596 -0.000227  250.084516      626       1          0   1       0
#
#      run  wfDCBits
# 79  9435         0
# AvsE:0.182  DCR:-0.00036  Energy:250.126  channel:626  run:9435
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 86  1.030062  0.000128  522.300526      598       1          0   1       0
#
#      run  wfDCBits
# 86  9436         0
# AvsE:1.343  DCR:-0.00017  Energy:522.698  channel:598  run:9436
#         AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 89  0.977888 -0.00003  175.413479      598       1          0   1       0
#
#      run  wfDCBits
# 89  9436         0
# AvsE:-0.246  DCR:-0.00025  Energy:175.582  channel:598  run:9436
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 92  0.989349 -0.000162  820.837699      626       1          0   1       0
#
#      run  wfDCBits
# 92  9437         0
# AvsE:-0.777  DCR:-0.00034  Energy:820.212  channel:626  run:9437
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 98  1.056888  0.000058  743.187353      690       1          0   1       0
#
#      run  wfDCBits
# 98  9439         0
# AvsE:9.650  DCR:-0.00015  Energy:743.438  channel:690  run:9439
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 119  0.990811 -0.000212  299.282934      664       1          0   1       0
#
#       run  wfDCBits
# 119  9475         0
# AvsE:-0.532  DCR:-0.00042  Energy:299.726  channel:664  run:9475
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 122  0.959075 -0.000153  178.893861      632       1          0   1       0
#
#       run  wfDCBits
# 122  9476         0
# AvsE:0.287  DCR:-0.00045  Energy:178.891  channel:632  run:9476
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 135  0.99225 -0.000411  893.869916      626       1          0   1       0
#
#       run  wfDCBits
# 135  9478         0
# AvsE:-0.716  DCR:-0.00064  Energy:893.412  channel:626  run:9478
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 145  0.987931 -0.000072  101.220693      610       1          0   1       0
#
#       run  wfDCBits
# 145  9480         0
# AvsE:0.536  DCR:-0.00021  Energy:101.459  channel:610  run:9480
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 153  0.990008 -0.000269  402.19646      626       1          0   1       0
#
#       run  wfDCBits
# 153  9482         0
# AvsE:-0.053  DCR:-0.00041  Energy:402.263  channel:626  run:9482
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 159  1.007732  0.000051  1237.881411      610       1          0   1       0
#
#       run  wfDCBits
# 159  9483         0
# AvsE:0.233  DCR:-0.00005  Energy:1237.495  channel:610  run:9483
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 164  1.005947  0.000023  344.105034      598       1          0   1       0
#
#       run  wfDCBits
# 164  9485         0
# AvsE:0.195  DCR:-0.00023  Energy:344.039  channel:598  run:9485
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 165  0.974907 -0.00012  228.074327      648       1          0   1       0
#
#       run  wfDCBits
# 165  9485         0
# AvsE:-0.197  DCR:-0.00092  Energy:228.238  channel:648  run:9485
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 167  0.997918 -0.000181  416.639708      626       1          0   1       0
#
#       run  wfDCBits
# 167  9485         0
# AvsE:0.142  DCR:-0.00036  Energy:416.666  channel:626  run:9485
# Untagged - run: 9486  channel: 626  Energy: 832.229  AvsE: -0.938  DCR: -0.00036 LocalTime: 1985.12
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 179  0.992335 -0.000414  851.508801      626       1          0   1       0
#
#       run  wfDCBits
# 179  9487         0
# AvsE:-0.658  DCR:-0.00055  Energy:851.171  channel:626  run:9487
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 181  0.992497 -0.000213  277.05338      626       1          0   1       0
#
#       run  wfDCBits
# 181  9487         0
# AvsE:0.223  DCR:-0.00036  Energy:277.111  channel:626  run:9487
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 182  1.002406  0.000008  413.707367      582       1          0   1       0
#
#       run  wfDCBits
# 182  9487         0
# AvsE:0.318  DCR:-0.00024  Energy:413.843  channel:582  run:9487
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 188  0.94351 -0.000297  144.270316      580       1          0   1       0
#
#       run  wfDCBits
# 188  9492         0
# AvsE:0.387  DCR:-0.00051  Energy:144.483  channel:580  run:9492
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 201  0.83332 -0.000122  160.611058      592       1          0   1       0
#
#       run  wfDCBits
# 201  9539         0
# AvsE:-0.608  DCR:-0.00061  Energy:160.694  channel:592  run:9539
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 203  1.011752  0.000111  755.489098      598       1          0   1       0
#
#       run  wfDCBits
# 203  9539         0
# AvsE:0.507  DCR:-0.00019  Energy:755.370  channel:598  run:9539
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 212  0.998883 -0.000189  1079.041741      580       1          0   1       0
#
#       run  wfDCBits
# 212  9540         0
# AvsE:-0.487  DCR:-0.00036  Energy:1078.782  channel:580  run:9540
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 215  0.995647 -0.00029  250.147369      580       1          0   1       0
#
#       run  wfDCBits
# 215  9541         0
# AvsE:0.299  DCR:-0.00049  Energy:250.107  channel:580  run:9541
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 216  0.954816 -0.000225  211.03216      626       1          0   1       0
#
#       run  wfDCBits
# 216  9541         0
# AvsE:-0.195  DCR:-0.00038  Energy:211.094  channel:626  run:9541
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 220  0.991559 -0.000056  283.851833      626       1          0   1       0
#
#       run  wfDCBits
# 220  9542         0
# AvsE:0.194  DCR:-0.00024  Energy:283.857  channel:626  run:9542
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 227  0.777199 -0.000216  125.861853      578       1          0   1       0
#
#       run  wfDCBits
# 227  9543         0
# AvsE:-0.970  DCR:-0.00030  Energy:126.115  channel:578  run:9543
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 228  1.004491  0.000089  1268.323068      580       1          0   1       0
#
#       run  wfDCBits
# 228  9543         0
# AvsE:-0.665  DCR:-0.00009  Energy:1268.146  channel:580  run:9543
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 235  0.992743 -0.000316  869.081893      608       1          0   1       0
#
#       run  wfDCBits
# 235  9545         0
# AvsE:1.023  DCR:-0.00061  Energy:868.403  channel:608  run:9545
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 236  0.992853 -0.000415  1007.356977      626       1          0   1       0
#
#       run  wfDCBits
# 236  9545         0
# AvsE:-0.817  DCR:-0.00060  Energy:1006.492  channel:626  run:9545
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 238  0.995755 -0.00025  580.133117      580       1          0   1       0
#
#       run  wfDCBits
# 238  9545         0
# AvsE:-0.475  DCR:-0.00047  Energy:580.024  channel:580  run:9545
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 245  0.998144 -0.000224  159.512328      626       1          0   1       0
#
#       run  wfDCBits
# 245  9546         0
# AvsE:0.475  DCR:-0.00035  Energy:159.697  channel:626  run:9546
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 246  1.005938  0.000159  848.150086      598       1          0   1       0
#
#       run  wfDCBits
# 246  9546         0
# AvsE:0.072  DCR:-0.00019  Energy:847.854  channel:598  run:9546
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 250  0.991736 -0.000251  905.162171      626       1          0   1       0
#
#       run  wfDCBits
# 250  9547         0
# AvsE:-0.763  DCR:-0.00043  Energy:904.566  channel:626  run:9547
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 256  0.997154 -0.000272  395.959436      608       1          0   1       0
#
#       run  wfDCBits
# 256  9548         0
# AvsE:0.976  DCR:-0.00050  Energy:395.788  channel:608  run:9548
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 259  0.976153 -0.000133  171.200993      626       1          0   1       0
#
#       run  wfDCBits
# 259  9548         0
# AvsE:0.217  DCR:-0.00031  Energy:171.258  channel:626  run:9548
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 274  0.954256 -0.000154  266.886168      578       1          0   1       0
#
#       run  wfDCBits
# 274  9551         0
# AvsE:-0.221  DCR:-0.00026  Energy:267.173  channel:578  run:9551
#         AvsE     DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 279  0.99455 -0.0004  922.346538      626       1          0   1       0
#
#       run  wfDCBits
# 279  9551         0
# AvsE:-0.612  DCR:-0.00056  Energy:921.698  channel:626  run:9551
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 282  0.946434 -0.000262  130.545363      580       1          0   1       0
#
#       run  wfDCBits
# 282  9552         0
# AvsE:0.476  DCR:-0.00045  Energy:130.566  channel:580  run:9552
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 285  0.995253 -0.000037  161.605573      598       1          0   1       0
#
#       run  wfDCBits
# 285  9552         0
# AvsE:0.065  DCR:-0.00025  Energy:161.721  channel:598  run:9552
#        AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 290  0.9952 -0.000069  196.872605      640       1          0   1       0
#
#       run  wfDCBits
# 290  9553         0
# AvsE:0.213  DCR:-0.00029  Energy:197.049  channel:640  run:9553
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 296  0.900497 -0.000042  156.817528      626       1          0   1       0
#
#       run  wfDCBits
# 296  9554         0
# AvsE:-0.535  DCR:-0.00015  Energy:156.957  channel:626  run:9554
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 307  0.989412 -0.000328  553.570328      626       1          0   1       0
#
#       run  wfDCBits
# 307  9556         0
# AvsE:-0.320  DCR:-0.00048  Energy:553.210  channel:626  run:9556
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 310  0.766983 -0.000194  107.856272      632       1          0   1       0
#
#       run  wfDCBits
# 310  9556         0
# AvsE:-0.995  DCR:-0.00050  Energy:108.004  channel:632  run:9556
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 314  1.008461  0.00017  748.829467      598       1          0   1       0
#
#       run  wfDCBits
# 314  9557         0
# AvsE:0.289  DCR:-0.00012  Energy:748.488  channel:598  run:9557
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 322  1.013368  0.000031  482.416769      672       1          0   1       0
#
#       run  wfDCBits
# 322  9557         0
# AvsE:0.311  DCR:-0.00006  Energy:482.662  channel:672  run:9557
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 327  1.004737  0.000171  1015.113276      598       1          0   1       0
#
#       run  wfDCBits
# 327  9558         0
# AvsE:-0.092  DCR:-0.00014  Energy:1014.791  channel:598  run:9558
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 340  0.989974 -0.000087  132.062934      608       1          0   1       0
#
#       run  wfDCBits
# 340  9560         0
# AvsE:0.402  DCR:-0.00041  Energy:132.169  channel:608  run:9560
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 345  0.991918 -0.000318  865.685943      626       1          0   1       0
#
#       run  wfDCBits
# 345  9563         0
# AvsE:-0.706  DCR:-0.00049  Energy:865.266  channel:626  run:9563
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 364  1.014831  0.000054  740.159072      690       1          0   1       0
#
#       run  wfDCBits
# 364  9565         0
# AvsE:2.847  DCR:-0.00015  Energy:740.257  channel:690  run:9565
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 365  1.010605  0.000203  1539.812532      592       1          0   1       0
#
#       run  wfDCBits
# 365  9638         0
# AvsE:-0.347  DCR:-0.00056  Energy:1538.466  channel:592  run:9638
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 366  1.006036  0.000093  619.579784      598       1          0   1       0
#
#       run  wfDCBits
# 366  9638         0
# AvsE:0.134  DCR:-0.00022  Energy:619.396  channel:598  run:9638
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 373  0.986679 -0.000424  844.516594      626       1          0   1       0
#
#       run  wfDCBits
# 373  9639         0
# AvsE:-0.955  DCR:-0.00058  Energy:843.902  channel:626  run:9639
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 382  0.915194 -0.000179  174.82848      648       1          0   1       0
#
#       run  wfDCBits
# 382  9640         0
# AvsE:-0.791  DCR:-0.00100  Energy:175.006  channel:648  run:9640
#         AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 391  0.98526 -0.00016  555.124619      578       1          0   1       0
#
#       run  wfDCBits
# 391  9642         0
# AvsE:-0.440  DCR:-0.00027  Energy:555.502  channel:578  run:9642
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 394  1.009792  0.000168  846.772056      598       1          0   1       0
#
#       run  wfDCBits
# 394  9642         0
# AvsE:0.376  DCR:-0.00017  Energy:846.605  channel:598  run:9642
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 415  0.99286 -0.000223  260.562846      664       1          0   1       0
#
#       run  wfDCBits
# 415  9645         0
# AvsE:-0.367  DCR:-0.00043  Energy:260.887  channel:664  run:9645
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 423  0.980117 -0.00018  341.410701      610       1          0   1       0
#
#       run  wfDCBits
# 423  9646         0
# AvsE:-0.420  DCR:-0.00029  Energy:341.524  channel:610  run:9646
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 565  1.013067 -0.000267  820.478409      608       1          0   1       0
#
#       run  wfDCBits
# 565  9654         0
# AvsE:0.419  DCR:-0.00050  Energy:820.126  channel:608  run:9654
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 566  1.021601 -0.000226  1102.233114      592       1          0   1       0
#
#       run  wfDCBits
# 566  9654         0
# AvsE:0.370  DCR:-0.00091  Energy:1102.127  channel:592  run:9654
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 567  1.022316 -0.000144  260.250335      592       1          0   1       0
#
#       run  wfDCBits
# 567  9654         0
# AvsE:0.056  DCR:-0.00063  Energy:260.345  channel:592  run:9654
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 569  0.998182 -0.000234  256.007776      632       1          0   1       0
#
#       run  wfDCBits
# 569  9654         0
# AvsE:0.678  DCR:-0.00053  Energy:256.106  channel:632  run:9654
# Untagged - run: 9655  channel: 582  Energy: 280.457  AvsE: 0.268  DCR: -0.00038 LocalTime: 3388.21
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 572  0.79005 -0.000129  104.663769      608       1          0   1       0
#
#       run  wfDCBits
# 572  9655         0
# AvsE:-0.696  DCR:-0.00040  Energy:104.741  channel:608  run:9655
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 574  0.992678 -0.000157  143.223542      664       1          0   1       0
#
#       run  wfDCBits
# 574  9656         0
# AvsE:0.024  DCR:-0.00036  Energy:143.596  channel:664  run:9656
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 577  1.006703  0.000297  977.872623      598       1          0   1       0
#
#       run  wfDCBits
# 577  9656         0
# AvsE:0.115  DCR:-0.00003  Energy:977.486  channel:598  run:9656
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 578  1.047536  0.000462  679.760704      648       1          0   1       0
#
#       run  wfDCBits
# 578  9656         0
# AvsE:-0.200  DCR:-0.00033  Energy:679.721  channel:648  run:9656
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 592  0.956618 -0.000101  190.442413      598       1          0   1       0
#
#       run  wfDCBits
# 592  9658         0
# AvsE:-0.694  DCR:-0.00031  Energy:190.642  channel:598  run:9658
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 602  1.010276  0.000298  1291.918205      598       1          0   1       0
#
#       run  wfDCBits
# 602  9660         0
# AvsE:0.492  DCR:-0.00008  Energy:1291.536  channel:598  run:9660
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 603  1.036501  0.000011  443.612118      690       1          0   1       0
#
#       run  wfDCBits
# 603  9660         0
# AvsE:4.442  DCR:-0.00019  Energy:443.795  channel:690  run:9660
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 606  1.011792  0.000142  637.855771      598       1          0   1       0
#
#       run  wfDCBits
# 606  9660         0
# AvsE:0.484  DCR:-0.00010  Energy:637.673  channel:598  run:9660
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 610  0.998879 -0.000422  1111.504323      608       1          0   1       0
#
#       run  wfDCBits
# 610  9661         0
# AvsE:-0.349  DCR:-0.00067  Energy:1111.058  channel:608  run:9661
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 612  0.994157 -0.000265  187.82891      580       1          0   1       0
#
#       run  wfDCBits
# 612  9661         0
# AvsE:0.375  DCR:-0.00047  Energy:187.873  channel:580  run:9661
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 622  1.072081  0.000107  1383.838133      690       1          0   1       0
#
#       run  wfDCBits
# 622  9662         0
# AvsE:21.042  DCR:-0.00008  Energy:1384.162  channel:690  run:9662
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 627  0.997642 -0.000033  377.185879      610       1          0   1       0
#
#       run  wfDCBits
# 627  9663         0
# AvsE:0.123  DCR:-0.00019  Energy:377.254  channel:610  run:9663
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 631  0.991043 -0.000508  505.879647      626       1          0   1       0
#
#       run  wfDCBits
# 631  9664         0
# AvsE:-0.204  DCR:-0.00066  Energy:505.874  channel:626  run:9664
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 639  0.906693 -0.000068  249.507597      578       1          0   1       0
#
#       run  wfDCBits
# 639  9667         0
# AvsE:-0.898  DCR:-0.00020  Energy:249.730  channel:578  run:9667
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 641  0.951673 -0.000231  186.147977      608       1          0   1       0
#
#       run  wfDCBits
# 641  9667         0
# AvsE:-0.072  DCR:-0.00050  Energy:186.238  channel:608  run:9667
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 664  0.990182 -0.000445  981.011462      626       1          0   1       0
#
#       run  wfDCBits
# 664  9711         0
# AvsE:-0.972  DCR:-0.00061  Energy:980.781  channel:626  run:9711
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 674  0.993244 -0.000211  345.276592      626       1          0   1       0
#
#       run  wfDCBits
# 674  9712         0
# AvsE:0.123  DCR:-0.00042  Energy:345.442  channel:626  run:9712
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 687  0.90395 -0.000129  177.265786      640       1          0   1       0
#
#       run  wfDCBits
# 687  9716         0
# AvsE:-0.342  DCR:-0.00033  Energy:177.296  channel:640  run:9716
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 690  0.990192 -0.000263  639.868835      626       1          0   1       0
#
#       run  wfDCBits
# 690  9716         0
# AvsE:-0.430  DCR:-0.00040  Energy:639.625  channel:626  run:9716
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 691  0.997306 -0.000108  247.995449      610       1          0   1       0
#
#       run  wfDCBits
# 691  9717         0
# AvsE:0.347  DCR:-0.00022  Energy:248.128  channel:610  run:9717
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 692  0.988933 -0.000262  116.319432      598       1          0   1       0
#
#       run  wfDCBits
# 692  9717         0
# AvsE:0.054  DCR:-0.00049  Energy:116.438  channel:598  run:9717
#          AvsE           DCR      Energy  channel  isGood  isLNFill1  mH  \
# 695  0.999059  3.033059e-07  137.816656      648       1          0   1
#
#      muVeto   run  wfDCBits
# 695       0  9717         0
# AvsE:-0.053  DCR:-0.00084  Energy:138.036  channel:648  run:9717
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 701  1.009044  0.000255  1256.23905      598       1          0   1       0
#
#       run  wfDCBits
# 701  9719         0
# AvsE:0.347  DCR:-0.00012  Energy:1255.873  channel:598  run:9719
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 703  1.04409  0.000019  164.369531      598       1          0   1       0
#
#       run  wfDCBits
# 703  9719         0
# AvsE:0.836  DCR:-0.00020  Energy:164.524  channel:598  run:9719
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 710  1.009792  0.000103  855.881523      598       1          0   1       0
#
#       run  wfDCBits
# 710  9720         0
# AvsE:0.382  DCR:-0.00021  Energy:855.729  channel:598  run:9720
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 714  0.94446 -0.000311  276.456064      626       1          0   1       0
#
#       run  wfDCBits
# 714  9721         0
# AvsE:-0.657  DCR:-0.00048  Energy:276.563  channel:626  run:9721
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 722  0.996965 -0.000041  194.745049      626       1          0   1       0
#
#       run  wfDCBits
# 722  9722         0
# AvsE:0.422  DCR:-0.00019  Energy:194.846  channel:626  run:9722
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 733  0.996906 -0.000184  234.100692      578       1          0   1       0
#
#       run  wfDCBits
# 733  9724         0
# AvsE:0.582  DCR:-0.00031  Energy:234.300  channel:578  run:9724
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 745  0.991294 -0.000224  192.851117      582       1          0   1       0
#
#       run  wfDCBits
# 745  9726         0
# AvsE:-0.123  DCR:-0.00042  Energy:192.977  channel:582  run:9726
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 747  0.933849 -0.000124  278.964575      640       1          0   1       0
#
#       run  wfDCBits
# 747  9727         0
# AvsE:-0.889  DCR:-0.00034  Energy:279.148  channel:640  run:9727
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 752  1.011853  0.000043  945.184019      632       1          0   1       0
#
#       run  wfDCBits
# 752  9727         0
# AvsE:0.206  DCR:-0.00028  Energy:945.424  channel:632  run:9727
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 756  0.952411 -0.000066  226.837877      610       1          0   1       0
#
#       run  wfDCBits
# 756  9763         0
# AvsE:-0.632  DCR:-0.00021  Energy:226.908  channel:610  run:9763
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 768  0.942558 -0.000127  145.152677      648       1          0   1       0
#
#       run  wfDCBits
# 768  9765         0
# AvsE:-0.346  DCR:-0.00094  Energy:145.370  channel:648  run:9765
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 776  1.073564  0.000019  114.986121      608       1          0   1       0
#
#       run  wfDCBits
# 776  9767         0
# AvsE:1.534  DCR:-0.00024  Energy:114.959  channel:608  run:9767
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 782  0.999796 -0.000255  812.246663      664       1          0   1       0
#
#       run  wfDCBits
# 782  9768         0
# AvsE:-0.403  DCR:-0.00053  Energy:812.430  channel:664  run:9768
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 788  0.858884 -0.000008  110.207723      610       1          0   1       0
#
#       run  wfDCBits
# 788  9770         0
# AvsE:-0.908  DCR:-0.00017  Energy:110.304  channel:610  run:9770
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 794  0.975948 -0.000235  420.143837      640       1          0   1       0
#
#       run  wfDCBits
# 794  9772         0
# AvsE:-0.491  DCR:-0.00039  Energy:420.134  channel:640  run:9772
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 796  0.93589 -0.000034  131.917292      608       1          0   1       0
#
#       run  wfDCBits
# 796  9772         0
# AvsE:-0.015  DCR:-0.00032  Energy:131.913  channel:608  run:9772
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 797  0.972633 -0.00025  165.914136      640       1          0   1       0
#
#       run  wfDCBits
# 797  9772         0
# AvsE:-0.021  DCR:-0.00044  Energy:165.920  channel:640  run:9772
#         AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 811  1.02408  0.00008  962.050696      598       1          0   1       0
#
#       run  wfDCBits
# 811  9774         0
# AvsE:1.705  DCR:-0.00028  Energy:961.871  channel:598  run:9774
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 818  0.981245 -0.000048  272.309857      690       1          0   1       0
#
#       run  wfDCBits
# 818  9775         0
# AvsE:0.035  DCR:-0.00021  Energy:272.650  channel:690  run:9775
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 841  0.991082 -0.000215  137.292211      580       1          0   1       0
#
#       run  wfDCBits
# 841  9779         0
# AvsE:1.013  DCR:-0.00044  Energy:137.368  channel:580  run:9779
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 854  0.991816 -0.000021  134.05638      608       1          0   1       0
#
#       run  wfDCBits
# 854  9817         0
# AvsE:0.467  DCR:-0.00033  Energy:134.225  channel:608  run:9817
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 860  0.918518 -0.000208  244.008609      608       1          0   1       0
#
#       run  wfDCBits
# 860  9818         0
# AvsE:-0.990  DCR:-0.00049  Energy:244.175  channel:608  run:9818
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 862  0.923209 -0.000097  256.022319      648       1          0   1       0
#
#       run  wfDCBits
# 862  9819         0
# AvsE:-0.838  DCR:-0.00093  Energy:256.229  channel:648  run:9819
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 884  0.945672 -0.000185  207.853423      648       1          0   1       0
#
#       run  wfDCBits
# 884  9824         0
# AvsE:-0.631  DCR:-0.00103  Energy:208.029  channel:648  run:9824
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 887  1.03673  0.000088  752.209328      598       1          0   1       0
#
#       run  wfDCBits
# 887  9824         0
# AvsE:2.324  DCR:-0.00020  Energy:752.094  channel:598  run:9824
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 891  1.007445  0.000027  1163.907648      598       1          0   1       0
#
#       run  wfDCBits
# 891  9826         0
# AvsE:0.162  DCR:-0.00031  Energy:1163.458  channel:598  run:9826
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 892  1.011973  0.000018  798.949637      672       1          0   1       0
#
#       run  wfDCBits
# 892  9826         0
# AvsE:0.170  DCR:-0.00010  Energy:799.298  channel:672  run:9826
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 914  1.011775  0.000096  156.407971      598       1          0   1       0
#
#       run  wfDCBits
# 914  9828         0
# AvsE:0.322  DCR:-0.00013  Energy:156.519  channel:598  run:9828
#          AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 921  1.003953  0.000013  820.47461      598       1          0   1       0
#
#       run  wfDCBits
# 921  9830         0
# AvsE:-0.092  DCR:-0.00034  Energy:820.320  channel:598  run:9830
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 927  0.975462 -0.000029  264.191772      598       1          0   1       0
#
#       run  wfDCBits
# 927  9831         0
# AvsE:-0.588  DCR:-0.00024  Energy:264.413  channel:598  run:9831
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 931  0.997608 -0.000167  353.667981      580       1          0   1       0
#
#       run  wfDCBits
# 931  9831         0
# AvsE:0.866  DCR:-0.00042  Energy:353.726  channel:580  run:9831
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 933  1.013385  0.000068  1074.317508      598       1          0   1       0
#
#       run  wfDCBits
# 933  9831         0
# AvsE:0.789  DCR:-0.00030  Energy:1073.917  channel:598  run:9831
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 937  0.972171 -0.000242  188.523426      608       1          0   1       0
#
#       run  wfDCBits
# 937  9832         0
# AvsE:0.315  DCR:-0.00054  Energy:188.687  channel:608  run:9832
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 941  0.999434 -0.000187  128.611964      640       1          0   1       0
#
#       run  wfDCBits
# 941  9848         0
# AvsE:0.034  DCR:-0.00041  Energy:128.768  channel:640  run:9848
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 948  1.094554  0.000006  1115.800147      690       1          0   1       0
#
#       run  wfDCBits
# 948  9849         0
# AvsE:22.782  DCR:-0.00016  Energy:1116.295  channel:690  run:9849
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 958  0.972375 -0.000306  149.321113      626       1          0   1       0
#
#       run  wfDCBits
# 958  9851         0
# AvsE:0.235  DCR:-0.00042  Energy:149.479  channel:626  run:9851
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 962  0.999817 -0.00034  496.689458      626       1          0   1       0
#
#       run  wfDCBits
# 962  9852         0
# AvsE:0.115  DCR:-0.00047  Energy:496.452  channel:626  run:9852
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 972  0.994383 -0.000127  177.319223      592       1          0   1       0
#
#       run  wfDCBits
# 972  9854         0
# AvsE:-0.076  DCR:-0.00056  Energy:177.523  channel:592  run:9854
#          AvsE      DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 978  0.992424 -0.00058  788.35176      626       1          0   1       0
#
#       run  wfDCBits
# 978  9857         0
# AvsE:-0.572  DCR:-0.00072  Energy:788.005  channel:626  run:9857
# Untagged - run: 9858  channel: 578  Energy: 183.509  AvsE: 0.691  DCR: -0.00011 LocalTime: 786.86
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 981  0.998441  0.000005  576.331286      582       1          0   1       0
#
#       run  wfDCBits
# 981  9858         0
# AvsE:-0.333  DCR:-0.00019  Energy:576.249  channel:582  run:9858
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 990  0.996193 -0.000301  660.544347      580       1          0   1       0
#
#       run  wfDCBits
# 990  9860         0
# AvsE:-0.327  DCR:-0.00051  Energy:660.712  channel:580  run:9860
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 995  0.948975 -0.000141  112.533623      578       1          0   1       0
#
#       run  wfDCBits
# 995  9861         0
# AvsE:0.501  DCR:-0.00032  Energy:112.632  channel:578  run:9861
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1011  0.931831 -0.000189  193.438428      664       1          0   1       0
#
#        run  wfDCBits
# 1011  9864         0
# AvsE:-0.535  DCR:-0.00041  Energy:193.733  channel:664  run:9864
#           AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1020  0.914498 -0.00005  125.460876      610       1          0   1       0
#
#        run  wfDCBits
# 1020  9867         0
# AvsE:-0.468  DCR:-0.00018  Energy:125.722  channel:610  run:9867
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1025  0.965739 -0.000209  120.44998      592       1          0   1       0
#
#        run  wfDCBits
# 1025  9868         0
# AvsE:-0.161  DCR:-0.00065  Energy:120.570  channel:592  run:9868
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1032  0.997743 -0.000242  439.924777      578       1          0   1       0
#
#        run  wfDCBits
# 1032  9869         0
# AvsE:0.209  DCR:-0.00038  Energy:440.099  channel:578  run:9869
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1039  1.008975  0.000125  1325.522466      690       1          0   1       0
#
#        run  wfDCBits
# 1039  9870         0
# AvsE:2.070  DCR:-0.00006  Energy:1325.571  channel:690  run:9870
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1054  0.987564 -0.000195  164.501285      626       1          0   1       0
#
#        run  wfDCBits
# 1054  9873         0
# AvsE:0.354  DCR:-0.00033  Energy:164.653  channel:626  run:9873
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1061  1.005551  0.000018  510.793489      690       1          0   1       0
#
#        run  wfDCBits
# 1061  9874         0
# AvsE:1.426  DCR:-0.00016  Energy:511.010  channel:690  run:9874
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1071  0.997066 -0.000056  118.014013      598       1          0   1       0
#
#        run  wfDCBits
# 1071  9876         0
# AvsE:0.149  DCR:-0.00026  Energy:118.071  channel:598  run:9876
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1074  0.970846 -0.000127  718.208795      592       1          0   1       0
#
#        run  wfDCBits
# 1074  9876         0
# AvsE:-0.788  DCR:-0.00073  Energy:717.886  channel:592  run:9876
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1079  0.998366 -0.000182  327.205958      626       1          0   1       0
#
#        run  wfDCBits
# 1079  9878         0
# AvsE:0.265  DCR:-0.00038  Energy:327.203  channel:626  run:9878
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1082  0.998113 -0.000097  154.041356      672       1          0   1       0
#
#        run  wfDCBits
# 1082  9879         0
# AvsE:0.310  DCR:-0.00016  Energy:154.431  channel:672  run:9879
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1090  1.012099  0.000164  1144.469908      632       1          0   1       0
#
#        run  wfDCBits
# 1090  9881         0
# AvsE:-0.027  DCR:-0.00015  Energy:1144.253  channel:632  run:9881
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1104  0.991627 -0.000524  947.940011      626       1          0   1       0
#
#        run  wfDCBits
# 1104  9885         0
# AvsE:-0.847  DCR:-0.00069  Energy:947.508  channel:626  run:9885
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1108  0.954112 -0.000334  129.416476      580       1          0   1       0
#
#        run  wfDCBits
# 1108  9885         0
# AvsE:0.190  DCR:-0.00051  Energy:129.520  channel:580  run:9885
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1114  0.903662 -0.000214  231.931411      608       1          0   1       0
#
#        run  wfDCBits
# 1114  9886         0
# AvsE:-0.760  DCR:-0.00047  Energy:232.019  channel:608  run:9886
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1117  0.98237 -0.000162  166.655529      626       1          0   1       0
#
#        run  wfDCBits
# 1117  9887         0
# AvsE:0.308  DCR:-0.00032  Energy:166.572  channel:626  run:9887
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1126  0.948692 -0.000223  166.994961      578       1          0   1       0
#
#        run  wfDCBits
# 1126  9888         0
# AvsE:0.198  DCR:-0.00038  Energy:167.301  channel:578  run:9888
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1130  0.991361 -0.000441  505.033827      626       1          0   1       0
#
#        run  wfDCBits
# 1130  9890         0
# AvsE:-0.181  DCR:-0.00057  Energy:504.846  channel:626  run:9890
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1135  0.994441 -0.000082  633.147105      578       1          0   1       0
#
#        run  wfDCBits
# 1135  9890         0
# AvsE:-0.245  DCR:-0.00020  Energy:633.363  channel:578  run:9890
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1136  0.995218 -0.000084  461.457875      578       1          0   1       0
#
#        run  wfDCBits
# 1136  9891         0
# AvsE:0.104  DCR:-0.00023  Energy:461.507  channel:578  run:9891
#          AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1161  0.81576 -0.000167  199.510047      592       1          0   1       0
#
#        run  wfDCBits
# 1161  9896         0
# AvsE:-0.717  DCR:-0.00065  Energy:199.603  channel:592  run:9896
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1162  0.988527 -0.000133  216.696362      598       1          0   1       0
#
#        run  wfDCBits
# 1162  9896         0
# AvsE:-0.147  DCR:-0.00035  Energy:216.786  channel:598  run:9896
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1173  1.013029  0.000072  548.621429      592       1          0   1       0
#
#        run  wfDCBits
# 1173  9898         0
# AvsE:0.067  DCR:-0.00046  Energy:548.599  channel:592  run:9898
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1174  0.994054 -0.000411  633.500015      626       1          0   1       0
#
#        run  wfDCBits
# 1174  9898         0
# AvsE:-0.279  DCR:-0.00056  Energy:633.299  channel:626  run:9898
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1177  0.963143 -0.000103  312.272088      608       1          0   1       0
#
#        run  wfDCBits
# 1177  9898         0
# AvsE:-0.724  DCR:-0.00035  Energy:312.382  channel:608  run:9898
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1179  0.990549 -0.000375  629.700002      626       1          0   1       0
#
#        run  wfDCBits
# 1179  9899         0
# AvsE:-0.412  DCR:-0.00059  Energy:629.374  channel:626  run:9899
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1183  0.967329 -0.000188  121.275127      608       1          0   1       0
#
#        run  wfDCBits
# 1183  9899         0
# AvsE:0.395  DCR:-0.00051  Energy:121.370  channel:608  run:9899
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1198  0.850932 -0.000172  181.938561      648       1          0   1       0
#
#        run  wfDCBits
# 1198  9902         0
# AvsE:-0.965  DCR:-0.00103  Energy:182.126  channel:648  run:9902
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1204  0.996336 -0.000124  766.032875      632       1          0   1       0
#
#        run  wfDCBits
# 1204  9904         0
# AvsE:-0.070  DCR:-0.00042  Energy:766.063  channel:632  run:9904
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1210  0.9837 -0.000146  191.704436      592       1          0   1       0
#
#        run  wfDCBits
# 1210  9904         0
# AvsE:-0.234  DCR:-0.00061  Energy:191.740  channel:592  run:9904
#           AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1227  0.993065 -0.00024  241.633153      592       1          0   1       0
#
#        run  wfDCBits
# 1227  9908         0
# AvsE:-0.133  DCR:-0.00068  Energy:241.754  channel:592  run:9908
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1230  1.011554  0.000026  1293.307773      598       1          0   1       0
#
#        run  wfDCBits
# 1230  9908         0
# AvsE:0.638  DCR:-0.00036  Energy:1293.051  channel:598  run:9908
#          AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1240  1.00178  0.000039  1658.329124      582       1          0   1       0
#
#        run  wfDCBits
# 1240  9911         0
# AvsE:0.060  DCR:-0.00011  Energy:1657.754  channel:582  run:9911
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1244  1.175432  0.000037  128.095885      626       1          0   1       0
#
#        run  wfDCBits
# 1244  9911         0
# AvsE:2.031  DCR:-0.00014  Energy:128.204  channel:626  run:9911
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1249  0.998339 -0.000682  1184.796321      626       1          0   1       0
#
#        run  wfDCBits
# 1249  9911         0
# AvsE:-0.650  DCR:-0.00086  Energy:1184.360  channel:626  run:9911
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1251  1.037586  0.000167  1550.774037      580       1          0   1       0
#
#        run  wfDCBits
# 1251  9912         0
# AvsE:7.155  DCR:-0.00006  Energy:1549.915  channel:580  run:9912
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1258  0.990706 -0.000067  149.106993      610       1          0   1       0
#
#        run  wfDCBits
# 1258  9928         0
# AvsE:0.428  DCR:-0.00024  Energy:149.393  channel:610  run:9928
#          AvsE     DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 1263  0.99094 -0.0003  347.354441      626       1          0   1       0
#
#        run  wfDCBits
# 1263  9953         0
# AvsE:0.060  DCR:-0.00043  Energy:347.579  channel:626  run:9953
# ...
# 7295  1.003252  0.000193  1507.519216      648       1          0   1       0
#
#         run  wfDCBits
# 7295  13281         0
# AvsE:-0.748  DCR:-0.00065  Energy:1507.340  channel:648  run:13281
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7298  0.627827 -0.000197  188.331668      592       1          0   1       0
#
#         run  wfDCBits
# 7298  13282         0
# AvsE:-0.951  DCR:-0.00069  Energy:188.473  channel:592  run:13282
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7300  0.971954 -0.000083  330.19535      640       1          0   1       0
#
#         run  wfDCBits
# 7300  13282         0
# AvsE:-0.131  DCR:-0.00073  Energy:330.256  channel:640  run:13282
#          AvsE      DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7301  1.00385  0.00003  1243.160402      648       1          0   1       0
#
#         run  wfDCBits
# 7301  13282         0
# AvsE:-0.753  DCR:-0.00081  Energy:1243.082  channel:648  run:13282
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7316  0.949383 -0.000389  295.935752      626       1          0   1       0
#
#         run  wfDCBits
# 7316  13286         0
# AvsE:-0.345  DCR:-0.00034  Energy:296.020  channel:626  run:13286
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7317  0.999746 -0.000261  132.560749      626       1          0   1       0
#
#         run  wfDCBits
# 7317  13286         0
# AvsE:0.774  DCR:-0.00032  Energy:132.595  channel:626  run:13286
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7319  0.986516 -0.000119  136.50199      578       1          0   1       0
#
#         run  wfDCBits
# 7319  13286         0
# AvsE:0.475  DCR:-0.00029  Energy:136.711  channel:578  run:13286
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7334  0.993364 -0.000932  788.550393      626       1          0   1       0
#
#         run  wfDCBits
# 7334  13306         0
# AvsE:0.536  DCR:-0.00042  Energy:788.740  channel:626  run:13306
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7379  0.893789 -0.000282  213.135007      608       1          0   1       0
#
#         run  wfDCBits
# 7379  13313         0
# AvsE:-0.829  DCR:-0.00054  Energy:213.281  channel:608  run:13313
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7382  0.974593 -0.000198  102.026244      648       1          0   1       0
#
#         run  wfDCBits
# 7382  13313         0
# AvsE:0.053  DCR:-0.00096  Energy:102.230  channel:648  run:13313
#           AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7383  1.004221  0.00018  727.287796      608       1          0   1       0
#
#         run  wfDCBits
# 7383  13314         0
# AvsE:-0.079  DCR:-0.00009  Energy:727.376  channel:608  run:13314
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7385  1.010748  0.000029  1470.859531      610       1          0   1       0
#
#         run  wfDCBits
# 7385  13314         0
# AvsE:0.883  DCR:-0.00017  Energy:1470.519  channel:610  run:13314
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7397  0.998549 -0.000108  543.733805      582       1          0   1       0
#
#         run  wfDCBits
# 7397  13316         0
# AvsE:0.143  DCR:-0.00036  Energy:543.534  channel:582  run:13316
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7404  1.005763  0.000003  139.784391      598       1          0   1       0
#
#         run  wfDCBits
# 7404  13316         0
# AvsE:0.422  DCR:-0.00029  Energy:140.069  channel:598  run:13316
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7410  1.006315  0.000045  287.055198      598       1          0   1       0
#
#         run  wfDCBits
# 7410  13317         0
# AvsE:0.355  DCR:-0.00029  Energy:287.228  channel:598  run:13317
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7413  0.999873 -0.000085  674.017982      580       1          0   1       0
#
#         run  wfDCBits
# 7413  13317         0
# AvsE:0.607  DCR:-0.00029  Energy:674.020  channel:580  run:13317
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7424  0.999478 -0.000185  543.010395      580       1          0   1       0
#
#         run  wfDCBits
# 7424  13319         0
# AvsE:0.210  DCR:-0.00042  Energy:543.112  channel:580  run:13319
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7426  0.997623 -0.000199  623.824091      580       1          0   1       0
#
#         run  wfDCBits
# 7426  13320         0
# AvsE:0.137  DCR:-0.00039  Energy:623.937  channel:580  run:13320
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7429  1.001758  0.000017  792.594393      578       1          0   1       0
#
#         run  wfDCBits
# 7429  13320         0
# AvsE:0.309  DCR:-0.00018  Energy:792.382  channel:578  run:13320
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7431  0.978228 -0.000552  512.876535      626       1          0   1       0
#
#         run  wfDCBits
# 7431  13320         0
# AvsE:0.001  DCR:-0.00028  Energy:513.048  channel:626  run:13320
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7432  0.991708 -0.000773  877.655783      626       1          0   1       0
#
#         run  wfDCBits
# 7432  13320         0
# AvsE:0.413  DCR:-0.00016  Energy:877.859  channel:626  run:13320
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7437  0.837112 -0.000207  190.846704      592       1          0   1       0
#
#         run  wfDCBits
# 7437  13321         0
# AvsE:-0.441  DCR:-0.00072  Energy:191.044  channel:592  run:13321
#           AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7448  0.937816 -0.00002  196.564498      690       1          0   1       0
#
#         run  wfDCBits
# 7448  13324         0
# AvsE:-0.891  DCR:-0.00034  Energy:196.787  channel:690  run:13324
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7458  0.995997 -0.000336  455.190495      632       1          0   1       0
#
#         run  wfDCBits
# 7458  13326         0
# AvsE:0.480  DCR:-0.00053  Energy:455.274  channel:632  run:13326
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7459  0.989716 -0.000293  131.79687      580       1          0   1       0
#
#         run  wfDCBits
# 7459  13326         0
# AvsE:1.361  DCR:-0.00045  Energy:131.938  channel:580  run:13326
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7460  0.994481 -0.000215  136.450764      608       1          0   1       0
#
#         run  wfDCBits
# 7460  13326         0
# AvsE:0.853  DCR:-0.00045  Energy:136.538  channel:608  run:13326
#           AvsE      DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7463  1.006161  0.00009  1222.721189      690       1          0   1       0
#
#         run  wfDCBits
# 7463  13327         0
# AvsE:-0.254  DCR:-0.00038  Energy:1223.065  channel:690  run:13327
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7467  0.986732 -0.001397  1429.675056      626       1          0   1       0
#
#         run  wfDCBits
# 7467  13327         0
# AvsE:-0.209  DCR:-0.00028  Energy:1429.868  channel:626  run:13327
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7473  0.975687 -0.000145  156.720817      640       1          0   1       0
#
#         run  wfDCBits
# 7473  13327         0
# AvsE:0.126  DCR:-0.00076  Energy:156.767  channel:640  run:13327
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7481  0.970374 -0.000155  175.254628      580       1          0   1       0
#
#         run  wfDCBits
# 7481  13329         0
# AvsE:1.522  DCR:-0.00037  Energy:175.331  channel:580  run:13329
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7486  0.982583 -0.000382  215.463848      608       1          0   1       0
#
#         run  wfDCBits
# 7486  13330         0
# AvsE:0.459  DCR:-0.00064  Energy:215.521  channel:608  run:13330
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7488  0.999578 -0.000205  145.101723      664       1          0   1       0
#
#         run  wfDCBits
# 7488  13330         0
# AvsE:0.180  DCR:-0.00051  Energy:145.215  channel:664  run:13330
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7494  1.003256  0.000004  717.74776      582       1          0   1       0
#
#         run  wfDCBits
# 7494  13332         0
# AvsE:0.327  DCR:-0.00026  Energy:717.535  channel:582  run:13332
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7496  0.988113 -0.000047  294.913982      578       1          0   1       0
#
#         run  wfDCBits
# 7496  13332         0
# AvsE:0.232  DCR:-0.00018  Energy:295.191  channel:578  run:13332
#           AvsE      DCR    Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7537  0.979451 -0.00001  621.6475      672       1          0   1       0
#
#         run  wfDCBits
# 7537  13340         0
# AvsE:-0.985  DCR:-0.00015  Energy:621.891  channel:672  run:13340
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7538  0.989306 -0.000724  625.042024      626       1          0   1       0
#
#         run  wfDCBits
# 7538  13340         0
# AvsE:0.369  DCR:-0.00032  Energy:625.275  channel:626  run:13340
#          AvsE      DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7540  0.98542 -0.00106  1187.654171      626       1          0   1       0
#
#         run  wfDCBits
# 7540  13340         0
# AvsE:-0.200  DCR:-0.00020  Energy:1187.682  channel:626  run:13340
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7550  0.989751 -0.000212  175.738583      632       1          0   1       0
#
#         run  wfDCBits
# 7550  13342         0
# AvsE:0.575  DCR:-0.00040  Energy:175.844  channel:632  run:13342
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7552  0.976906 -0.000102  296.503201      592       1          0   1       0
#
#         run  wfDCBits
# 7552  13342         0
# AvsE:-0.248  DCR:-0.00063  Energy:296.550  channel:592  run:13342
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7554  1.010321  0.000145  710.082399      690       1          0   1       0
#
#         run  wfDCBits
# 7554  13342         0
# AvsE:0.353  DCR:-0.00029  Energy:710.449  channel:690  run:13342
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7555  0.989546 -0.001139  1116.16179      626       1          0   1       0
#
#         run  wfDCBits
# 7555  13342         0
# AvsE:0.185  DCR:-0.00026  Energy:1116.324  channel:626  run:13342
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7564  0.990871 -0.000133  1007.437995      592       1          0   1       0
#
#         run  wfDCBits
# 7564  13344         0
# AvsE:-0.785  DCR:-0.00071  Energy:1006.575  channel:592  run:13344
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7569  1.007437  0.000026  958.172446      610       1          0   1       0
#
#         run  wfDCBits
# 7569  13345         0
# AvsE:0.118  DCR:-0.00017  Energy:957.961  channel:610  run:13345
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7570  1.052132  0.000048  2015.132311      580       1          0   1       0
#
#         run  wfDCBits
# 7570  13345         0
# AvsE:14.821  DCR:-0.00021  Energy:2013.757  channel:580  run:13345
#          AvsE      DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7580  1.20459  0.00001  654.043871      672       1          0   1       0
#
#         run  wfDCBits
# 7580  13346         0
# AvsE:9.414  DCR:-0.00017  Energy:654.764  channel:672  run:13346
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7581  1.009546  0.000047  828.635115      610       1          0   1       0
#
#         run  wfDCBits
# 7581  13347         0
# AvsE:0.371  DCR:-0.00013  Energy:828.668  channel:610  run:13347
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7588  0.989766 -0.000784  633.624716      626       1          0   1       0
#
#         run  wfDCBits
# 7588  13348         0
# AvsE:0.388  DCR:-0.00037  Energy:633.840  channel:626  run:13348
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7594  0.699235 -0.000147  127.710189      592       1          0   1       0
#
#         run  wfDCBits
# 7594  13349         0
# AvsE:-0.410  DCR:-0.00068  Energy:127.838  channel:592  run:13349
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7612  1.005989  0.000129  1187.577673      690       1          0   1       0
#
#         run  wfDCBits
# 7612  13363         0
# AvsE:-0.277  DCR:-0.00035  Energy:1187.800  channel:690  run:13363
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7615  0.938247 -0.000226  161.305648      608       1          0   1       0
#
#         run  wfDCBits
# 7615  13363         0
# AvsE:-0.186  DCR:-0.00054  Energy:161.390  channel:608  run:13363
#           AvsE       DCR    Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7616  0.985193 -0.000348  300.3119      626       1          0   1       0
#
#         run  wfDCBits
# 7616  13363         0
# AvsE:0.450  DCR:-0.00030  Energy:300.597  channel:626  run:13363
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7622  0.951505 -0.000259  200.173149      608       1          0   1       0
#
#         run  wfDCBits
# 7622  13364         0
# AvsE:0.089  DCR:-0.00052  Energy:200.262  channel:608  run:13364
#         AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7624  0.9797 -0.000346  330.423991      626       1          0   1       0
#
#         run  wfDCBits
# 7624  13364         0
# AvsE:0.286  DCR:-0.00025  Energy:330.688  channel:626  run:13364
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7628  0.995793 -0.000193  279.854012      578       1          0   1       0
#
#         run  wfDCBits
# 7628  13365         0
# AvsE:0.457  DCR:-0.00033  Energy:280.018  channel:578  run:13365
#           AvsE       DCR      Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7633  0.993037 -0.000205  320.997147      592       1          0   1       0
#
#         run  wfDCBits
# 7633  13366         0
# AvsE:-0.156  DCR:-0.00071  Energy:321.272  channel:592  run:13366
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7635  1.007227  0.000118  1033.680718      690       1          0   1       0
#
#         run  wfDCBits
# 7635  13366         0
# AvsE:-0.089  DCR:-0.00029  Energy:1034.074  channel:690  run:13366
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7641  1.011192  0.000028  1062.346574      672       1          0   1       0
#
#         run  wfDCBits
# 7641  13368         0
# AvsE:0.337  DCR:-0.00014  Energy:1062.778  channel:672  run:13368
#           AvsE       DCR     Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7643  1.005463  0.000058  894.97587      690       1          0   1       0
#
#         run  wfDCBits
# 7643  13368         0
# AvsE:-0.176  DCR:-0.00037  Energy:895.115  channel:690  run:13368
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 682   DCR: 252  Burst: 33
# Total swapped:  967
# Total mismatch:  14

# %%
graph = sns.JointGrid(x=np.array(energyList2), y=np.array(runList2), size=10, space=0.2)
graph.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph.x = np.array(energyList)
graph.y = np.array(runList)
graph.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph.ax_marg_y.set_axis_off()
_ = graph.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph.savefig('EventComparison_DS1.pdf')

# %%
graph2 = sns.JointGrid(x=np.array(energyList2), y=np.array(chList2), size=10, space=0.2)
graph2.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph2.x = np.array(energyList)
graph2.y = np.array(chList)
graph2.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph2.ax_marg_y.set_axis_off()
_ = graph2.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph2.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph2.set_axis_labels("Energy", "Channel", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph2.savefig('EventComparison_DS1_2.pdf')

# %%
graph3 = sns.JointGrid(x=np.array(energyListCut), y=np.array(runListCut), size=10, space=0.2)
graph3.plot_joint(plt.scatter, color='b', marker='x', label='Pass all cuts in new skim -- rejected in old skim')
graph3.x = np.array(energyListCut2)
graph3.y = np.array(runListCut2)
graph3.plot_joint(plt.scatter, color='r', marker='v', label='Pass all cuts in old skim -- rejected in new skim')
graph3.ax_marg_y.set_axis_off()
_ = graph3.ax_marg_x.hist(np.array(energyListCut), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph3.ax_marg_x.hist(np.array(energyListCut2), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph3.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph3.savefig('EventCutComparison_DS1_2.pdf')

# %%
# Specific study for ROI
# Cut events in old but not in new for ROI
nCutROI1,nSwapROI1 = 0,0
chListCutROI1 = []
runListCutROI1 = []
energyListCutROI1 = []
nDC, nMu, nLN, nAvsE, nDCR = 0, 0, 0, 0, 0
for index, row in dfOldCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 2000 or row['Energy'] > 2200:
        continue
    if not dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        print 'Tagged',dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        continue
#     elif not dfNewCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
#         continue
#     elif row['channel'] == 594:
#         continue
    elif not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy','LocalTime'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values != 0 or dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= -1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'Swapped -- AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        nSwapROI1 += 1
        chListCutROI1.append(row['channel'])
        runListCutROI1.append(row['run'])
        energyListCutROI1.append(row['Energy'])        
        continue
#     elif row['run'] in dfNewCut['run'].values and row['channel'] in dfNewCut['channel'].values:
    else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'])

        nCutROI1 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d"%(nLN, nMu, nDC, nAvsE, nDCR)
print "Total swapped: ", nSwapROI1
print "Total mismatch: ", nCutROI1
# Out:
# Tagged         AvsE   ClockTime      DCR                 Date       DateSec  \
# 65  0.831066  486.961264 -0.00031  2016-01-14 02:11:29  1.452737e+09
#
#          Energy   LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 65  2115.667791  485.696195  2113.916807      610    5254       1          0
#
#     isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 65          0   1    1       0  9472         0
# Tagged          AvsE    ClockTime       DCR                 Date       DateSec  \
# 164  4.322209  1542.481931 -0.000296  2016-01-15 07:30:18  1.452843e+09
#
#           Energy   LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 164  2083.352154  1541.57835  2086.481001      582   14210       1          0
#
#      isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 164          0   1    1       0  9544         0
# Tagged          AvsE    ClockTime       DCR                 Date       DateSec  \
# 1826  1.92981  1074.323333 -0.000396  2016-02-12 14:12:03  1.455286e+09
#
#            Energy    LocalTime      OEnergy  channel  iEvent  isGood  \
# 1826  2167.108407  1070.913101  2167.544362      582    8717       1
#
#       isLNFill1  isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 1826          0          0   1    1       0  10614         0
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 2967 -1.444929 -0.000418  2118.99211      632    2091       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 2967          0   1    1       0  10712         0
# Swapped -- AvsE:1.001  DCR:-0.00010  Energy:2119.479  channel:632  run:10712
# Untagged - run: 12576  channel: 608  Energy: 2116.310  AvsE: 1.009  DCR: -0.00011
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 1   DCR: 0
# Total swapped:  1
# Total mismatch:  1

# %%
# Specific study for ROI
# Cut events not rejected in new skim in ROI
nCutROI2,nSwapROI2 = 0,0
chListCutROI2 = []
runListCutROI2 = []
energyListCutROI2 = []
nDC, nMu, nLN, nAvsE, nDCR, nBurst = 0, 0, 0, 0, 0, 0
for index, row in dfNewCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 2000 or row['Energy'] > 2200:
        continue
    if not dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        print 'Tagged',dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        continue
#     elif not dfOldCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
#         continue
#     elif row['channel'] == 594:
#         continue
    elif not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        print dfTemp.drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        if 7370e3<dfTemp['ClockTime'].values<7371e3 or 2192e3<dfTemp['ClockTime'].values<2195e3 or 7840e3<dfTemp['ClockTime'].values<7860e3:
            nBurst += 1
        elif 8384e3<dfTemp['ClockTime'].values<8387e3 or 8984e3<dfTemp['ClockTime'].values<8985e3 or 9002e3<dfTemp['ClockTime'].values<9005e3:
            nBurst += 1
        elif dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= 1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'Swapped -- AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCutROI2.append(row['channel'])
        runListCutROI2.append(row['run'])
        energyListCutROI2.append(row['Energy'])
        nSwapROI2 += 1
        continue
#     elif row['run'] in dfOldCut['run'].values and row['channel'] in dfOldCut['channel'].values:
    else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCutROI2 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d  Burst: %d"%(nLN, nMu, nDC, nAvsE, nDCR, nBurst)
print "Total swapped: ", nSwapROI2
print "Total mismatch: ", nCutROI2
# Out:
# Tagged         AvsE     ClockTime     DCR                 Date       DateSec  \
# 48  1.008293  1.765979e+06 -0.0002  2016-02-03 12:36:22  1.454503e+09
#
#         Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 48  2116.66422  2114.141063      610       1          0   1       0  9472
#
#     wfDCBits
# 48         0
# Tagged          AvsE     ClockTime       DCR                 Date       DateSec  \
# 132  1.029238  1.871507e+06 -0.000122  2016-02-05 22:56:24  1.454713e+09
#
#           Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 132  2082.581969  2085.885625      582       1          0   1       0  9544
#
#      wfDCBits
# 132         0
# Tagged           AvsE     ClockTime      DCR                 Date       DateSec  \
# 1564  1.006712  4.314815e+06 -0.00023  2016-04-02 12:27:48  1.459600e+09
#
#            Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto    run  \
# 1564  2167.128093  2166.833404      582       1          0   1       0  10614
#
#       wfDCBits
# 1564         0
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7570  1.052132  0.000048  2015.132311      580       1          0   1       0
#
#         run  wfDCBits
# 7570  13345         0
# Swapped -- AvsE:14.821  DCR:-0.00021  Energy:2013.757  channel:580  run:13345
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 0   DCR: 1  Burst: 0
# Total swapped:  1
# Total mismatch:  0

# %%
print dfOldCut.query('run==12576 and 2000<Energy<2200 and channel==608')
print dfNewFull.query('run==12576 and 2000<Energy<2200 and channel==608')
# Out:
#           AvsE     ClockTime       DCR                 Date       DateSec  \
# 3142  1.008654  7.452911e+06 -0.000107  2016-06-14 03:54:41  1.465876e+09
#
#            Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto    run  \
# 3142  2116.309623  2114.295972      608       1          0   1       0  12576
#
#       wfDCBits
# 3142         0
# Empty DataFrame
# Columns: [AvsE, ClockTime, DCR, Date, DateSec, Energy, LocalTime, OEnergy, channel, iEvent, isGood, isLNFill1, isLNFill2, mH, mHL, muVeto, run, wfDCBits]
# Index: []

# %%
#bins=np.linspace(100, 3300, 80)
fig = plt.figure(figsize=(12,7))
# plt.hist(energyListCut, bins=np.linspace(100, 3300, 80), label='Total Mismatch')
plt.hist(energyListCutAvsE, bins=np.linspace(100, 3300, 80), alpha=0.5, label='AvsE Difference')
plt.hist(energyListCutDCR, bins=np.linspace(100, 3300, 80), alpha=0.5, label='DCR Difference')
plt.title('')
plt.xlim(0, 3000)
plt.xlabel('Energy (keV)')
plt.ylabel('Counts/40 keV')
plt.legend()
fig.savefig('ResidualContribution.pdf')
