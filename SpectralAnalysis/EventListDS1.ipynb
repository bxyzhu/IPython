# %%
# Event list comparison
import numpy as np
import pandas as pd

# pd.options.display.max_rows = 999

import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load files
extDir = '/Users/brianzhu/macros/code/MJDAnalysis/ROI/'
dfNew = pd.read_csv(extDir+'NewList_DS1_full.csv', sep=',', index_col=0)
dfOld = pd.read_csv(extDir+'OldList_DS1_full.csv', sep=',', index_col=0)

dfNewCut = pd.read_csv(extDir+'NewList_DS1_allcuts.csv', sep=',', index_col=0)
dfOldCut = pd.read_csv(extDir+'OldList_DS1_allcuts.csv', sep=',', index_col=0)

dfNewFull = pd.read_csv(extDir+'NewList_DS1_nocuts.csv', sep=',', index_col=0)
dfOldFull = pd.read_csv(extDir+'OldList_DS1_nocuts.csv', sep=',', index_col=0)

# %%
print dfNewFull.shape[0], dfNew.shape[0],dfNewCut.shape[0]
dfNewCut.head(10)
# Out:
# 9168 7824 6040
#        AvsE    ClockTime       DCR                 Date       DateSec  \
# 0  0.769360   165.767291 -0.000446  2016-01-13 00:01:08  1.452643e+09
# 1 -0.943519  1013.883899 -0.000497  2016-01-13 00:15:16  1.452644e+09
# 2  0.577846  1501.896750 -0.000252  2016-01-13 00:23:24  1.452645e+09
# 3 -0.023669  2691.145105 -0.000268  2016-01-13 00:43:13  1.452646e+09
# 4  0.949993  3336.091204 -0.000515  2016-01-13 00:53:58  1.452646e+09
# 5 -0.058129    26.145518 -0.000680  2016-01-13 00:58:51  1.452647e+09
# 6 -0.097852   839.703435 -0.000263  2016-01-13 01:12:25  1.452648e+09
# 7  2.677843  2071.086478 -0.000617  2016-01-13 01:32:56  1.452649e+09
# 8  0.496272  1551.978874 -0.000314  2016-01-13 02:27:38  1.452652e+09
# 9  1.108503  1727.785983 -0.000422  2016-01-13 02:30:34  1.452652e+09
#
#         Energy    LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 0   144.066708   164.566803   144.488413      664    2565       1          0
# 1   177.416239  1012.683410   177.535115      608   15795       1          0
# 2   914.400994  1500.696262   913.890484      598   23312       1          0
# 3  1253.466911  2689.944616  1254.303897      610   41774       1          0
# 4   267.134944  3334.890715   266.824089      632   51747       1          0
# 5   167.989804    23.852981   167.888488      592     208       1          0
# 6  1229.556965   837.410898  1227.366421      632    7451       1          0
# 7   992.519728  2068.793940   993.430127      626   22101       1          0
# 8   802.585536  1548.505728   802.187466      640   16324       1          0
# 9   780.439510  1724.312836   779.957278      632   18476       1          0
#
#    isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 0          0   1    1       0  9422         0
# 1          0   1    1       0  9422         0
# 2          0   1    1       0  9422         0
# 3          0   1    1       0  9422         0
# 4          0   1    1       0  9422         0
# 5          0   1    1       0  9423         0
# 6          0   1    1       0  9423         0
# 7          0   1    1       0  9423         0
# 8          0   1    1       0  9425         0
# 9          0   1    1       0  9425         0

# %%
print dfOldFull.shape[0], dfOld.shape[0],dfOldCut.shape[0]
dfOld.head(10)
# Out:
# 17660 7647 4864
#        AvsE     ClockTime       DCR                 Date       DateSec  \
# 0  1.065350  1.671758e+06 -0.000253  2016-02-01 08:21:01  1.454315e+09
# 1  0.938456  1.672541e+06 -0.000131  2016-02-01 08:34:04  1.454316e+09
# 2  0.894826  1.672606e+06 -0.000245  2016-02-01 08:35:09  1.454316e+09
# 3  1.011895  1.673094e+06  0.000075  2016-02-01 08:43:17  1.454316e+09
# 4  1.030725  1.673134e+06 -0.000020  2016-02-01 08:43:57  1.454316e+09
# 5  1.006003  1.674283e+06 -0.000158  2016-02-01 09:03:07  1.454317e+09
# 6  1.004428  1.674928e+06 -0.000253  2016-02-01 09:13:52  1.454318e+09
# 7  1.002387  1.675222e+06 -0.000206  2016-02-01 10:18:50  1.454322e+09
# 8  0.735459  1.675350e+06 -0.000266  2016-02-01 10:20:58  1.454322e+09
# 9  1.009173  1.676036e+06  0.000076  2016-02-01 10:32:23  1.454323e+09
#
#         Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 0   143.708914   144.470993      664       1          0   1       0  9422
# 1   808.177531   808.514844      610       1          0   1       0  9422
# 2   177.316742   178.028607      608       1          0   1       0  9422
# 3   914.263784   913.478791      598       1          0   1       0  9422
# 4   105.659226   106.082843      578       1          0   1       4  9422
# 5  1253.374844  1254.493479      610       1          0   1       0  9422
# 6   266.972745   266.555593      632       1          0   1       0  9422
# 7   167.716731   168.466309      592       1          0   1       0  9423
# 8   217.336722   217.848280      608       1          0   1       0  9423
# 9  1229.525508  1227.419853      632       1          0   1       0  9423
#
#    wfDCBits
# 0         0
# 1         0
# 2         0
# 3         0
# 4         4
# 5         0
# 6         0
# 7         0
# 8         0
# 9         0

# %%
# In old but not in new
# 104 - 27 
n = 0
chList0 = []
runList0 = []
energyList0 = []
chList = []
runList = []
energyList = []
for index, row in dfOld.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-10,row['Energy']+10)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfNew.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-10,row['OEnergy']+10)).empty:
        continue
    elif row['run'] in dfNew['run'].values and row['channel'] in dfNew['channel'].values: 
#     else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['ClockTime'])
        chList.append(row['channel'])
        runList.append(row['run'])
        energyList.append(row['Energy'])
        n += 1
print "Total mismatched events: ", n
# Out:
# run: 9864  channel: 582  Energy: 342.215  AvsE: 1.001  DCR: -0.00001  ClockTime: 2597256.42
# run: 10129  channel: 608  Energy: 637.509  AvsE: 1.150  DCR: -0.00056  ClockTime: 3093898.49
# run: 10139  channel: 578  Energy: 228.430  AvsE: 0.052  DCR: -14.99160  ClockTime: 3133469.47
# run: 11133  channel: 578  Energy: 224.782  AvsE: 0.056  DCR: -14.99173  ClockTime: 5641100.06
# run: 12678  channel: 672  Energy: 560.742  AvsE: 0.726  DCR: -0.00012  ClockTime: 7891177.93
# run: 12681  channel: 672  Energy: 275.452  AvsE: 1.025  DCR: -0.00010  ClockTime: 7903196.18
# run: 12682  channel: 672  Energy: 339.421  AvsE: 0.998  DCR: -0.00018  ClockTime: 7904497.12
# run: 12689  channel: 672  Energy: 1172.192  AvsE: 0.903  DCR: -0.00003  ClockTime: 7931221.86
# run: 12691  channel: 672  Energy: 1026.937  AvsE: 1.014  DCR: -0.00015  ClockTime: 7936627.00
# run: 12691  channel: 672  Energy: 906.785  AvsE: 1.019  DCR: -0.00014  ClockTime: 7937776.03
# run: 12703  channel: 672  Energy: 651.979  AvsE: 1.009  DCR: -0.00009  ClockTime: 7980784.47
# run: 12707  channel: 672  Energy: 605.029  AvsE: 1.015  DCR: -0.00014  ClockTime: 7995298.36
# run: 12717  channel: 672  Energy: 841.039  AvsE: 1.009  DCR: -0.00011  ClockTime: 8030942.54
# run: 12721  channel: 672  Energy: 693.860  AvsE: 1.040  DCR: -0.00010  ClockTime: 8044339.17
# run: 12721  channel: 672  Energy: 645.840  AvsE: 0.985  DCR: -0.00020  ClockTime: 8045243.14
# run: 12781  channel: 648  Energy: 290.082  AvsE: 0.979  DCR: -0.00008  ClockTime: 8225424.09
# run: 13011  channel: 672  Energy: 208.928  AvsE: 0.832  DCR: -0.00009  ClockTime: 8613491.25
# run: 13037  channel: 610  Energy: 706.731  AvsE: 0.817  DCR: -0.00023  ClockTime: 8704781.07
# run: 13042  channel: 664  Energy: 293.437  AvsE: 1.003  DCR: -0.00019  ClockTime: 8725565.73
# run: 13050  channel: 580  Energy: 102.002  AvsE: 1.032  DCR: -0.00016  ClockTime: 8753379.52
# run: 13235  channel: 690  Energy: 253.474  AvsE: 1.011  DCR: 0.00001  ClockTime: 9306701.86
# run: 13259  channel: 580  Energy: 1420.911  AvsE: 0.845  DCR: -0.00032  ClockTime: 9394488.56
# run: 13263  channel: 578  Energy: 204.862  AvsE: 0.998  DCR: -0.00016  ClockTime: 9408226.40
# run: 13365  channel: 608  Energy: 100.030  AvsE: 0.966  DCR: 0.00046  ClockTime: 9681993.20
# Total mismatched events:  24

# %%
# In new but not in old
# 22 - 20 : due to 594
n2 = 0
chList2 = []
runList2 = []
energyList2 = []
for index, row in dfNew.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-10,row['Energy']+10)).empty:
        continue
    elif not dfOld.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-10,row['OEnergy']+10)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif row['run'] in dfOld['run'].values and row['channel'] in dfOld['channel'].values:
#     else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'], row['ClockTime'])
        chList2.append(row['channel'])
        runList2.append(row['run'])
        energyList2.append(row['Energy'])
        n2 += 1
print "Total mismatch: ", n2
# Out:
# run: 9486  channel: 626  Energy: 832.229  AvsE: -0.938  DCR: -0.00036 LocalTime: 1985.12  ClockTime: 1985.72
# run: 9639  channel: 578  Energy: 290.651  AvsE: -1.621  DCR: -0.00036 LocalTime: 2923.41  ClockTime: 2924.45
# run: 9655  channel: 582  Energy: 280.457  AvsE: 0.268  DCR: -0.00038 LocalTime: 3388.21  ClockTime: 3389.39
# run: 9858  channel: 578  Energy: 183.509  AvsE: 0.691  DCR: -0.00011 LocalTime: 786.86  ClockTime: 787.35
# run: 10139  channel: 578  Energy: 203.505  AvsE: -11.640  DCR: 0.11486 LocalTime: 3552.56  ClockTime: 3553.47
# run: 10379  channel: 582  Energy: 112.290  AvsE: -1.808  DCR: -0.00035 LocalTime: 1770.27  ClockTime: 1771.26
# run: 10618  channel: 582  Energy: 105.083  AvsE: 0.274  DCR: -0.00037 LocalTime: 2906.02  ClockTime: 2907.44
# run: 10681  channel: 640  Energy: 645.122  AvsE: 0.284  DCR: -0.00039 LocalTime: 2200.02  ClockTime: 2200.58
# run: 10745  channel: 648  Energy: 235.645  AvsE: -0.686  DCR: -0.00105 LocalTime: 645.95  ClockTime: 661.31
# run: 11133  channel: 578  Energy: 200.352  AvsE: -11.383  DCR: 0.11277 LocalTime: 343.38  ClockTime: 357.06
# run: 11451  channel: 592  Energy: 116.747  AvsE: -0.012  DCR: -0.00068 LocalTime: 3548.25  ClockTime: 3548.69
# run: 12755  channel: 598  Energy: 104.719  AvsE: 0.526  DCR: -0.00026 LocalTime: 406.82  ClockTime: 406.86
# run: 12844  channel: 640  Energy: 176.739  AvsE: 0.184  DCR: -0.00077 LocalTime: 2567.36  ClockTime: 2567.36
# run: 13036  channel: 632  Energy: 213.782  AvsE: 0.927  DCR: -0.00040 LocalTime: 3495.96  ClockTime: 3496.05
# run: 13127  channel: 582  Energy: 337.207  AvsE: 0.469  DCR: -0.00043 LocalTime: 1712.73  ClockTime: 1712.82
# run: 13225  channel: 610  Energy: 400.659  AvsE: 0.215  DCR: -0.00037 LocalTime: 3133.98  ClockTime: 3134.07
# run: 13335  channel: 580  Energy: 406.766  AvsE: -4.067  DCR: -0.00053 LocalTime: 494.37  ClockTime: 494.41
# Total mismatch:  17

# %%
# Since mismatched events, look in full file
# In old but not in new
nfull1 = 0
chListfull1 = []
runListfull1 = []
energyListfull1 = []
for run,channel,energy in zip(runList, chList, energyList):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-10,energy+10)).empty:
#         print 'Found events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
#         print dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-10,energy+10)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfNewFull['run'].values and channel in dfNewFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull1.append(row['channel'])
        runListfull1.append(row['run'])
        energyListfull1.append(row['Energy'])
        nfull1 += 1
print "Total mismatch: ", nfull1
# Out:
# Mismatched events -- run: 10129  channel: 608  Energy: 637.509
# Mismatched events -- run: 10139  channel: 578  Energy: 228.430
# Mismatched events -- run: 11133  channel: 578  Energy: 224.782
# Mismatched events -- run: 12678  channel: 672  Energy: 560.742
# Mismatched events -- run: 12681  channel: 672  Energy: 275.452
# Mismatched events -- run: 12682  channel: 672  Energy: 339.421
# Mismatched events -- run: 12689  channel: 672  Energy: 1172.192
# Mismatched events -- run: 12691  channel: 672  Energy: 1026.937
# Mismatched events -- run: 12691  channel: 672  Energy: 906.785
# Mismatched events -- run: 12703  channel: 672  Energy: 651.979
# Mismatched events -- run: 12707  channel: 672  Energy: 605.029
# Mismatched events -- run: 12717  channel: 672  Energy: 841.039
# Mismatched events -- run: 12721  channel: 672  Energy: 693.860
# Mismatched events -- run: 12721  channel: 672  Energy: 645.840
# Mismatched events -- run: 13365  channel: 608  Energy: 100.030
# Total mismatch:  15

# %%
# Since mismatched events, look in full file
# In new but not in old
nfull2 = 0
chListfull2 = []
runListfull2 = []
energyListfull2 = []
for run,channel,energy in zip(runList2, chList2, energyList2):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).empty:
#         print 'Found events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
#         print dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfOldFull['run'].values and channel in dfOldFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull2.append(row['channel'])
        runListfull2.append(row['run'])
        energyListfull2.append(row['Energy'])
        nfull2 += 1
print "Total mismatch: ", nfull2
# Out:
# Mismatched events -- run: 10139  channel: 578  Energy: 203.505
# Mismatched events -- run: 11133  channel: 578  Energy: 200.352
# Mismatched events -- run: 11451  channel: 592  Energy: 116.747
# Total mismatch:  3

# %%
# Cut events in old but not in new
nCut2,nSwap2 = 0,0
chListCut2 = []
runListCut2 = []
energyListCut2 = []
nDC, nMu, nLN, nAvsE, nDCR = 0, 0, 0, 0, 0
for index, row in dfOldCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 500:
        continue
    if not dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfNewCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy','LocalTime'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values != 0 or dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= -1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        nSwap2 += 1
        chListCut2.append(row['channel'])
        runListCut2.append(row['run'])
        energyListCut2.append(row['Energy'])        
        continue
    elif row['run'] in dfNewCut['run'].values and row['channel'] in dfNewCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'])

        nCut2 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d"%(nLN, nMu, nDC, nAvsE, nDCR)
print "Total swapped: ", nSwap2
print "Total mismatch: ", nCut2
# Out:
#         AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 978  0.57455 -0.000151  533.269955      672          1          0       0
#
#       run  wfDCBits
# 978  9895         0
# AvsE:1.024  DCR:-0.00009  Energy:532.805  channel:672  run:9895
# Untagged - run: 10129  channel: 608  Energy: 637.509  AvsE: 1.150  DCR: -0.00056
#           AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 1488  0.907717 -0.000359  647.438904      582          1          0       0
#
#         run  wfDCBits
# 1488  10140         0
# AvsE:1.011  DCR:-0.00016  Energy:647.384  channel:582  run:10140
#           AvsE       DCR       Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 1838  0.509778 -0.000546  1529.501705      598          1          0       0
#
#         run  wfDCBits
# 1838  10204         0
# AvsE:1.010  DCR:-0.00016  Energy:1529.789  channel:598  run:10204
#           AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 2894 -2.068289 -0.000393  910.772555      582          0          0       0
#
#         run  wfDCBits
# 2894  10700         0
# AvsE:1.005  DCR:-0.00021  Energy:910.538  channel:582  run:10700
#           AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 2966 -1.444929 -0.000418  2118.99211      632          0          0       0
#
#         run  wfDCBits
# 2966  10712         0
# AvsE:1.001  DCR:-0.00010  Energy:2119.479  channel:632  run:10712
#           AvsE       DCR     Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 3052 -0.088237 -0.000128  915.08278      672          1          0       0
#
#         run  wfDCBits
# 3052  10753         0
# AvsE:1.007  DCR:-0.00002  Energy:915.018  channel:672  run:10753
#           AvsE       DCR       Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 3697 -1.095471 -0.000396  1562.913105      632          0          0       0
#
#         run  wfDCBits
# 3697  11111         0
# AvsE:1.001  DCR:-0.00009  Energy:1563.023  channel:632  run:11111
#           AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 3787  0.082605 -0.000436  1017.75586      664          1          0       0
#
#         run  wfDCBits
# 3787  11126         0
# AvsE:1.004  DCR:-0.00025  Energy:1017.328  channel:664  run:11126
#          AvsE       DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 3989  0.15256 -0.000373  781.855972      640          1          0       0
#
#         run  wfDCBits
# 3989  11163         0
# AvsE:1.020  DCR:-0.00012  Energy:781.921  channel:640  run:11163
#           AvsE       DCR     Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 3990  0.432726 -0.000245  631.32732      578          1          0       0
#
#         run  wfDCBits
# 3990  11163         0
# AvsE:1.011  DCR:-0.00011  Energy:631.091  channel:578  run:11163
#           AvsE      DCR      Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 4898 -0.100743 -0.00032  870.191989      578          1          0       0
#
#         run  wfDCBits
# 4898  12688         0
# AvsE:1.004  DCR:-0.00016  Energy:870.013  channel:578  run:12688
# Untagged - run: 12691  channel: 672  Energy: 1026.937  AvsE: 1.014  DCR: -0.00015
# Untagged - run: 12691  channel: 672  Energy: 906.785  AvsE: 1.019  DCR: -0.00014
# Untagged - run: 12703  channel: 672  Energy: 651.979  AvsE: 1.009  DCR: -0.00009
# Untagged - run: 12707  channel: 672  Energy: 605.029  AvsE: 1.015  DCR: -0.00014
# Untagged - run: 12717  channel: 672  Energy: 841.039  AvsE: 1.009  DCR: -0.00011
# Untagged - run: 12721  channel: 672  Energy: 693.860  AvsE: 1.040  DCR: -0.00010
#           AvsE       DCR       Energy  channel  isLNFill1  isLNFill2  muVeto  \
# 5965 -1.291573 -0.000892  1556.183896      640          0          0       0
#
#         run  wfDCBits
# 5965  13084         0
# AvsE:1.003  DCR:-0.00028  Energy:1556.643  channel:640  run:13084
# Cut by LNFill: 8   muVeto: 0   wfDCBits: 0   AvsE: 4   DCR: 0
# Total swapped:  12
# Total mismatch:  7

# %%
# Cut events not rejected in new skim
nCut,nSwap = 0,0
chListCut = []
runListCut = []
energyListCut = []
nDC, nMu, nLN, nAvsE, nDCR, nBurst = 0, 0, 0, 0, 0, 0
for index, row in dfNewCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 500:
        continue
    if not dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfOldCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif row['channel'] == 594:
        continue
    elif not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        print dfTemp.drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        if 7370e3<dfTemp['ClockTime'].values<7371e3 or 2192e3<dfTemp['ClockTime'].values<2195e3 or 7840e3<dfTemp['ClockTime'].values<7860e3:
            nBurst += 1
        elif 8384e3<dfTemp['ClockTime'].values<8387e3 or 8984e3<dfTemp['ClockTime'].values<8985e3 or 9002e3<dfTemp['ClockTime'].values<9005e3:
            nBurst += 1
        elif dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= 1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCut.append(row['channel'])
        runListCut.append(row['run'])
        energyListCut.append(row['Energy'])
        nSwap += 1
        continue
    elif row['run'] in dfOldCut['run'].values and row['channel'] in dfOldCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCut += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d  Burst: %d"%(nLN, nMu, nDC, nAvsE, nDCR, nBurst)
print "Total swapped: ", nSwap
print "Total mismatch: ", nCut
# Out:
#        AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 3  1.011895  0.000075  914.263784      598          0       0  9422         0
# AvsE:0.578  DCR:-0.00025  Energy:914.401  channel:598  run:9422
#        AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 9  1.009173  0.000076  1229.525508      632          0       0  9423         0
# AvsE:-0.098  DCR:-0.00026  Energy:1229.557  channel:632  run:9423
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 43  0.989492 -0.000492  867.148612      626          0       0  9429         0
# AvsE:-0.838  DCR:-0.00063  Energy:866.408  channel:626  run:9429
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 55  1.009994  0.000033  512.022582      598          0       0  9432         0
# AvsE:0.337  DCR:-0.00022  Energy:512.315  channel:598  run:9432
#         AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 57  1.007599  0.000202  1191.974227      598          0       0  9432
#
#     wfDCBits
# 57         0
# AvsE:0.179  DCR:-0.00010  Energy:1192.046  channel:598  run:9432
#        AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 60  0.98931 -0.000324  816.917557      626          0       0  9432         0
# AvsE:-0.772  DCR:-0.00049  Energy:816.283  channel:626  run:9432
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 66  1.014337  0.000005  965.992586      672          0       0  9433         0
# AvsE:0.243  DCR:-0.00010  Energy:966.278  channel:672  run:9433
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 68  1.008633  0.000092  643.953362      598          0       0  9433         0
# AvsE:0.275  DCR:-0.00020  Energy:644.199  channel:598  run:9433
#         AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 77  1.010724  0.000232  1062.151608      598          0       0  9435
#
#     wfDCBits
# 77         0
# AvsE:0.508  DCR:-0.00011  Energy:1062.265  channel:598  run:9435
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 86  1.030062  0.000128  522.300526      598          0       0  9436         0
# AvsE:1.343  DCR:-0.00017  Energy:522.698  channel:598  run:9436
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 92  0.989349 -0.000162  820.837699      626          0       0  9437         0
# AvsE:-0.777  DCR:-0.00034  Energy:820.212  channel:626  run:9437
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 98  1.056888  0.000058  743.187353      690          0       0  9439         0
# AvsE:9.650  DCR:-0.00015  Energy:743.438  channel:690  run:9439
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 135  0.99225 -0.000411  893.869916      626          0       0  9478         0
# AvsE:-0.716  DCR:-0.00064  Energy:893.412  channel:626  run:9478
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 159  1.007732  0.000051  1237.881411      610          0       0  9483
#
#      wfDCBits
# 159         0
# AvsE:0.233  DCR:-0.00005  Energy:1237.495  channel:610  run:9483
# Untagged - run: 9486  channel: 626  Energy: 832.229  AvsE: -0.938  DCR: -0.00036 LocalTime: 1985.12
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 179  0.992335 -0.000414  851.508801      626          0       0  9487
#
#      wfDCBits
# 179         0
# AvsE:-0.658  DCR:-0.00055  Energy:851.171  channel:626  run:9487
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 203  1.011752  0.000111  755.489098      598          0       0  9539
#
#      wfDCBits
# 203         0
# AvsE:0.507  DCR:-0.00019  Energy:755.370  channel:598  run:9539
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 212  0.998883 -0.000189  1079.041741      580          0       0  9540
#
#      wfDCBits
# 212         0
# AvsE:-0.487  DCR:-0.00036  Energy:1078.782  channel:580  run:9540
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 228  1.004491  0.000089  1268.323068      580          0       0  9543
#
#      wfDCBits
# 228         0
# AvsE:-0.665  DCR:-0.00009  Energy:1268.146  channel:580  run:9543
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 235  0.992743 -0.000316  869.081893      608          0       0  9545
#
#      wfDCBits
# 235         0
# AvsE:1.023  DCR:-0.00061  Energy:868.403  channel:608  run:9545
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 236  0.992853 -0.000415  1007.356977      626          0       0  9545
#
#      wfDCBits
# 236         0
# AvsE:-0.817  DCR:-0.00060  Energy:1006.492  channel:626  run:9545
#          AvsE      DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 238  0.995755 -0.00025  580.133117      580          0       0  9545         0
# AvsE:-0.475  DCR:-0.00047  Energy:580.024  channel:580  run:9545
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 246  1.005938  0.000159  848.150086      598          0       0  9546
#
#      wfDCBits
# 246         0
# AvsE:0.072  DCR:-0.00019  Energy:847.854  channel:598  run:9546
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 250  0.991736 -0.000251  905.162171      626          0       0  9547
#
#      wfDCBits
# 250         0
# AvsE:-0.763  DCR:-0.00043  Energy:904.566  channel:626  run:9547
#         AvsE     DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 279  0.99455 -0.0004  922.346538      626          0       0  9551         0
# AvsE:-0.612  DCR:-0.00056  Energy:921.698  channel:626  run:9551
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 307  0.989412 -0.000328  553.570328      626          0       0  9556
#
#      wfDCBits
# 307         0
# AvsE:-0.320  DCR:-0.00048  Energy:553.210  channel:626  run:9556
#          AvsE      DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 314  1.008461  0.00017  748.829467      598          0       0  9557         0
# AvsE:0.289  DCR:-0.00012  Energy:748.488  channel:598  run:9557
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 327  1.004737  0.000171  1015.113276      598          0       0  9558
#
#      wfDCBits
# 327         0
# AvsE:-0.092  DCR:-0.00014  Energy:1014.791  channel:598  run:9558
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 345  0.991918 -0.000318  865.685943      626          0       0  9563
#
#      wfDCBits
# 345         0
# AvsE:-0.706  DCR:-0.00049  Energy:865.266  channel:626  run:9563
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 364  1.014831  0.000054  740.159072      690          0       0  9565
#
#      wfDCBits
# 364         0
# AvsE:2.847  DCR:-0.00015  Energy:740.257  channel:690  run:9565
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 365  1.010605  0.000203  1539.812532      592          0       0  9638
#
#      wfDCBits
# 365         0
# AvsE:-0.347  DCR:-0.00056  Energy:1538.466  channel:592  run:9638
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 366  1.006036  0.000093  619.579784      598          0       0  9638
#
#      wfDCBits
# 366         0
# AvsE:0.134  DCR:-0.00022  Energy:619.396  channel:598  run:9638
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 373  0.986679 -0.000424  844.516594      626          0       0  9639
#
#      wfDCBits
# 373         0
# AvsE:-0.955  DCR:-0.00058  Energy:843.902  channel:626  run:9639
#         AvsE      DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 391  0.98526 -0.00016  555.124619      578          0       0  9642         0
# AvsE:-0.440  DCR:-0.00027  Energy:555.502  channel:578  run:9642
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 394  1.009792  0.000168  846.772056      598          0       0  9642
#
#      wfDCBits
# 394         0
# AvsE:0.376  DCR:-0.00017  Energy:846.605  channel:598  run:9642
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 565  1.013067 -0.000267  820.478409      608          0       0  9654
#
#      wfDCBits
# 565         0
# AvsE:0.419  DCR:-0.00050  Energy:820.126  channel:608  run:9654
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 566  1.021601 -0.000226  1102.233114      592          0       0  9654
#
#      wfDCBits
# 566         0
# AvsE:0.370  DCR:-0.00091  Energy:1102.127  channel:592  run:9654
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 577  1.006703  0.000297  977.872623      598          0       0  9656
#
#      wfDCBits
# 577         0
# AvsE:0.115  DCR:-0.00003  Energy:977.486  channel:598  run:9656
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 578  1.047536  0.000462  679.760704      648          0       0  9656
#
#      wfDCBits
# 578         0
# AvsE:-0.200  DCR:-0.00033  Energy:679.721  channel:648  run:9656
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 602  1.010276  0.000298  1291.918205      598          0       0  9660
#
#      wfDCBits
# 602         0
# AvsE:0.492  DCR:-0.00008  Energy:1291.536  channel:598  run:9660
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 606  1.011792  0.000142  637.855771      598          0       0  9660
#
#      wfDCBits
# 606         0
# AvsE:0.484  DCR:-0.00010  Energy:637.673  channel:598  run:9660
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 610  0.998879 -0.000422  1111.504323      608          0       0  9661
#
#      wfDCBits
# 610         0
# AvsE:-0.349  DCR:-0.00067  Energy:1111.058  channel:608  run:9661
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 622  1.072081  0.000107  1383.838133      690          0       0  9662
#
#      wfDCBits
# 622         0
# AvsE:21.042  DCR:-0.00008  Energy:1384.162  channel:690  run:9662
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 631  0.991043 -0.000508  505.879647      626          0       0  9664
#
#      wfDCBits
# 631         0
# AvsE:-0.204  DCR:-0.00066  Energy:505.874  channel:626  run:9664
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 664  0.990182 -0.000445  981.011462      626          0       0  9711
#
#      wfDCBits
# 664         0
# AvsE:-0.972  DCR:-0.00061  Energy:980.781  channel:626  run:9711
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 690  0.990192 -0.000263  639.868835      626          0       0  9716
#
#      wfDCBits
# 690         0
# AvsE:-0.430  DCR:-0.00040  Energy:639.625  channel:626  run:9716
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 701  1.009044  0.000255  1256.23905      598          0       0  9719
#
#      wfDCBits
# 701         0
# AvsE:0.347  DCR:-0.00012  Energy:1255.873  channel:598  run:9719
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 710  1.009792  0.000103  855.881523      598          0       0  9720
#
#      wfDCBits
# 710         0
# AvsE:0.382  DCR:-0.00021  Energy:855.729  channel:598  run:9720
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 752  1.011853  0.000043  945.184019      632          0       0  9727
#
#      wfDCBits
# 752         0
# AvsE:0.206  DCR:-0.00028  Energy:945.424  channel:632  run:9727
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 782  0.999796 -0.000255  812.246663      664          0       0  9768
#
#      wfDCBits
# 782         0
# AvsE:-0.403  DCR:-0.00053  Energy:812.430  channel:664  run:9768
#         AvsE      DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 811  1.02408  0.00008  962.050696      598          0       0  9774         0
# AvsE:1.705  DCR:-0.00028  Energy:961.871  channel:598  run:9774
#         AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 887  1.03673  0.000088  752.209328      598          0       0  9824         0
# AvsE:2.324  DCR:-0.00020  Energy:752.094  channel:598  run:9824
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 891  1.007445  0.000027  1163.907648      598          0       0  9826
#
#      wfDCBits
# 891         0
# AvsE:0.162  DCR:-0.00031  Energy:1163.458  channel:598  run:9826
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 892  1.011973  0.000018  798.949637      672          0       0  9826
#
#      wfDCBits
# 892         0
# AvsE:0.170  DCR:-0.00010  Energy:799.298  channel:672  run:9826
#          AvsE       DCR     Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 921  1.003953  0.000013  820.47461      598          0       0  9830         0
# AvsE:-0.092  DCR:-0.00034  Energy:820.320  channel:598  run:9830
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 933  1.013385  0.000068  1074.317508      598          0       0  9831
#
#      wfDCBits
# 933         0
# AvsE:0.789  DCR:-0.00030  Energy:1073.917  channel:598  run:9831
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 948  1.094554  0.000006  1115.800147      690          0       0  9849
#
#      wfDCBits
# 948         0
# AvsE:22.782  DCR:-0.00016  Energy:1116.295  channel:690  run:9849
#          AvsE      DCR     Energy  channel  isLNFill1  muVeto   run  wfDCBits
# 978  0.992424 -0.00058  788.35176      626          0       0  9857         0
# AvsE:-0.572  DCR:-0.00072  Energy:788.005  channel:626  run:9857
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 981  0.998441  0.000005  576.331286      582          0       0  9858
#
#      wfDCBits
# 981         0
# AvsE:-0.333  DCR:-0.00019  Energy:576.249  channel:582  run:9858
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 990  0.996193 -0.000301  660.544347      580          0       0  9860
#
#      wfDCBits
# 990         0
# AvsE:-0.327  DCR:-0.00051  Energy:660.712  channel:580  run:9860
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1039  1.008975  0.000125  1325.522466      690          0       0  9870
#
#       wfDCBits
# 1039         0
# AvsE:2.070  DCR:-0.00006  Energy:1325.571  channel:690  run:9870
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1061  1.005551  0.000018  510.793489      690          0       0  9874
#
#       wfDCBits
# 1061         0
# AvsE:1.426  DCR:-0.00016  Energy:511.010  channel:690  run:9874
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1074  0.970846 -0.000127  718.208795      592          0       0  9876
#
#       wfDCBits
# 1074         0
# AvsE:-0.788  DCR:-0.00073  Energy:717.886  channel:592  run:9876
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1090  1.012099  0.000164  1144.469908      632          0       0  9881
#
#       wfDCBits
# 1090         0
# AvsE:-0.027  DCR:-0.00015  Energy:1144.253  channel:632  run:9881
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1104  0.991627 -0.000524  947.940011      626          0       0  9885
#
#       wfDCBits
# 1104         0
# AvsE:-0.847  DCR:-0.00069  Energy:947.508  channel:626  run:9885
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1130  0.991361 -0.000441  505.033827      626          0       0  9890
#
#       wfDCBits
# 1130         0
# AvsE:-0.181  DCR:-0.00057  Energy:504.846  channel:626  run:9890
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1135  0.994441 -0.000082  633.147105      578          0       0  9890
#
#       wfDCBits
# 1135         0
# AvsE:-0.245  DCR:-0.00020  Energy:633.363  channel:578  run:9890
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1173  1.013029  0.000072  548.621429      592          0       0  9898
#
#       wfDCBits
# 1173         0
# AvsE:0.067  DCR:-0.00046  Energy:548.599  channel:592  run:9898
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1174  0.994054 -0.000411  633.500015      626          0       0  9898
#
#       wfDCBits
# 1174         0
# AvsE:-0.279  DCR:-0.00056  Energy:633.299  channel:626  run:9898
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1179  0.990549 -0.000375  629.700002      626          0       0  9899
#
#       wfDCBits
# 1179         0
# AvsE:-0.412  DCR:-0.00059  Energy:629.374  channel:626  run:9899
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto   run  \
# 1204  0.996336 -0.000124  766.032875      632          0       0  9904
#
#       wfDCBits
# 1204         0
# AvsE:-0.070  DCR:-0.00042  Energy:766.063  channel:632  run:9904
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1230  1.011554  0.000026  1293.307773      598          0       0  9908
#
#       wfDCBits
# 1230         0
# AvsE:0.638  DCR:-0.00036  Energy:1293.051  channel:598  run:9908
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1240  1.00178  0.000039  1658.329124      582          0       0  9911
#
#       wfDCBits
# 1240         0
# AvsE:0.060  DCR:-0.00011  Energy:1657.754  channel:582  run:9911
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1249  0.998339 -0.000682  1184.796321      626          0       0  9911
#
#       wfDCBits
# 1249         0
# AvsE:-0.650  DCR:-0.00086  Energy:1184.360  channel:626  run:9911
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto   run  \
# 1251  1.037586  0.000167  1550.774037      580          0       0  9912
#
#       wfDCBits
# 1251         0
# AvsE:7.155  DCR:-0.00006  Energy:1549.915  channel:580  run:9912
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1368  1.009404  0.000047  977.188319      598          0       0  10024
#
#       wfDCBits
# 1368         0
# AvsE:0.356  DCR:-0.00028  Energy:977.047  channel:598  run:10024
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1397  0.999281 -0.000061  699.870659      582          0       0  10028
#
#       wfDCBits
# 1397         0
# AvsE:-0.513  DCR:-0.00027  Energy:699.923  channel:582  run:10028
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1411  1.01119  0.000057  1143.792197      592          0       0  10031
#
#       wfDCBits
# 1411         0
# AvsE:-0.109  DCR:-0.00064  Energy:1142.961  channel:592  run:10031
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1421  1.007355  0.000061  502.296039      664          0       0  10033
#
#       wfDCBits
# 1421         0
# AvsE:0.288  DCR:-0.00015  Energy:502.473  channel:664  run:10033
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1425  0.996438 -0.000463  802.748028      626          0       0  10034
#
#       wfDCBits
# 1425         0
# AvsE:-0.375  DCR:-0.00052  Energy:802.841  channel:626  run:10034
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1428  1.013234  0.000335  541.562968      648          0       0  10034
#
#       wfDCBits
# 1428         0
# AvsE:-0.109  DCR:-0.00046  Energy:541.693  channel:648  run:10034
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1437  0.998502 -0.000245  1400.913372      578          0       0  10074
#
#       wfDCBits
# 1437         0
# AvsE:-0.861  DCR:-0.00037  Energy:1401.346  channel:578  run:10074
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1465  0.993572 -0.000456  932.654788      626          0       0  10078
#
#       wfDCBits
# 1465         0
# AvsE:-0.697  DCR:-0.00050  Energy:932.450  channel:626  run:10078
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1494  1.009397  0.000037  1142.412537      610          0       0  10082
#
#       wfDCBits
# 1494         0
# AvsE:0.414  DCR:-0.00011  Energy:1142.357  channel:610  run:10082
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1497  1.002658  0.000029  714.932578      578          0       0  10082
#
#       wfDCBits
# 1497         0
# AvsE:0.010  DCR:-0.00013  Energy:714.916  channel:578  run:10082
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1509  0.996992 -0.000105  674.304015      672          0       0  10086
#
#       wfDCBits
# 1509         0
# AvsE:-0.296  DCR:-0.00021  Energy:674.600  channel:672  run:10086
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1532  0.997569 -0.000073  653.052385      610          0       0  10089
#
#       wfDCBits
# 1532         0
# AvsE:-0.327  DCR:-0.00023  Energy:653.069  channel:610  run:10089
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 1546  1.010745  0.000005  781.52527      610          0       0  10116
#
#       wfDCBits
# 1546         0
# AvsE:0.511  DCR:-0.00016  Energy:781.569  channel:610  run:10116
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1617  0.96124 -0.000088  515.612274      592          0       0  10130
#
#       wfDCBits
# 1617         0
# AvsE:-0.413  DCR:-0.00061  Energy:515.701  channel:592  run:10130
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1639  1.003191  0.000091  714.642809      592          0       0  10134
#
#       wfDCBits
# 1639         0
# AvsE:-0.247  DCR:-0.00053  Energy:714.357  channel:592  run:10134
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1714  1.002705  0.000153  1236.138981      582          0       0  10148
#
#       wfDCBits
# 1714         0
# AvsE:-0.453  DCR:-0.00008  Energy:1235.798  channel:582  run:10148
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1720  0.998624  0.000287  651.296289      592          0       0  10149
#
#       wfDCBits
# 1720         0
# AvsE:-0.112  DCR:-0.00030  Energy:651.402  channel:592  run:10149
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1724  1.036656  0.000012  981.539507      672          0       0  10149
#
#       wfDCBits
# 1724         0
# AvsE:1.299  DCR:-0.00011  Energy:982.361  channel:672  run:10149
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1725  1.057184  0.000003  1292.659188      640          0       0  10149
#
#       wfDCBits
# 1725         0
# AvsE:3.043  DCR:-0.00007  Energy:1292.633  channel:640  run:10149
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1743  0.992435 -0.000484  817.181027      626          0       0  10152
#
#       wfDCBits
# 1743         0
# AvsE:-0.612  DCR:-0.00055  Energy:816.917  channel:626  run:10152
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1747  0.976931 -0.000239  563.726867      592          0       0  10153
#
#       wfDCBits
# 1747         0
# AvsE:-0.788  DCR:-0.00076  Energy:563.808  channel:592  run:10153
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 1812  1.001704  0.000058  502.68047      648          0       0  10167
#
#       wfDCBits
# 1812         0
# AvsE:-0.192  DCR:-0.00076  Energy:502.758  channel:648  run:10167
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1816  0.998731 -0.00002  553.421471      582          0       0  10167
#
#       wfDCBits
# 1816         0
# AvsE:-0.454  DCR:-0.00026  Energy:553.363  channel:582  run:10167
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1840  0.999269 -0.000123  803.389625      578          0       0  10171
#
#       wfDCBits
# 1840         0
# AvsE:-0.274  DCR:-0.00025  Energy:803.713  channel:578  run:10171
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 1861  0.994113 -0.000199  887.34993      578          0       0  10175
#
#       wfDCBits
# 1861         0
# AvsE:-0.653  DCR:-0.00031  Energy:887.483  channel:578  run:10175
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1863  1.028456  0.000055  1410.779427      672          0       0  10175
#
#       wfDCBits
# 1863         0
# AvsE:1.222  DCR:-0.00006  Energy:1411.062  channel:672  run:10175
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1867  0.994157 -0.000483  772.422292      626          0       0  10175
#
#       wfDCBits
# 1867         0
# AvsE:-0.452  DCR:-0.00056  Energy:772.064  channel:626  run:10175
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 1907  1.013851  0.000012  1294.708696      640          0       0  10181
#
#       wfDCBits
# 1907         0
# AvsE:-0.319  DCR:-0.00001  Energy:1294.148  channel:640  run:10181
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1910  1.008053  0.000013  753.507483      580          0       0  10181
#
#       wfDCBits
# 1910         0
# AvsE:-0.110  DCR:-0.00021  Energy:753.729  channel:580  run:10181
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1950  1.004562  0.000076  1280.74111      648          0       0  10188
#
#       wfDCBits
# 1950         0
# AvsE:-0.617  DCR:-0.00073  Energy:1280.962  channel:648  run:10188
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 1962  1.00529  0.000172  773.912937      592          0       0  10192
#
#       wfDCBits
# 1962         0
# AvsE:-0.225  DCR:-0.00047  Energy:773.511  channel:592  run:10192
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2000  1.011763  0.000003  573.993658      610          0       0  10199
#
#       wfDCBits
# 2000         0
# AvsE:0.595  DCR:-0.00014  Energy:574.155  channel:610  run:10199
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2081  1.033205  0.000002  933.621547      648          0       0  10212
#
#       wfDCBits
# 2081         0
# AvsE:0.559  DCR:-0.00080  Energy:933.806  channel:648  run:10212
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2088  0.998334  0.000048  611.364691      582          0       0  10213
#
#       wfDCBits
# 2088         0
# AvsE:-0.043  DCR:-0.00016  Energy:611.245  channel:582  run:10213
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2094  0.986567 -0.00017  559.123107      608          0       0  10214
#
#       wfDCBits
# 2094         0
# AvsE:-0.885  DCR:-0.00045  Energy:559.216  channel:608  run:10214
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2178  1.064192  0.000166  600.463282      664          0       0  10230
#
#       wfDCBits
# 2178         0
# AvsE:2.956  DCR:-0.00005  Energy:600.764  channel:664  run:10230
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2199  0.980078 -0.00008  736.286484      592          0       0  10265
#
#       wfDCBits
# 2199         0
# AvsE:-0.680  DCR:-0.00066  Energy:735.722  channel:592  run:10265
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2231  0.996153 -0.000361  660.787366      608          0       0  10271
#
#       wfDCBits
# 2231         0
# AvsE:1.321  DCR:-0.00062  Energy:660.484  channel:608  run:10271
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2232  1.005278  0.000086  698.453431      648          0       0  10272
#
#       wfDCBits
# 2232         0
# AvsE:-0.205  DCR:-0.00076  Energy:698.543  channel:648  run:10272
#         AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2235  0.9982 -0.000593  1188.189072      626          0       0  10272
#
#       wfDCBits
# 2235         0
# AvsE:-0.668  DCR:-0.00061  Energy:1188.379  channel:626  run:10272
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2287  1.010227  0.000019  599.564089      578          0       0  10308
#
#       wfDCBits
# 2287         0
# AvsE:0.429  DCR:-0.00012  Energy:599.704  channel:578  run:10308
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 2299  1.002574  0.000111  867.39106      610          0       0  10313
#
#       wfDCBits
# 2299         0
# AvsE:-0.209  DCR:-0.00004  Energy:867.579  channel:610  run:10313
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2328  0.985692 -0.000167  581.922956      648          0       0  10319
#
#       wfDCBits
# 2328         0
# AvsE:-0.937  DCR:-0.00100  Energy:582.085  channel:648  run:10319
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 2336  1.007331  0.000024  999.23866      578          0       0  10321
#
#       wfDCBits
# 2336         0
# AvsE:0.045  DCR:-0.00011  Energy:999.301  channel:578  run:10321
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2391  0.996763 -0.000182  610.486222      578          0       0  10332
#
#       wfDCBits
# 2391         0
# AvsE:-0.113  DCR:-0.00027  Energy:610.700  channel:578  run:10332
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2400  0.996341 -0.000192  574.856036      580          0       0  10334
#
#       wfDCBits
# 2400         0
# AvsE:0.052  DCR:-0.00040  Energy:575.046  channel:580  run:10334
#           AvsE      DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2413  1.025706  0.00016  1428.454557      690          0       0  10337
#
#       wfDCBits
# 2413         0
# AvsE:7.235  DCR:-0.00000  Energy:1428.703  channel:690  run:10337
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2435  1.07529  0.000081  1012.295305      582          0       0  10344
#
#       wfDCBits
# 2435         0
# AvsE:7.738  DCR:-0.00009  Energy:1012.512  channel:582  run:10344
#           AvsE     DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2482  1.012943  0.0001  937.072711      690          0       0  10381
#
#       wfDCBits
# 2482         0
# AvsE:2.743  DCR:-0.00007  Energy:936.735  channel:690  run:10381
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2508  0.998595 -0.000194  1103.398546      610          0       0  10386
#
#       wfDCBits
# 2508         0
# AvsE:-0.792  DCR:-0.00032  Energy:1103.376  channel:610  run:10386
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2528  1.013283  0.000008  1037.322105      690          0       0  10389
#
#       wfDCBits
# 2528         0
# AvsE:2.913  DCR:-0.00017  Energy:1037.005  channel:690  run:10389
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2581  0.996686 -0.000215  1223.861611      626          0       0  10556
#
#       wfDCBits
# 2581         0
# AvsE:-0.783  DCR:-0.00035  Energy:1222.682  channel:626  run:10556
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2593  1.015865  0.000003  744.811429      690          0       0  10557
#
#       wfDCBits
# 2593         0
# AvsE:3.010  DCR:-0.00021  Energy:744.948  channel:690  run:10557
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2594  0.995137  0.000004  924.901493      608          0       0  10557
#
#       wfDCBits
# 2594         0
# AvsE:-0.412  DCR:-0.00029  Energy:925.082  channel:608  run:10557
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2598  0.999729 -0.000132  867.980581      610          0       0  10608
#
#       wfDCBits
# 2598         0
# AvsE:-0.460  DCR:-0.00029  Energy:868.028  channel:610  run:10608
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 2681  0.993726 -0.000149  618.37047      626          0       0  10623
#
#       wfDCBits
# 2681         0
# AvsE:-0.255  DCR:-0.00029  Energy:617.840  channel:626  run:10623
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2691  0.996183 -0.000232  879.117093      626          0       0  10626
#
#       wfDCBits
# 2691         0
# AvsE:-0.451  DCR:-0.00039  Energy:878.115  channel:626  run:10626
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2698  0.998972 -0.000102  593.206161      626          0       0  10628
#
#       wfDCBits
# 2698         0
# AvsE:-0.007  DCR:-0.00021  Energy:592.609  channel:626  run:10628
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2708  1.004605  0.00001  968.720576      578          0       0  10630
#
#       wfDCBits
# 2708         0
# AvsE:-0.109  DCR:-0.00012  Energy:968.723  channel:578  run:10630
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2738  0.999054 -0.000117  541.842314      592          0       0  10635
#
#       wfDCBits
# 2738         0
# AvsE:-0.226  DCR:-0.00066  Energy:541.604  channel:592  run:10635
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2743  1.014337  0.000022  959.169044      592          0       0  10636
#
#       wfDCBits
# 2743         0
# AvsE:-0.008  DCR:-0.00062  Energy:958.658  channel:592  run:10636
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2746  0.999784 -0.000275  1110.222938      626          0       0  10637
#
#       wfDCBits
# 2746         0
# AvsE:-0.454  DCR:-0.00041  Energy:1109.287  channel:626  run:10637
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2749  1.062057  0.000223  638.580986      648          0       0  10639
#
#       wfDCBits
# 2749         0
# AvsE:0.490  DCR:-0.00065  Energy:638.774  channel:648  run:10639
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2757  0.999309 -0.000148  734.171556      626          0       0  10640
#
#       wfDCBits
# 2757         0
# AvsE:-0.150  DCR:-0.00032  Energy:733.611  channel:626  run:10640
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2764  1.009438  0.000066  993.748625      598          0       0  10642
#
#       wfDCBits
# 2764         0
# AvsE:0.373  DCR:-0.00025  Energy:993.406  channel:598  run:10642
#           AvsE     DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2787  0.998666 -0.0002  858.420188      664          0       0  10647
#
#       wfDCBits
# 2787         0
# AvsE:-0.947  DCR:-0.00041  Energy:858.712  channel:664  run:10647
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2798  0.997385 -0.000165  720.912734      626          0       0  10651
#
#       wfDCBits
# 2798         0
# AvsE:-0.219  DCR:-0.00030  Energy:720.222  channel:626  run:10651
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2828  0.994996 -0.000143  631.389857      626          0       0  10655
#
#       wfDCBits
# 2828         0
# AvsE:-0.225  DCR:-0.00031  Energy:630.918  channel:626  run:10655
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2838  0.995943  0.000033  540.852863      626          0       0  10657
#
#       wfDCBits
# 2838         0
# AvsE:-0.055  DCR:-0.00017  Energy:540.262  channel:626  run:10657
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2842  0.998059 -0.000039  748.735871      626          0       0  10657
#
#       wfDCBits
# 2842         0
# AvsE:-0.220  DCR:-0.00023  Energy:748.066  channel:626  run:10657
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2869  1.002696  0.000178  1010.479476      648          0       0  10662
#
#       wfDCBits
# 2869         0
# AvsE:-0.468  DCR:-0.00063  Energy:1010.861  channel:648  run:10662
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2901  1.003014  0.000039  692.986672      648          0       0  10669
#
#       wfDCBits
# 2901         0
# AvsE:-0.373  DCR:-0.00078  Energy:693.329  channel:648  run:10669
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2902  1.005674  0.000001  784.473256      592          0       0  10669
#
#       wfDCBits
# 2902         0
# AvsE:-0.171  DCR:-0.00059  Energy:783.977  channel:592  run:10669
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2922  1.01564  0.000173  944.289556      608          0       0  10672
#
#       wfDCBits
# 2922         0
# AvsE:0.486  DCR:-0.00014  Energy:943.847  channel:608  run:10672
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2932  1.080809  0.000041  780.219686      664          0       0  10673
#
#       wfDCBits
# 2932         0
# AvsE:4.164  DCR:-0.00017  Energy:780.749  channel:664  run:10673
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2937  0.996553 -0.000197  1216.168452      626          0       0  10674
#
#       wfDCBits
# 2937         0
# AvsE:-0.791  DCR:-0.00031  Energy:1215.064  channel:626  run:10674
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 2947  0.99485  0.000041  1231.245687      626          0       0  10676
#
#       wfDCBits
# 2947         0
# AvsE:-0.932  DCR:-0.00012  Energy:1229.941  channel:626  run:10676
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2963  0.983125 -0.000219  699.999823      640          0       0  10679
#
#       wfDCBits
# 2963         0
# AvsE:-0.760  DCR:-0.00044  Energy:699.883  channel:640  run:10679
# Untagged - run: 10681  channel: 640  Energy: 645.122  AvsE: 0.284  DCR: -0.00039 LocalTime: 2200.02
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2993  1.007652  0.000107  754.544124      610          0       0  10684
#
#       wfDCBits
# 2993         0
# AvsE:0.289  DCR:-0.00007  Energy:754.445  channel:610  run:10684
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 2994  1.006119  0.000029  511.626762      610          0       0  10684
#
#       wfDCBits
# 2994         0
# AvsE:0.328  DCR:-0.00013  Energy:511.657  channel:610  run:10684
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3016  1.006923  0.000008  710.956224      664          0       0  10687
#
#       wfDCBits
# 3016         0
# AvsE:0.208  DCR:-0.00021  Energy:711.249  channel:664  run:10687
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3024  1.005768  0.00007  739.627949      664          0       0  10689
#
#       wfDCBits
# 3024         0
# AvsE:0.197  DCR:-0.00014  Energy:739.924  channel:664  run:10689
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3074  1.008559  0.000006  1312.678896      598          0       0  10699
#
#       wfDCBits
# 3074         0
# AvsE:0.279  DCR:-0.00038  Energy:1312.305  channel:598  run:10699
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3155  0.999485  0.000048  664.776395      626          0       0  10712
#
#       wfDCBits
# 3155         0
# AvsE:-0.071  DCR:-0.00014  Energy:664.263  channel:626  run:10712
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3189  1.034642  0.000003  537.489792      640          0       0  10745
#
#       wfDCBits
# 3189         0
# AvsE:0.514  DCR:-0.00027  Energy:537.508  channel:640  run:10745
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3255  0.992914 -0.000136  727.652666      626          0       0  10756
#
#       wfDCBits
# 3255         0
# AvsE:-0.454  DCR:-0.00030  Energy:727.357  channel:626  run:10756
#           AvsE      DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3259  1.009429  0.00003  1371.434136      632          0       0  10757
#
#       wfDCBits
# 3259         0
# AvsE:-0.584  DCR:-0.00024  Energy:1371.594  channel:632  run:10757
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3260  0.951148 -0.000049  567.603012      592          0       0  10757
#
#       wfDCBits
# 3260         0
# AvsE:-0.628  DCR:-0.00063  Energy:567.656  channel:592  run:10757
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 3302  0.998938 -0.000218  680.75178      582          0       0  10790
#
#       wfDCBits
# 3302         0
# AvsE:0.018  DCR:-0.00046  Energy:680.713  channel:582  run:10790
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3317  0.997378 -0.000239  648.049669      626          0       0  10793
#
#       wfDCBits
# 3317         0
# AvsE:-0.135  DCR:-0.00041  Energy:647.595  channel:626  run:10793
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3351  0.980238 -0.000009  510.470274      578          0       0  10798
#
#       wfDCBits
# 3351         0
# AvsE:-0.487  DCR:-0.00013  Energy:510.619  channel:578  run:10798
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3372  1.000516  0.000194  1052.478155      648          0       0  10801
#
#       wfDCBits
# 3372         0
# AvsE:-0.792  DCR:-0.00060  Energy:1052.597  channel:648  run:10801
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3373  0.987502 -0.000148  1674.970632      632          0       0  10801
#
#       wfDCBits
# 3373         0
# AvsE:1.931  DCR:-0.00044  Energy:1675.196  channel:632  run:10801
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3389  0.999038 -0.00009  502.788749      578          0       0  10831
#
#       wfDCBits
# 3389         0
# AvsE:0.145  DCR:-0.00020  Energy:502.876  channel:578  run:10831
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3427  0.997397 -0.000235  813.435898      580          0       0  10839
#
#       wfDCBits
# 3427         0
# AvsE:0.182  DCR:-0.00043  Energy:813.631  channel:580  run:10839
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3443  0.996151  0.00035  764.608238      648          0       0  10842
#
#       wfDCBits
# 3443         0
# AvsE:-0.573  DCR:-0.00050  Energy:764.536  channel:648  run:10842
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3556  0.998709  0.000085  911.349642      582          0       0  11004
#
#       wfDCBits
# 3556         0
# AvsE:-0.543  DCR:-0.00013  Energy:911.182  channel:582  run:11004
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3559  0.994219 -0.000063  746.349788      626          0       0  11005
#
#       wfDCBits
# 3559         0
# AvsE:-0.401  DCR:-0.00021  Energy:745.816  channel:626  run:11005
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3621  0.99948  0.000006  834.499704      626          0       0  11018
#
#       wfDCBits
# 3621         0
# AvsE:-0.231  DCR:-0.00013  Energy:834.010  channel:626  run:11018
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3683  1.000597  0.000022  625.454762      582          0       0  11055
#
#       wfDCBits
# 3683         0
# AvsE:0.162  DCR:-0.00016  Energy:625.532  channel:582  run:11055
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3691  1.005805  0.000034  975.249443      610          0       0  11058
#
#       wfDCBits
# 3691         0
# AvsE:0.042  DCR:-0.00011  Energy:975.184  channel:610  run:11058
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3713  1.156025  0.000095  703.686377      582          0       0  11062
#
#       wfDCBits
# 3713         0
# AvsE:11.582  DCR:-0.00011  Energy:704.031  channel:582  run:11062
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3783  1.004528  0.000056  1000.253358      578          0       0  11092
#
#       wfDCBits
# 3783         0
# AvsE:-0.128  DCR:-0.00010  Energy:1000.295  channel:578  run:11092
#          AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3795  0.99359 -0.000147  1118.130279      672          0       0  11096
#
#       wfDCBits
# 3795         0
# AvsE:-0.903  DCR:-0.00023  Energy:1118.066  channel:672  run:11096
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3856  0.997594 -0.000146  557.825203      626          0       0  11106
#
#       wfDCBits
# 3856         0
# AvsE:-0.031  DCR:-0.00032  Energy:557.549  channel:626  run:11106
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3869  0.998725  0.000067  933.315804      626          0       0  11108
#
#       wfDCBits
# 3869         0
# AvsE:-0.358  DCR:-0.00005  Energy:932.514  channel:626  run:11108
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3871  1.011066  0.000004  633.753928      632          0       0  11109
#
#       wfDCBits
# 3871         0
# AvsE:-0.045  DCR:-0.00032  Energy:633.904  channel:632  run:11109
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3872  0.996036  0.000143  835.784053      648          0       0  11109
#
#       wfDCBits
# 3872         0
# AvsE:-0.634  DCR:-0.00070  Energy:835.832  channel:648  run:11109
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3932  1.00726  0.000002  604.746966      610          0       0  11119
#
#       wfDCBits
# 3932         0
# AvsE:0.345  DCR:-0.00018  Energy:604.575  channel:610  run:11119
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 3935  1.005096  0.000062  1067.969166      582          0       0  11120
#
#       wfDCBits
# 3935         0
# AvsE:0.633  DCR:-0.00015  Energy:1067.999  channel:582  run:11120
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3936  0.996317 -0.000193  551.215426      626          0       0  11120
#
#       wfDCBits
# 3936         0
# AvsE:-0.071  DCR:-0.00035  Energy:550.969  channel:626  run:11120
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3943  1.007522  0.000022  711.227098      690          0       0  11121
#
#       wfDCBits
# 3943         0
# AvsE:1.678  DCR:-0.00017  Energy:711.119  channel:690  run:11121
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 3949  0.992363 -0.000118  821.449032      578          0       0  11122
#
#       wfDCBits
# 3949         0
# AvsE:-0.666  DCR:-0.00027  Energy:821.873  channel:578  run:11122
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 4026  0.999492 -0.000132  1048.000209      632          0       0  11134
#
#       wfDCBits
# 4026         0
# AvsE:-0.560  DCR:-0.00040  Energy:1048.078  channel:632  run:11134
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 4030  1.022474  0.000067  945.778818      592          0       0  11135
#
#       wfDCBits
# 4030         0
# AvsE:0.268  DCR:-0.00059  Energy:945.307  channel:592  run:11135
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 4058  0.999541  0.000221  1252.739151      648          0       0  11141
#
#       wfDCBits
# 4058         0
# AvsE:-0.640  DCR:-0.00061  Energy:1252.665  channel:648  run:11141
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 4112  0.998873 -0.000017  1166.816808      626          0       0  11153
#
#       wfDCBits
# 4112         0
# AvsE:-0.553  DCR:-0.00016  Energy:1165.845  channel:626  run:11153
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 4159  1.007363  0.000059  1061.641196      598          0       0  11160
#
#       wfDCBits
# 4159         0
# AvsE:0.160  DCR:-0.00030  Energy:1060.967  channel:598  run:11160
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 4265  0.98404  0.000539  507.779484      648          0       0  11183
#
#       wfDCBits
# 4265         0
# AvsE:-0.578  DCR:-0.00027  Energy:507.666  channel:648  run:11183
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 4275  0.996836 -0.000122  942.915396      632          0       0  11185
#
#       wfDCBits
# 4275         0
# ...
#
#       wfDCBits
# 6844         0
# AvsE:-0.276  DCR:-0.00029  Energy:1264.465  channel:578  run:13202
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6856  0.993595 -0.000454  523.669872      626          0       0  13205
#
#       wfDCBits
# 6856         0
# AvsE:0.602  DCR:-0.00015  Energy:523.468  channel:626  run:13205
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6877  1.004048  0.000072  504.728998      598          0       0  13209
#
#       wfDCBits
# 6877         0
# AvsE:0.161  DCR:-0.00023  Energy:504.710  channel:598  run:13209
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6896  1.011739  0.00008  867.005513      610          0       0  13212
#
#       wfDCBits
# 6896         0
# AvsE:0.631  DCR:-0.00008  Energy:866.622  channel:610  run:13212
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6920  0.999559 -0.000121  621.006508      582          0       0  13216
#
#       wfDCBits
# 6920         0
# AvsE:-0.469  DCR:-0.00037  Energy:620.881  channel:582  run:13216
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 6940  1.017817  0.000101  1010.219041      690          0       0  13219
#
#       wfDCBits
# 6940         0
# AvsE:1.121  DCR:-0.00034  Energy:1010.518  channel:690  run:13219
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6946  1.011112  0.000055  1353.41684      608          0       0  13219
#
#       wfDCBits
# 6946         0
# AvsE:0.243  DCR:-0.00023  Energy:1353.341  channel:608  run:13219
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 6956  1.046644  0.000208  1395.980505      690          0       0  13222
#
#       wfDCBits
# 6956         0
# AvsE:6.023  DCR:-0.00033  Energy:1396.441  channel:690  run:13222
#          AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6979  0.99297 -0.000979  968.404746      626          0       0  13225
#
#       wfDCBits
# 6979         0
# AvsE:0.484  DCR:-0.00030  Energy:968.039  channel:626  run:13225
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6980  1.000226  0.000022  823.038644      582          0       0  13225
#
#       wfDCBits
# 6980         0
# AvsE:-0.159  DCR:-0.00024  Energy:822.737  channel:582  run:13225
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 6990  1.010794  0.000001  833.281845      664          0       0  13227
#
#       wfDCBits
# 6990         0
# AvsE:0.180  DCR:-0.00032  Energy:833.516  channel:664  run:13227
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7004  1.011254  0.000189  1568.303091      690          0       0  13228
#
#       wfDCBits
# 7004         0
# AvsE:0.607  DCR:-0.00034  Energy:1568.406  channel:690  run:13228
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7007  0.992373 -0.000693  596.221076      626          0       0  13229
#
#       wfDCBits
# 7007         0
# AvsE:0.522  DCR:-0.00031  Energy:596.103  channel:626  run:13229
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7025  0.993525 -0.000761  735.986922      626          0       0  13231
#
#       wfDCBits
# 7025         0
# AvsE:0.557  DCR:-0.00031  Energy:735.682  channel:626  run:13231
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7055  0.994959 -0.000381  857.885901      608          0       0  13235
#
#       wfDCBits
# 7055         0
# AvsE:-0.231  DCR:-0.00067  Energy:857.426  channel:608  run:13235
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7067  0.989301 -0.000648  521.091129      626          0       0  13238
#
#       wfDCBits
# 7067         0
# AvsE:0.424  DCR:-0.00035  Energy:521.002  channel:626  run:13238
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7094  0.982776 -0.001121  1212.022724      626          0       0  13243
#
#       wfDCBits
# 7094         0
# AvsE:-0.465  DCR:-0.00019  Energy:1211.421  channel:626  run:13243
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7102  1.009026  0.00001  877.758848      690          0       0  13244
#
#       wfDCBits
# 7102         0
# AvsE:0.158  DCR:-0.00043  Energy:878.053  channel:690  run:13244
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7105  1.009888  0.000105  1202.234141      690          0       0  13244
#
#       wfDCBits
# 7105         0
# AvsE:0.251  DCR:-0.00034  Energy:1202.269  channel:690  run:13244
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7110  0.990233 -0.000683  672.736803      626          0       0  13245
#
#       wfDCBits
# 7110         0
# AvsE:0.399  DCR:-0.00031  Energy:672.471  channel:626  run:13245
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7113  0.986729 -0.001267  1328.500956      626          0       0  13245
#
#       wfDCBits
# 7113         0
# AvsE:-0.148  DCR:-0.00021  Energy:1327.693  channel:626  run:13245
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7117  0.982896 -0.000789  799.086045      626          0       0  13246
#
#       wfDCBits
# 7117         0
# AvsE:-0.099  DCR:-0.00026  Energy:798.774  channel:626  run:13246
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7129  1.013117  0.000013  1068.471295      664          0       0  13247
#
#       wfDCBits
# 7129         0
# AvsE:0.397  DCR:-0.00034  Energy:1068.875  channel:664  run:13247
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7160  0.989773 -0.000702  555.574146      626          0       0  13253
#
#       wfDCBits
# 7160         0
# AvsE:0.427  DCR:-0.00036  Energy:555.444  channel:626  run:13253
#          AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7167  1.04833  0.00009  596.626086      582          0       0  13255
#
#       wfDCBits
# 7167         0
# AvsE:3.254  DCR:-0.00015  Energy:596.657  channel:582  run:13255
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7177  0.988956 -0.000624  720.011591      626          0       0  13257
#
#       wfDCBits
# 7177         0
# AvsE:0.302  DCR:-0.00020  Energy:719.817  channel:626  run:13257
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7189  0.992391 -0.000754  801.113962      626          0       0  13259
#
#       wfDCBits
# 7189         0
# AvsE:0.475  DCR:-0.00024  Energy:800.819  channel:626  run:13259
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7190  1.003252  0.000064  1033.907002      582          0       0  13259
#
#       wfDCBits
# 7190         0
# AvsE:-0.033  DCR:-0.00021  Energy:1033.590  channel:582  run:13259
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7192  0.999474 -0.000096  744.231824      582          0       0  13260
#
#       wfDCBits
# 7192         0
# AvsE:-0.064  DCR:-0.00038  Energy:743.965  channel:582  run:13260
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7214  1.013463  0.000121  779.966703      690          0       0  13264
#
#       wfDCBits
# 7214         0
# AvsE:0.601  DCR:-0.00030  Energy:780.148  channel:690  run:13264
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7222  0.990003 -0.000803  745.099363      626          0       0  13265
#
#       wfDCBits
# 7222         0
# AvsE:0.355  DCR:-0.00027  Energy:744.818  channel:626  run:13265
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7253  1.017461  0.000054  719.560712      690          0       0  13271
#
#       wfDCBits
# 7253         0
# AvsE:0.926  DCR:-0.00034  Energy:719.727  channel:690  run:13271
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7272  1.009246  0.00009  752.944997      690          0       0  13276
#
#       wfDCBits
# 7272         0
# AvsE:0.254  DCR:-0.00033  Energy:753.029  channel:690  run:13276
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7289  0.985742 -0.001698  1667.033586      626          0       0  13279
#
#       wfDCBits
# 7289         0
# AvsE:-0.416  DCR:-0.00035  Energy:1666.055  channel:626  run:13279
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7295  1.003252  0.000193  1507.519216      648          0       0  13281
#
#       wfDCBits
# 7295         0
# AvsE:-0.748  DCR:-0.00065  Energy:1507.340  channel:648  run:13281
#          AvsE      DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7301  1.00385  0.00003  1243.160402      648          0       0  13282
#
#       wfDCBits
# 7301         0
# AvsE:-0.753  DCR:-0.00081  Energy:1243.082  channel:648  run:13282
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7334  0.993364 -0.000932  788.550393      626          0       0  13306
#
#       wfDCBits
# 7334         0
# AvsE:0.536  DCR:-0.00042  Energy:788.740  channel:626  run:13306
#           AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7383  1.004221  0.00018  727.287796      608          0       0  13314
#
#       wfDCBits
# 7383         0
# AvsE:-0.079  DCR:-0.00009  Energy:727.376  channel:608  run:13314
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7385  1.010748  0.000029  1470.859531      610          0       0  13314
#
#       wfDCBits
# 7385         0
# AvsE:0.883  DCR:-0.00017  Energy:1470.519  channel:610  run:13314
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7397  0.998549 -0.000108  543.733805      582          0       0  13316
#
#       wfDCBits
# 7397         0
# AvsE:0.143  DCR:-0.00036  Energy:543.534  channel:582  run:13316
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7413  0.999873 -0.000085  674.017982      580          0       0  13317
#
#       wfDCBits
# 7413         0
# AvsE:0.607  DCR:-0.00029  Energy:674.020  channel:580  run:13317
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7424  0.999478 -0.000185  543.010395      580          0       0  13319
#
#       wfDCBits
# 7424         0
# AvsE:0.210  DCR:-0.00042  Energy:543.112  channel:580  run:13319
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7426  0.997623 -0.000199  623.824091      580          0       0  13320
#
#       wfDCBits
# 7426         0
# AvsE:0.137  DCR:-0.00039  Energy:623.937  channel:580  run:13320
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7429  1.001758  0.000017  792.594393      578          0       0  13320
#
#       wfDCBits
# 7429         0
# AvsE:0.309  DCR:-0.00018  Energy:792.382  channel:578  run:13320
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7431  0.978228 -0.000552  512.876535      626          0       0  13320
#
#       wfDCBits
# 7431         0
# AvsE:0.001  DCR:-0.00028  Energy:513.048  channel:626  run:13320
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7432  0.991708 -0.000773  877.655783      626          0       0  13320
#
#       wfDCBits
# 7432         0
# AvsE:0.413  DCR:-0.00016  Energy:877.859  channel:626  run:13320
#           AvsE      DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7463  1.006161  0.00009  1222.721189      690          0       0  13327
#
#       wfDCBits
# 7463         0
# AvsE:-0.254  DCR:-0.00038  Energy:1223.065  channel:690  run:13327
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7467  0.986732 -0.001397  1429.675056      626          0       0  13327
#
#       wfDCBits
# 7467         0
# AvsE:-0.209  DCR:-0.00028  Energy:1429.868  channel:626  run:13327
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 7494  1.003256  0.000004  717.74776      582          0       0  13332
#
#       wfDCBits
# 7494         0
# AvsE:0.327  DCR:-0.00026  Energy:717.535  channel:582  run:13332
#           AvsE      DCR    Energy  channel  isLNFill1  muVeto    run  wfDCBits
# 7537  0.979451 -0.00001  621.6475      672          0       0  13340         0
# AvsE:-0.985  DCR:-0.00015  Energy:621.891  channel:672  run:13340
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7538  0.989306 -0.000724  625.042024      626          0       0  13340
#
#       wfDCBits
# 7538         0
# AvsE:0.369  DCR:-0.00032  Energy:625.275  channel:626  run:13340
#          AvsE      DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7540  0.98542 -0.00106  1187.654171      626          0       0  13340
#
#       wfDCBits
# 7540         0
# AvsE:-0.200  DCR:-0.00020  Energy:1187.682  channel:626  run:13340
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7554  1.010321  0.000145  710.082399      690          0       0  13342
#
#       wfDCBits
# 7554         0
# AvsE:0.353  DCR:-0.00029  Energy:710.449  channel:690  run:13342
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7555  0.989546 -0.001139  1116.16179      626          0       0  13342
#
#       wfDCBits
# 7555         0
# AvsE:0.185  DCR:-0.00026  Energy:1116.324  channel:626  run:13342
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7564  0.990871 -0.000133  1007.437995      592          0       0  13344
#
#       wfDCBits
# 7564         0
# AvsE:-0.785  DCR:-0.00071  Energy:1006.575  channel:592  run:13344
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7569  1.007437  0.000026  958.172446      610          0       0  13345
#
#       wfDCBits
# 7569         0
# AvsE:0.118  DCR:-0.00017  Energy:957.961  channel:610  run:13345
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7570  1.052132  0.000048  2015.132311      580          0       0  13345
#
#       wfDCBits
# 7570         0
# AvsE:14.821  DCR:-0.00021  Energy:2013.757  channel:580  run:13345
#          AvsE      DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7580  1.20459  0.00001  654.043871      672          0       0  13346
#
#       wfDCBits
# 7580         0
# AvsE:9.414  DCR:-0.00017  Energy:654.764  channel:672  run:13346
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7581  1.009546  0.000047  828.635115      610          0       0  13347
#
#       wfDCBits
# 7581         0
# AvsE:0.371  DCR:-0.00013  Energy:828.668  channel:610  run:13347
#           AvsE       DCR      Energy  channel  isLNFill1  muVeto    run  \
# 7588  0.989766 -0.000784  633.624716      626          0       0  13348
#
#       wfDCBits
# 7588         0
# AvsE:0.388  DCR:-0.00037  Energy:633.840  channel:626  run:13348
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7612  1.005989  0.000129  1187.577673      690          0       0  13363
#
#       wfDCBits
# 7612         0
# AvsE:-0.277  DCR:-0.00035  Energy:1187.800  channel:690  run:13363
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7635  1.007227  0.000118  1033.680718      690          0       0  13366
#
#       wfDCBits
# 7635         0
# AvsE:-0.089  DCR:-0.00029  Energy:1034.074  channel:690  run:13366
#           AvsE       DCR       Energy  channel  isLNFill1  muVeto    run  \
# 7641  1.011192  0.000028  1062.346574      672          0       0  13368
#
#       wfDCBits
# 7641         0
# AvsE:0.337  DCR:-0.00014  Energy:1062.778  channel:672  run:13368
#           AvsE       DCR     Energy  channel  isLNFill1  muVeto    run  \
# 7643  1.005463  0.000058  894.97587      690          0       0  13368
#
#       wfDCBits
# 7643         0
# AvsE:-0.176  DCR:-0.00037  Energy:895.115  channel:690  run:13368
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 171   DCR: 196  Burst: 21
# Total swapped:  388
# Total mismatch:  3

# %%
graph = sns.JointGrid(x=np.array(energyList2), y=np.array(runList2), size=10, space=0.2)
graph.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph.x = np.array(energyList)
graph.y = np.array(runList)
graph.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph.ax_marg_y.set_axis_off()
_ = graph.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph.savefig('EventComparison_DS1.pdf')

# %%
graph2 = sns.JointGrid(x=np.array(energyList2), y=np.array(chList2), size=10, space=0.2)
graph2.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph2.x = np.array(energyList)
graph2.y = np.array(chList)
graph2.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph2.ax_marg_y.set_axis_off()
_ = graph2.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph2.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph2.set_axis_labels("Energy", "Channel", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph2.savefig('EventComparison_DS1_2.pdf')

# %%
graph3 = sns.JointGrid(x=np.array(energyListCut), y=np.array(runListCut), size=10, space=0.2)
graph3.plot_joint(plt.scatter, color='b', marker='x', label='Pass all cuts in new skim -- rejected in old skim')
graph3.x = np.array(energyListCut2)
graph3.y = np.array(runListCut2)
graph3.plot_joint(plt.scatter, color='r', marker='v', label='Pass all cuts in old skim -- rejected in new skim')
graph3.ax_marg_y.set_axis_off()
_ = graph3.ax_marg_x.hist(np.array(energyListCut), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph3.ax_marg_x.hist(np.array(energyListCut2), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph3.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS1 Event Comparison', fontsize=15)
plt.legend()
# graph3.savefig('EventCutComparison_DS1_2.pdf')

# %%
# Specific study for ROI
# Cut events in old but not in new for ROI
nCutROI1,nSwapROI1 = 0,0
chListCutROI1 = []
runListCutROI1 = []
energyListCutROI1 = []
nDC, nMu, nLN, nAvsE, nDCR = 0, 0, 0, 0, 0
for index, row in dfOldCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 2000 or row['Energy'] > 2200:
        continue
    if not dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        print 'Tagged',dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        continue
#     elif not dfNewCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
#         continue
#     elif row['channel'] == 594:
#         continue
    elif not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy','LocalTime'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values != 0 or dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= -1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'Swapped -- AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        nSwapROI1 += 1
        chListCutROI1.append(row['channel'])
        runListCutROI1.append(row['run'])
        energyListCutROI1.append(row['Energy'])        
        continue
#     elif row['run'] in dfNewCut['run'].values and row['channel'] in dfNewCut['channel'].values:
    else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'])

        nCutROI1 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d"%(nLN, nMu, nDC, nAvsE, nDCR)
print "Total swapped: ", nSwapROI1
print "Total mismatch: ", nCutROI1
# Out:
# Tagged         AvsE   ClockTime      DCR                 Date       DateSec  \
# 65  0.831066  486.961264 -0.00031  2016-01-14 02:11:29  1.452737e+09
#
#          Energy   LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 65  2115.667791  485.696195  2113.916807      610    5254       1          0
#
#     isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 65          0   1    1       0  9472         0
# Tagged          AvsE    ClockTime       DCR                 Date       DateSec  \
# 164  4.322209  1542.481931 -0.000296  2016-01-15 07:30:18  1.452843e+09
#
#           Energy   LocalTime      OEnergy  channel  iEvent  isGood  isLNFill1  \
# 164  2083.352154  1541.57835  2086.481001      582   14210       1          0
#
#      isLNFill2  mH  mHL  muVeto   run  wfDCBits
# 164          0   1    1       0  9544         0
# Tagged          AvsE    ClockTime       DCR                 Date       DateSec  \
# 1826  1.92981  1074.323333 -0.000396  2016-02-12 14:12:03  1.455286e+09
#
#            Energy    LocalTime      OEnergy  channel  iEvent  isGood  \
# 1826  2167.108407  1070.913101  2167.544362      582    8717       1
#
#       isLNFill1  isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 1826          0          0   1    1       0  10614         0
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 2967 -1.444929 -0.000418  2118.99211      632    2091       1          0
#
#       isLNFill2  mH  mHL  muVeto    run  wfDCBits
# 2967          0   1    1       0  10712         0
# Swapped -- AvsE:1.001  DCR:-0.00010  Energy:2119.479  channel:632  run:10712
# Untagged - run: 12576  channel: 608  Energy: 2116.310  AvsE: 1.009  DCR: -0.00011
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 1   DCR: 0
# Total swapped:  1
# Total mismatch:  1

# %%
# Specific study for ROI
# Cut events not rejected in new skim in ROI
nCutROI2,nSwapROI2 = 0,0
chListCutROI2 = []
runListCutROI2 = []
energyListCutROI2 = []
nDC, nMu, nLN, nAvsE, nDCR, nBurst = 0, 0, 0, 0, 0, 0
for index, row in dfNewCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 2000 or row['Energy'] > 2200:
        continue
    if not dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        print 'Tagged',dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        continue
#     elif not dfOldCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
#         continue
#     elif row['channel'] == 594:
#         continue
    elif not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
        print dfTemp.drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        if 7370e3<dfTemp['ClockTime'].values<7371e3 or 2192e3<dfTemp['ClockTime'].values<2195e3 or 7840e3<dfTemp['ClockTime'].values<7860e3:
            nBurst += 1
        elif 8384e3<dfTemp['ClockTime'].values<8387e3 or 8984e3<dfTemp['ClockTime'].values<8985e3 or 9002e3<dfTemp['ClockTime'].values<9005e3:
            nBurst += 1
        elif dfTemp['isLNFill1'].values != 0:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= 1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'Swapped -- AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCutROI2.append(row['channel'])
        runListCutROI2.append(row['run'])
        energyListCutROI2.append(row['Energy'])
        nSwapROI2 += 1
        continue
#     elif row['run'] in dfOldCut['run'].values and row['channel'] in dfOldCut['channel'].values:
    else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCutROI2 += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d  Burst: %d"%(nLN, nMu, nDC, nAvsE, nDCR, nBurst)
print "Total swapped: ", nSwapROI2
print "Total mismatch: ", nCutROI2
# Out:
# Tagged         AvsE     ClockTime     DCR                 Date       DateSec  \
# 48  1.008293  1.765979e+06 -0.0002  2016-02-03 12:36:22  1.454503e+09
#
#         Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 48  2116.66422  2114.141063      610       1          0   1       0  9472
#
#     wfDCBits
# 48         0
# Tagged          AvsE     ClockTime       DCR                 Date       DateSec  \
# 132  1.029238  1.871507e+06 -0.000122  2016-02-05 22:56:24  1.454713e+09
#
#           Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto   run  \
# 132  2082.581969  2085.885625      582       1          0   1       0  9544
#
#      wfDCBits
# 132         0
# Tagged           AvsE     ClockTime      DCR                 Date       DateSec  \
# 1564  1.006712  4.314815e+06 -0.00023  2016-04-02 12:27:48  1.459600e+09
#
#            Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto    run  \
# 1564  2167.128093  2166.833404      582       1          0   1       0  10614
#
#       wfDCBits
# 1564         0
#           AvsE       DCR       Energy  channel  isGood  isLNFill1  mH  muVeto  \
# 7570  1.052132  0.000048  2015.132311      580       1          0   1       0
#
#         run  wfDCBits
# 7570  13345         0
# Swapped -- AvsE:14.821  DCR:-0.00021  Energy:2013.757  channel:580  run:13345
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 0   DCR: 1  Burst: 0
# Total swapped:  1
# Total mismatch:  0

# %%
print dfOldCut.query('run==12576 and 2000<Energy<2200 and channel==608')
print dfNewFull.query('run==12576 and 2000<Energy<2200 and channel==608')
# Out:
#           AvsE     ClockTime       DCR                 Date       DateSec  \
# 3142  1.008654  7.452911e+06 -0.000107  2016-06-14 03:54:41  1.465876e+09
#
#            Energy      OEnergy  channel  isGood  isLNFill1  mH  muVeto    run  \
# 3142  2116.309623  2114.295972      608       1          0   1       0  12576
#
#       wfDCBits
# 3142         0
# Empty DataFrame
# Columns: [AvsE, ClockTime, DCR, Date, DateSec, Energy, LocalTime, OEnergy, channel, iEvent, isGood, isLNFill1, isLNFill2, mH, mHL, muVeto, run, wfDCBits]
# Index: []
