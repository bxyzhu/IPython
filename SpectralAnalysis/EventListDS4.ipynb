# %%
# Event list comparison
import numpy as np
import pandas as pd

# pd.options.display.max_rows = 999

import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load files
extDir = '/Users/brianzhu/macros/code/MJDAnalysis/ROI/'
dfNew = pd.read_csv(extDir+'NewList_DS4_full.csv', sep=',', index_col=0)
dfOld = pd.read_csv(extDir+'OldList_DS4_full.csv', sep=',', index_col=0)

dfNewCut = pd.read_csv(extDir+'NewList_DS4_allcuts.csv', sep=',', index_col=0)
dfOldCut = pd.read_csv(extDir+'OldList_DS4_allcuts.csv', sep=',', index_col=0)

dfNewFull = pd.read_csv(extDir+'NewList_DS4_nocuts.csv', sep=',', index_col=0)
dfOldFull = pd.read_csv(extDir+'OldList_DS4_nocuts.csv', sep=',', index_col=0)

# %%
print dfNew.shape[0],dfNewCut.shape[0]
dfNew.head(10)
# Out:
# 1229 941
#        AvsE     ClockTime       DCR                 Date       DateSec  \
# 0 -0.029045   6907.211937 -0.005146  2016-08-26 00:02:46  1.472170e+09
# 1  0.129406   8648.263723 -0.000354  2016-08-26 00:31:47  1.472172e+09
# 2 -0.526015  10356.496212 -0.000179  2016-08-26 01:00:15  1.472173e+09
# 3 -0.772978  10682.697275 -0.000137  2016-08-26 01:05:41  1.472174e+09
# 4  0.004767  11186.666847 -0.000304  2016-08-26 01:14:05  1.472174e+09
# 5  0.476789  12478.539542 -0.000147  2016-08-26 01:35:37  1.472175e+09
# 6  0.517713  13335.782929 -0.000392  2016-08-26 01:49:54  1.472176e+09
# 7 -1.226529  15215.550549 -0.000548  2016-08-26 02:21:14  1.472178e+09
# 8 -0.083997  15384.159271 -0.000287  2016-08-26 02:24:03  1.472178e+09
# 9  0.507364  15455.752346 -0.000283  2016-08-26 02:25:14  1.472178e+09
#
#        Energy    LocalTime     OEnergy  channel  iEvent  isGood  isLNFill1  \
# 0  223.998607   127.021828  224.067205     1296    6278       1          0
# 1  406.974421  1868.073613  406.886603     1176   85229       1          0
# 2  776.337304  3576.306102  776.472677     1298  170168       1          0
# 3  557.894571   300.637075  557.907799     1298   14317       1          0
# 4  435.919884   804.606647  436.259572     1332   38879       1          0
# 5  192.579342  2096.479342  192.554608     1298  102090       1          0
# 6  840.611342  2953.722729  839.944255     1332  147390       1          0
# 7  743.911301  1230.545906  744.661801     1332   65065       1          0
# 8  174.061755  1399.154628  174.172089     1332   74189       1          0
# 9  476.318505  1470.747704  476.486569     1236   78293       1          0
#
#    isLNFill2  mH  mHL  muVeto       run  wfDCBits
# 0          1   1    1       0  60000802         0
# 1          0   1    1       0  60000802         0
# 2          0   1    1       0  60000802         0
# 3          0   1    1       0  60000803         0
# 4          0   1    1       0  60000803         0
# 5          0   1    1       0  60000803         0
# 6          0   1    1       0  60000803         0
# 7          0   1    1       0  60000804         0
# 8          0   1    1       0  60000804         0
# 9          0   1    1       0  60000804         0

# %%
print dfOld.shape[0], dfOldCut.shape[0]
dfOld.head(10)
# Out:
# 1512 1119
#        AvsE     ClockTime       DCR                 Date       DateSec  \
# 0 -0.009744   6948.211937 -0.000407  2016-08-26 01:55:48  1.472177e+09
# 1  0.264772   8689.263723 -0.000156  2016-08-26 02:24:49  1.472178e+09
# 2 -0.500852  10397.496212 -0.000092  2016-08-26 02:53:17  1.472180e+09
# 3 -0.614666  14324.697275 -0.000049  2016-08-26 03:58:44  1.472184e+09
# 4 -0.107760  14828.666847 -0.000105  2016-08-26 04:07:08  1.472184e+09
# 5  0.570695  16120.539542 -0.000058  2016-08-26 04:28:40  1.472186e+09
# 6  0.487255  16977.782929 -0.000184  2016-08-26 04:42:57  1.472187e+09
# 7 -1.323683  22459.550549 -0.000343  2016-08-26 06:14:19  1.472192e+09
# 8 -0.232344  22628.159271 -0.000094  2016-08-26 06:17:08  1.472192e+09
# 9  0.458637  22699.752346 -0.000150  2016-08-26 06:18:19  1.472192e+09
#
#        Energy     OEnergy  channel  iEvent  isGood  isLNFill1  isLNFill2  mH  \
# 0  224.055584  223.957791     1296       1       1          0          0   1
# 1  406.894789  406.741528     1176       1       1          0          0   1
# 2  776.417366  776.436048     1298       1       1          0          0   1
# 3  557.944578  557.925747     1298       1       1          0          0   1
# 4  436.114620  436.277310     1332       1       1          0          0   1
# 5  192.587528  192.590218     1298       1       1          0          0   1
# 6  840.481931  839.998256     1332       1       1          0          0   1
# 7  744.257817  744.763226     1332       1       1          0          0   1
# 8  174.077517  174.107262     1332       1       1          0          0   1
# 9  476.267064  476.420047     1236       1       1          0          0   1
#
#    muVeto       run  wfDCBits
# 0       0  60000802         0
# 1       0  60000802         0
# 2       0  60000802         0
# 3       0  60000803         0
# 4       0  60000803         0
# 5       0  60000803         0
# 6       0  60000803         0
# 7       0  60000804         0
# 8       0  60000804         0
# 9       0  60000804         0

# %%
# In old but not in new
print "In old but not in new"
n = 0
chList0 = []
runList0 = []
energyList0 = []
chList = []
runList = []
energyList = []
for index, row in dfOld.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfNew.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif row['run'] in dfNew['run'].values and row['channel'] in dfNew['channel'].values: 
#     else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['ClockTime'])
        chList.append(row['channel'])
        runList.append(row['run'])
        energyList.append(row['Energy'])
        n += 1
print "Total mismatched events: ", n
# Out:
# In old but not in new
# run: 60000811  channel: 1296  Energy: 260.434  AvsE: -1.248  DCR: -14.99043  ClockTime: 75072.62
# run: 60001662  channel: 1332  Energy: 161.895  AvsE: -0.257  DCR: -0.00007  ClockTime: 2369813.93
# Total mismatched events:  2

# %%
# In new but not in old
print "In new but not in old"
n2 = 0
chList2 = []
runList2 = []
energyList2 = []
for index, row in dfNew.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfOld.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
#     elif row['run'] in dfOld['run'].values and row['channel'] in dfOld['channel'].values:
    else:
        print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f  ClockTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'], row['ClockTime'])
        chList2.append(row['channel'])
        runList2.append(row['run'])
        energyList2.append(row['Energy'])
        n2 += 1
print "Total mismatch: ", n2
# Out:
# In new but not in old
# run: 60001463  channel: 1296  Energy: 406.780  AvsE: -0.003  DCR: -0.00502 LocalTime: 3562.51  ClockTime: 219952.85
# run: 60001601  channel: 1172  Energy: 220.400  AvsE: 0.320  DCR: -0.00048 LocalTime: 1543.90  ClockTime: 16168.09
# run: 60001661  channel: 1332  Energy: 161.952  AvsE: -0.112  DCR: -0.00026 LocalTime: 3604.89  ClockTime: 232385.93
# Total mismatch:  3

# %%
# Since mismatched events, look in full file
# In new but not in old
nfull1 = 0
chListfull1 = []
runListfull1 = []
energyListfull1 = []
for run,channel,energy in zip(runList, chList, energyList):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).empty:
        print dfNewFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    if not dfNewFull.query(cut+'and %.3f<OEnergy<%.3f'%(energy-5,energy+5)).empty:
        print dfNewFull.query(cut+'and %.3f<OEnergy<%.3f'%(energy-5,energy+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfNewFull['run'].values and channel in dfNewFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull1.append(row['channel'])
        runListfull1.append(row['run'])
        energyListfull1.append(row['Energy'])
        nfull1 += 1
print "Total mismatch: ", nfull1
# Out:
# Mismatched events -- run: 60000811  channel: 1296  Energy: 260.434
# Mismatched events -- run: 60001662  channel: 1332  Energy: 161.895
# Total mismatch:  2

# %%
# Since mismatched events, look in full file
# In new but not in old
nfull = 0
chListfull = []
runListfull = []
energyListfull = []
for run,channel,energy in zip(runList2, chList2, energyList2):
    cut = 'run==%d and channel==%d'%(run, channel)
    if not dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).empty:
        print 'Found events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        print dfOldFull.query(cut+'and %.3f<Energy<%.3f'%(energy-5,energy+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        continue
    elif run in dfOldFull['run'].values and channel in dfOldFull['channel'].values:
#         print 'run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        print 'Mismatched events -- run: %d  channel: %d  Energy: %.3f'%(run, channel, energy)
        chListfull.append(row['channel'])
        runListfull.append(row['run'])
        energyListfull.append(row['Energy'])
        nfull += 1
print "Total mismatch: ", nfull
# Out:
# Found events -- run: 60001463  channel: 1296  Energy: 406.780
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 3502 -0.002519 -0.000292  406.743001     1296       1       1          0
#
#       isLNFill2  mH  muVeto       run  wfDCBits
# 3502          0   2       0  60001463         0
# Found events -- run: 60001601  channel: 1172  Energy: 220.400
#           AvsE       DCR     Energy  channel  iEvent  isGood  isLNFill1  \
# 3787  0.351278 -0.000266  220.14073     1172       1       1          0
#
#       isLNFill2  mH  muVeto       run  wfDCBits
# 3787          0   2       0  60001601         0
# Mismatched events -- run: 60001661  channel: 1332  Energy: 161.952
# Total mismatch:  1

# %%
# Cut events in old but not in new
nCut2,nSwap2 = 0,0
chListCut2 = []
runListCut2 = []
energyListCut2 = []
for index, row in dfOldCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 500:
        continue
    if not dfNewCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfNewCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif not dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfNew.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy','LocalTime'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values == 1:
            print 'Cut by LN'
        elif dfTemp['AvsE'].values >= -1:
            print 'Cut by AvsE'
        elif dfTemp['DCR'].values >= 0.:
            print 'Cut by DCR'
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCut2.append(row['channel'])
        runListCut2.append(row['run'])
        energyListCut2.append(row['Energy'])
        nSwap2 += 1
        continue
    elif row['run'] in dfNewCut['run'].values and row['channel'] in dfNewCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCut2 += 1
print "Total swapped: ", nSwap2
print "Total mismatch: ", nCut2
# Out:
#        AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 82  0.77714 -0.000211  1354.20002     1204   39928       1          0
#
#     isLNFill2  mH  mHL  muVeto       run  wfDCBits
# 82          1   1    1       0  60000977         0
# Cut by LN
# AvsE:0.984  DCR:-0.00009  Energy:1354.253  channel:1204  run:60000977
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 998  0.107057 -0.000555  566.624582     1172  254053       1          0
#
#      isLNFill2  mH  mHL  muVeto       run  wfDCBits
# 998          1   1    1       0  60001618         0
# Cut by LN
# AvsE:0.090  DCR:-0.00034  Energy:566.526  channel:1172  run:60001618
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 924 -0.004809 -0.000316  917.798567     1298    4768       1          0
#
#      isLNFill2  mH  mHL  muVeto       run  wfDCBits
# 924          1   1    1       0  60001534         0
# Cut by LN
# AvsE:-0.125  DCR:-0.00023  Energy:917.820  channel:1298  run:60001534
#           AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 1215 -0.796069 -0.000199  1250.748077     1298   72758       1          0
#
#       isLNFill2  mH  mHL  muVeto       run  wfDCBits
# 1215          1   1    1       0  60001710         0
# Cut by LN
# AvsE:-0.795  DCR:-0.00011  Energy:1250.737  channel:1298  run:60001710
# Total swapped:  4
# Total mismatch:  0

# %%
# Cut events not rejected in new skim
nCut,nSwap = 0,0
chListCut = []
runListCut = []
energyListCut = []
nDC, nMu, nLN, nAvsE, nDCR = 0, 0, 0, 0, 0
for index, row in dfNewCut.iterrows():
    cut = 'run==%d and channel==%d'%(row['run'],row['channel'])
    if row['Energy'] < 500:
        continue
    if not dfOldCut.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        continue
    elif not dfOldCut.query(cut+'and %.3f<OEnergy<%.3f'%(row['OEnergy']-5,row['OEnergy']+5)).empty:
        continue
    elif not dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).empty:
        dfTemp = dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5)).drop(['DateSec','Date','ClockTime','OEnergy'], axis=1)
        print dfTemp
        if dfTemp['isLNFill2'].values == 1 or dfTemp['isLNFill1'].values == 1:
            nLN += 1
        elif dfTemp['muVeto'].values != 0:
            nMu += 1
        elif dfTemp['wfDCBits'].values != 0:
            nDC += 1
        elif dfTemp['AvsE'].values <= -1:
            nAvsE += 1
        elif dfTemp['DCR'].values >= 0.:
            nDCR += 1
        print 'AvsE:%.3f  DCR:%.5f  Energy:%.3f  channel:%d  run:%d'%(row['AvsE'], row['DCR'], row['Energy'], row['channel'], row['run'])
        chListCut.append(row['channel'])
        runListCut.append(row['run'])
        energyListCut.append(row['Energy'])
        nSwap += 1
        continue
    elif row['run'] in dfOldCut['run'].values and row['channel'] in dfOldCut['channel'].values:
#     else:
        print 'Untagged - run: %d  channel: %d  Energy: %.3f  AvsE: %.3f  DCR: %.5f LocalTime: %.2f'%(row['run'], row['channel'], row['Energy'], row['AvsE'], row['DCR'], row['LocalTime'])
        nCut += 1
print "Cut by LNFill: %d   muVeto: %d   wfDCBits: %d   AvsE: %d   DCR: %d"%(nLN, nMu, nDC, nAvsE, nDCR)
print "Total swapped: ", nSwap
print "Total mismatch: ", nCut
# Out:
#         AvsE      DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 62  5.807977  0.00003  1175.978045     1298       1       1          0
#
#     isLNFill2  mH  muVeto       run  wfDCBits
# 62          0   1       0  60000821         0
# AvsE:7.545  DCR:-0.00006  Energy:1175.851  channel:1298  run:60000821
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 127 -0.225015  0.000074  669.504727     1298       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 127          0   1       0  60000998         0
# AvsE:-0.223  DCR:-0.00001  Energy:669.439  channel:1298  run:60000998
#         AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 138 -0.34993  0.000032  1012.313427     1298       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 138          0   1       0  60000999         0
# AvsE:-0.264  DCR:-0.00006  Energy:1012.206  channel:1298  run:60000999
#          AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 223  0.468207  0.000082  1313.932626     1298       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 223          0   1       0  60001051         0
# AvsE:0.802  DCR:-0.00001  Energy:1313.725  channel:1298  run:60001051
#          AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 227  8.889037  0.000044  1032.978934     1236       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 227          0   1       0  60001054         0
# AvsE:9.339  DCR:-0.00009  Energy:1033.029  channel:1236  run:60001054
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 268  2.951892  0.000008  975.711049     1204       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 268          0   1       0  60001070         0
# AvsE:2.501  DCR:-0.00011  Energy:975.580  channel:1204  run:60001070
#         AvsE      DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 309  0.03186  0.00003  705.433636     1298       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 309          0   1       0  60001085         0
# AvsE:0.116  DCR:-0.00006  Energy:705.361  channel:1298  run:60001085
#          AvsE       DCR     Energy  channel  iEvent  isGood  isLNFill1  \
# 401  0.775366  0.000022  771.56603     1204       0       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 401          0   1       0  60001103         0
# AvsE:0.581  DCR:-0.00009  Energy:771.647  channel:1204  run:60001103
#          AvsE      DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 528 -0.374316  0.00099  1379.198187     1296       0       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 528          0   1       0  60001124         0
# AvsE:-0.373  DCR:-0.00372  Energy:1378.906  channel:1296  run:60001124
#          AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 350 -0.215332  0.000032  1002.472098     1172       0       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 350          0   1       0  60001188         0
# AvsE:-0.164  DCR:-0.00019  Energy:1002.846  channel:1172  run:60001188
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 408  3.532571  0.000053  880.481671     1236       0       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 408          0   1       0  60001199         0
# AvsE:3.746  DCR:-0.00008  Energy:880.490  channel:1236  run:60001199
#          AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 609  0.016149  0.000016  1125.999247     1176       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 609          0   1       0  60001389         0
# AvsE:0.085  DCR:-0.00018  Energy:1126.146  channel:1176  run:60001389
#          AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 902  0.514974  0.000032  508.642612     1298       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 902          0   1       0  60001498         0
# AvsE:0.627  DCR:-0.00006  Energy:508.679  channel:1298  run:60001498
#          AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 995  4.920377  0.000029  1286.025679     1204       1       1          0
#
#      isLNFill2  mH  muVeto       run  wfDCBits
# 995          0   1       0  60001630         0
# AvsE:4.223  DCR:-0.00009  Energy:1285.431  channel:1204  run:60001630
#           AvsE       DCR      Energy  channel  iEvent  isGood  isLNFill1  \
# 1149 -0.469584  0.000032  981.528793     1332       1       1          0
#
#       isLNFill2  mH  muVeto       run  wfDCBits
# 1149          0   1       0  60001672         0
# AvsE:-0.440  DCR:-0.00017  Energy:982.082  channel:1332  run:60001672
#           AvsE       DCR       Energy  channel  iEvent  isGood  isLNFill1  \
# 1165 -0.773345  0.000009  1097.312871     1176       1       1          0
#
#       isLNFill2  mH  muVeto       run  wfDCBits
# 1165          0   1       0  60001674         0
# AvsE:-0.894  DCR:-0.00019  Energy:1096.545  channel:1176  run:60001674
# Cut by LNFill: 0   muVeto: 0   wfDCBits: 0   AvsE: 0   DCR: 16
# Total swapped:  16
# Total mismatch:  0

# %%
dfOld.query(cut+'and %.3f<Energy<%.3f'%(row['Energy']-5,row['Energy']+5))
# Out:
#           AvsE     ClockTime       DCR                 Date       DateSec  \
# 1371  1.771443  2.736274e+06 -0.000025  2016-09-26 16:04:34  1.474906e+09
#
#           Energy     OEnergy  channel  iEvent  isGood  isLNFill1  isLNFill2  \
# 1371  169.660276  169.752593     1204       1       1          0          0
#
#       mH  muVeto       run  wfDCBits
# 1371   1       0  60001714         0

# %%
graph = sns.JointGrid(x=np.array(energyList2), y=np.array(runList2), size=10, space=0.2)
graph.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph.x = np.array(energyList)
graph.y = np.array(runList)
graph.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph.ax_marg_y.set_axis_off()
_ = graph.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS4 Event Comparison', fontsize=15)
plt.legend()
# graph.savefig('EventComparison_DS4.pdf')

# %%
graph2 = sns.JointGrid(x=np.array(energyList2), y=np.array(chList2), size=10, space=0.2)
graph2.plot_joint(plt.scatter, color='b', marker='x', label='Not in old skim')
graph2.x = np.array(energyList)
graph2.y = np.array(chList)
graph2.plot_joint(plt.scatter, color='r', marker='v', label='Not in new skim')
graph2.ax_marg_y.set_axis_off()
_ = graph2.ax_marg_x.hist(np.array(energyList2), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph2.ax_marg_x.hist(np.array(energyList), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph2.set_axis_labels("Energy", "Channel", fontsize=15)
plt.title('DS4 Event Comparison', fontsize=15)
plt.legend()
# graph2.savefig('EventComparison_DS4_2.pdf')

# %%
graph3 = sns.JointGrid(x=np.array(energyListCut), y=np.array(runListCut), size=10, space=0.2)
graph3.plot_joint(plt.scatter, color='b', marker='x', label='Pass all cuts in new skim -- rejected in old skim')
graph3.x = np.array(energyListCut2)
graph3.y = np.array(runListCut2)
graph3.plot_joint(plt.scatter, color='r', marker='v', label='Pass all cuts in old skim -- rejected in new skim')
graph3.ax_marg_y.set_axis_off()
_ = graph3.ax_marg_x.hist(np.array(energyListCut), color='b', alpha=0.5, bins=np.linspace(100, 3300, 80))
_ = graph3.ax_marg_x.hist(np.array(energyListCut2), color='r', alpha=0.5, bins=np.linspace(100, 3300, 80))
graph3.set_axis_labels("Energy", "Run", fontsize=15)
plt.title('DS4 Event Comparison', fontsize=15)
plt.legend()
# graph3.savefig('EventCutComparison_DS4.pdf')
