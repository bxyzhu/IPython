# %%
import numpy as np
import pandas as pd
import glob

# Set print options so Pandas shows a lot of stuff!
# pd.options.display.width = 999
# pd.options.display.max_rows = 999
# pd.options.display.max_columns = 999

# visualization
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid') # Style style so background is white

# %%
# Read in DS0 External Pulser Files -- Ch624 and Ch688
extDir = '/Users/brianzhu/project/Pandas/ForceTrigger'
sigFiles = glob.glob('%s/latSkimDS0_run72*.h5' % extDir)
dfSigFull = pd.DataFrame()
sigList = []
for file in sigFiles:
    print(file)
    dfDummy = pd.read_hdf(file,'skimTree')
    sigList.append(dfDummy)

dfSigFull = pd.concat(sigList)
dfSigFull.head()
# Out:
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7238.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7239.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7240.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7241.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7242.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7243.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7244.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7250.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7251.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7252.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7253.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7254.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7255.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7256.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS0_run7257.h5
#      C    bandMax  bandTime       bcMax       bcMin  channel        den10  \
# 0  1.0  39.434251   10100.0  399.728008  245.751146    624.0  9673.330711
# 1  1.0  39.301239   10090.0  444.433538  225.906266    624.0  9657.767812
# 2  1.0  40.053721   10090.0  500.491057  255.908987    624.0  9663.999893
# 3  1.0  39.199651   10080.0  389.936179  257.513630    624.0  9672.812473
# 4  1.0  39.150821   10110.0  418.698311  246.170113    624.0  9694.809043
#
#          den50         den90   derivMax     ...      trapENMCal  \
# 0  9800.096284  10039.575915  52.920119     ...       21.424156
# 1  9787.441418  10039.332668  53.266500     ...       21.565236
# 2  9789.627640  10013.413052  53.199570     ...       21.537975
# 3  9795.681627  10014.591145  53.208878     ...       21.541767
# 4  9821.111276  10053.163706  53.618902     ...       21.708769
#
#    trapENMSample  triggerTrapt0        waveS0     waveS1      waveS2  \
# 0         1525.0    6078.201582  12973.446235  72.040276  798.694930
# 1         1521.0    6045.825839  13004.873357  73.745833  799.983960
# 2         1509.0    6071.494214  13040.375247  98.498032  808.167085
# 3         1494.0    6051.816543  13046.127839  68.218610  787.478830
# 4         1437.0    6086.569968  13092.739480  65.592449  770.225419
#
#         waveS3       waveS4       waveS5       wpar4
# 0  6425.600834  5677.110196  2450.922774  213.656008
# 1  6462.396693  5668.746872  2410.276246  216.211289
# 2  6442.317166  5691.392965  2593.577844  210.920976
# 3  6472.577935  5717.852464  2421.943131  212.393408
# 4  6551.149438  5705.772174  2478.152661  213.831483
#
# [5 rows x 46 columns]

# %%
# Read in DS1 Force Trigger files
# Use Ch 626 (same as Ch 624 in DS0)
inDir = '/Users/brianzhu/project/Pandas/ForceTrigger'
bkgFiles = glob.glob('%s/latSkimDS1_run99*.h5' % inDir)
dfBkgFull = pd.DataFrame()
bkgList = []
for file in bkgFiles:
    print(file)
    dfDummy = pd.read_hdf(file,'skimTree')
    bkgList.append(dfDummy)

dfBkgFull = pd.concat(bkgList)
dfBkgFull.head()
# Out:
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9913.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9914.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9915.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9916.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9917.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9918.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9919.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9920.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9921.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9922.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9923.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9925.h5
# /Users/brianzhu/project/Pandas/ForceTrigger/latSkimDS1_run9926.h5
#      C      bandMax  bandTime        bcMax       bcMin  channel         den10  \
# 0  1.0   388.449312   20040.0  1607.979354  234.418748    582.0    510.620169
# 1  1.0  1277.436624   17390.0  1482.874413  232.365326    582.0  16983.429505
# 2  1.0   387.343933   20040.0  1558.992225  243.870622    582.0   1004.005732
# 3  1.0  1276.603449   17370.0  1652.389624  240.185818    582.0  16964.763584
# 4  1.0   386.626336   20040.0  1465.272541  221.771236    582.0     89.751928
#
#           den50         den90     derivMax     ...       trapENMCal  \
# 0   2267.848049   2716.572135     0.018621     ...        -0.093654
# 1  17102.357414  17325.769878  1385.085856     ...       527.641894
# 2   1077.392320   1168.061146     0.356527     ...         0.035094
# 3  17083.872210  17307.221102  1392.545699     ...       530.484228
# 4   1239.005546   1362.576305     0.139745     ...        -0.047504
#
#    trapENMSample  triggerTrapt0         waveS0     waveS1     waveS2  \
# 0         1045.0    6488.439727  131202.280181  76.464425  71.101300
# 1         2015.0    5320.954462  130811.997177  69.316035  57.086466
# 2         1493.0    5572.469465  131109.224822  67.619383  62.712298
# 3         2015.0    1635.523960  131625.998246  54.170793  84.379260
# 4         1369.0    1868.666813  130630.308954  65.387341  81.944849
#
#       waveS3         waveS4       waveS5        wpar4
# 0  67.021414  130987.693042  3320.631400  6713.585160
# 1  71.513395  130614.081281  3184.872662  6726.820387
# 2  71.638637  130907.254504  3259.819474  6712.105716
# 3  70.817901  131416.630293  3385.728430  6720.664564
# 4  70.673332  130412.303431  3181.726580  6726.215601
#
# [5 rows x 46 columns]

# %%
# Read in Data files from DS1
bkgDir = '/Users/brianzhu/project/Pandas/bkg'
dataFiles = glob.glob('%s/latSkimDS1_*.h5' % bkgDir)
dfDataFull = pd.DataFrame()
dataList = []
for file in dataFiles:
    print(file)
    dfDummy = pd.read_hdf(file,'skimTree')
    dataList.append(dfDummy)

dfDataFull = pd.concat(dataList)
dfDataFull.head()
# Out:
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_0_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_10_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_11_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_12_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_13_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_14_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_15_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_16_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_17_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_18_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_19_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_1_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_20_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_21_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_22_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_23_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_24_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_25_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_26_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_27_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_28_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_29_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_2_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_30_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_31_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_32_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_33_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_34_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_35_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_36_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_37_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_38_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_39_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_3_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_40_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_41_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_42_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_43_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_44_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_45_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_46_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_47_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_48_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_49_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_4_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_50_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_51_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_5_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_6_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_7_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_8_0.h5
# /Users/brianzhu/project/Pandas/bkg/latSkimDS1_9_0.h5
#      C     bandMax  bandTime       bcMax       bcMin  channel        den10  \
# 0  1.0    2.766155    7740.0  620.826494  223.516751    610.0  2611.782088
# 1  1.0    1.808499    7410.0  517.966244  227.208316    610.0   755.853616
# 2  1.0  261.980438   10360.0  415.357081  221.424401    664.0  9931.829532
# 3  1.0    2.262342    8410.0  558.248782  221.048426    610.0   565.932048
# 4  1.0    2.719122    8240.0  597.251129  219.963210    610.0  7057.807608
#
#           den50         den90    derivMax     ...       trapENMCal  \
# 0   6953.833612   7225.068764    2.755790     ...         1.029980
# 1   6393.875617   6695.708833    2.306465     ...         0.845375
# 2  10060.985268  10290.537490  351.588273     ...       144.389976
# 3   6262.776801   6897.771942    2.794474     ...         1.045874
# 4   7154.158030   7494.415540    3.191006     ...         1.208789
#
#    trapENMSample  triggerTrapt0        waveS0     waveS1       waveS2  \
# 0         1074.0    3871.068038    926.088386  62.338929   266.095183
# 1         1000.0    3392.474706    846.929977  97.137403   253.006325
# 2         1398.0    6188.592673  83630.462750  52.956809  2651.654945
# 3         1180.0    3246.918231    861.626568  60.004720   272.105451
# 4         1282.0    4077.801527   1019.618212  64.033599   270.633498
#
#          waveS3        waveS4       waveS5        wpar4
# 0    327.098873    270.555400  2256.783098    20.364431
# 1    281.416615    215.369634  2165.036599    15.325874
# 2  43234.290406  37691.560589  2025.307145  1403.743819
# 3    304.335953    225.180444  2289.147578    14.784373
# 4    382.031504    302.919611  2309.065641    17.790184
#
# [5 rows x 46 columns]

# %%
# Clean up datasets a little
# Determined that the cut to use to remove extra pulsers for FT run is oppie < 15 || TMath::IsNaN(oppie)
# First replace all NaN values in oppie with a dummy variable like -9999, this allows a cut like oppie < 15 to remove pulsers

# dfBkg.loc[:,'S5Cut'] = df1.loc[:,'waveS5'] / np.power(df1.loc[:,'trapENFCal'], 0.25)
# dfBkg = np.isnan(dfBkg.loc[:,'oppie'])

# inplace=True will replaces the values in the column with the new values
dfBkgFull['oppie'].fillna(-9999, inplace=True)
print (dfBkg.shape)

# Check for NaN -- those suck
print dfBkgFull.isnull().sum()
print dfSigFull.isnull().sum()
print dfDataFull.isnull().sum()
# Out:
# (180959, 46)
# C                0
# bandMax          0
# bandTime         0
# bcMax            0
# bcMin            0
# channel          0
# den10            0
# den50            0
# den90            0
# derivMax         0
# derivTime        0
# exp0             0
# exp1             0
# fails            0
# fitE             0
# fitMatch         0
# fitMax           0
# fitSlo           0
# kvorrT           0
# matchMax         0
# matchTime        0
# matchWidth       0
# oppie            0
# pol0             0
# pol1             0
# pol2             0
# raw10            0
# raw50            0
# raw90            0
# run              0
# tOffset          0
# threshKeV        0
# threshSigma      0
# trapENF          0
# trapENFCal       0
# trapENM          0
# trapENMCal       0
# trapENMSample    0
# triggerTrapt0    0
# waveS0           0
# waveS1           0
# waveS2           0
# waveS3           0
# waveS4           0
# waveS5           0
# wpar4            0
# dtype: int64
# C                0
# bandMax          0
# bandTime         0
# bcMax            0
# bcMin            0
# channel          0
# den10            0
# den50            0
# den90            0
# derivMax         0
# derivTime        0
# exp0             0
# exp1             0
# fails            0
# fitE             0
# fitMatch         0
# fitMax           0
# fitSlo           0
# kvorrT           0
# matchMax         0
# matchTime        0
# matchWidth       0
# oppie            0
# pol0             0
# pol1             0
# pol2             0
# raw10            0
# raw50            0
# raw90            0
# run              0
# tOffset          0
# threshKeV        0
# threshSigma      0
# trapENF          0
# trapENFCal       0
# trapENM          0
# trapENMCal       0
# trapENMSample    0
# triggerTrapt0    0
# waveS0           0
# waveS1           0
# waveS2           0
# waveS3           0
# waveS4           0
# waveS5           0
# wpar4            0
# dtype: int64
# C                0
# bandMax          0
# bandTime         0
# bcMax            0
# bcMin            0
# channel          0
# den10            0
# den50            0
# den90            0
# derivMax         0
# derivTime        0
# exp0             0
# exp1             0
# fails            0
# fitE             0
# fitMatch         0
# fitMax           0
# fitSlo           0
# kvorrT           0
# matchMax         0
# matchTime        0
# matchWidth       0
# oppie            0
# pol0             0
# pol1             0
# pol2             0
# raw10            0
# raw50            0
# raw90            0
# run              0
# tOffset          0
# threshKeV        0
# threshSigma      0
# trapENF          0
# trapENFCal       0
# trapENM          0
# trapENMCal       0
# trapENMSample    0
# triggerTrapt0    0
# waveS0           0
# waveS1           0
# waveS2           0
# waveS3           0
# waveS4           0
# waveS5           0
# wpar4            0
# dtype: int64

# %%
# The background DF is set, the signal DF is already good to go
dfBkgTest = dfBkgFull.query('oppie < 15 and channel==626')
dfSig = dfSigFull.query('channel==624')
dfData = dfDataFull.query('channel==626')
dfBkgTest.shape
print ('Force Trigger: ', dfBkgTest.shape)
print ('Ext Pulser: ', dfSig.shape)
print ('Data: ', dfData.shape)
print (dfSig.columns.values)
# Out:
# ('Force Trigger: ', (28035, 46))
# ('Ext Pulser: ', (18163, 46))
# ('Data: ', (1853, 46))
# ['C' 'bandMax' 'bandTime' 'bcMax' 'bcMin' 'channel' 'den10' 'den50' 'den90'
#  'derivMax' 'derivTime' 'exp0' 'exp1' 'fails' 'fitE' 'fitMatch' 'fitMax'
#  'fitSlo' 'kvorrT' 'matchMax' 'matchTime' 'matchWidth' 'oppie' 'pol0'
#  'pol1' 'pol2' 'raw10' 'raw50' 'raw90' 'run' 'tOffset' 'threshKeV'
#  'threshSigma' 'trapENF' 'trapENFCal' 'trapENM' 'trapENMCal'
#  'trapENMSample' 'triggerTrapt0' 'waveS0' 'waveS1' 'waveS2' 'waveS3'
#  'waveS4' 'waveS5' 'wpar4']

# %%
# Drop all columns that aren't useful for learning -- drop all time parameters since we don't trust them
dfBkgTest = dfBkgTest.drop(['C','channel','wpar4','bcMin','run','fails','bandTime','den10','den50','den90','derivTime','exp0','fitE','fitMatch','fitMax','kvorrT','pol0','raw10','raw50','raw90','threshKeV','threshSigma','trapENF','trapENM','trapENMCal','trapENMSample','triggerTrapt0','waveS0'], axis=1)
dfSig = dfSig.drop(['C','channel','wpar4','bcMin','run','fails','bandTime','den10','den50','den90','derivTime','exp0','fitE','fitMatch','fitMax','kvorrT','pol0','raw10','raw50','raw90','threshKeV','threshSigma','trapENF','trapENM','trapENMCal','trapENMSample','triggerTrapt0','waveS0'], axis=1)
dfData = dfData.drop(['C','channel','wpar4','bcMin','run','fails','bandTime','den10','den50','den90','derivTime','exp0','fitE','fitMatch','fitMax','kvorrT','pol0','raw10','raw50','raw90','threshKeV','threshSigma','trapENF','trapENM','trapENMCal','trapENMSample','triggerTrapt0','waveS0'], axis=1)

# Create array of parameter names to train on, remove trapENFCal (don't want to train on energy)
feat_cols = np.delete(dfBkgTest.columns.values, np.argwhere(dfBkgTest.columns.values=='trapENFCal' ))

# Add Column of zeros and ones for truth information
dfBkgTest['Truth'] = 'Force Trigger'
dfSig['Truth'] = 'Ext Pulser'
dfData['Truth'] = 'DS1 data'
print ("Columns: ", dfBkgTest.columns.values)
print ("Features to train on: ",feat_cols)
# Out:
# ('Columns: ', array(['bandMax', 'bcMax', 'derivMax', 'exp1', 'fitSlo', 'matchMax',
#        'matchTime', 'matchWidth', 'oppie', 'pol1', 'pol2', 'tOffset',
#        'trapENFCal', 'waveS1', 'waveS2', 'waveS3', 'waveS4', 'waveS5',
#        'Truth'], dtype=object))
# ('Features to train on: ', array(['bandMax', 'bcMax', 'derivMax', 'exp1', 'fitSlo', 'matchMax',
#        'matchTime', 'matchWidth', 'oppie', 'pol1', 'pol2', 'tOffset',
#        'waveS1', 'waveS2', 'waveS3', 'waveS4', 'waveS5'], dtype=object))

# %%
# Split up training data for testing
from sklearn.model_selection import train_test_split

TotalDF = pd.concat([dfBkgTest,dfSig,dfData])
TotalDF.head()
print (TotalDF.shape)

# Split it twice, first split creates development (with 66% of data) and evaluation set
# 2nd split is for training and testing the training
DF_dev, DF_eval = train_test_split(TotalDF, test_size=0.33, random_state=42)
DF_train, DF_test = train_test_split(DF_dev, test_size=0.33, random_state=492)

print(DF_dev.shape, DF_eval.shape, DF_train.shape, DF_test.shape)
print(DF_dev.columns.values)

# For sklearn, drop the Truth column for X, only save Truth for Y
# X is the data, Y is the target
X_dev = DF_dev.drop(['Truth', 'trapENFCal'], axis=1)
X_eval = DF_eval.drop(['Truth', 'trapENFCal'], axis=1)
X_train = DF_train.drop(['Truth', 'trapENFCal'], axis=1)
X_test = DF_test.drop(['Truth', 'trapENFCal'], axis=1)
Y_dev = DF_dev['Truth']
Y_eval = DF_eval['Truth']
Y_train = DF_train['Truth']
Y_test = DF_test['Truth']
print(X_dev.shape, X_eval.shape, X_train.shape, X_test.shape)
print(Y_dev.shape, Y_eval.shape, Y_train.shape, Y_test.shape)
print(X_dev.columns.values)
# Out:
# (48051, 19)
# ((32194, 19), (15857, 19), (21569, 19), (10625, 19))
# ['bandMax' 'bcMax' 'derivMax' 'exp1' 'fitSlo' 'matchMax' 'matchTime'
#  'matchWidth' 'oppie' 'pol1' 'pol2' 'tOffset' 'trapENFCal' 'waveS1'
#  'waveS2' 'waveS3' 'waveS4' 'waveS5' 'Truth']
# ((32194, 17), (15857, 17), (21569, 17), (10625, 17))
# ((32194,), (15857,), (21569,), (10625,))
# ['bandMax' 'bcMax' 'derivMax' 'exp1' 'fitSlo' 'matchMax' 'matchTime'
#  'matchWidth' 'oppie' 'pol1' 'pol2' 'tOffset' 'waveS1' 'waveS2' 'waveS3'
#  'waveS4' 'waveS5']

# %%
# Try PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
pca_result = pca.fit_transform(DF_dev.loc[:,feat_cols].values)
# pca_result = pca.fit_transform(X_dev)

DF_dev.loc[:,'pca-one'] = pd.Series(pca_result[:,0])
DF_dev.loc[:,'pca-two'] = pd.Series(pca_result[:,1])
DF_dev.loc[:,'pca-three'] = pd.Series(pca_result[:,2])
DF_dev.loc[:,'pca-four'] = pd.Series(pca_result[:,3])
DF_dev.loc[:,'pca-five'] = pd.Series(pca_result[:,4])
DF_dev.loc[:,'pca-six'] = pd.Series(pca_result[:,5])
DF_dev.loc[:,'pca-seven'] = pd.Series(pca_result[:,6])
DF_dev.loc[:,'pca-eight'] = pd.Series(pca_result[:,7])
DF_dev.loc[:,'pca-nine'] = pd.Series(pca_result[:,8])
DF_dev.loc[:,'pca-ten'] = pd.Series(pca_result[:,9])

print 'Explained variation per principal component: ',(pca.explained_variance_ratio_)
DF_dev.head()
# Out:
# Explained variation per principal component:  [  1.00000000e+00   8.50401303e-12   8.89014232e-14   7.97588449e-15
#    1.99361671e-16   5.04132350e-17   2.68533804e-17   1.77888370e-17
#    2.77002755e-18   1.45319076e-18]
#         bandMax       bcMax  derivMax          exp1      fitSlo  matchMax  \
# 13802  1.688348  272.497943  3.040524 -8.888800e+04  532.875000    -888.0
# 8499   1.205461  304.924517  0.000000  2.999637e+11   20.000000      -0.0
# 12406  1.307182  427.165944  2.862979 -8.888800e+04  513.840871    -888.0
# 14276  1.632210  519.858137  3.188191 -8.888800e+04  437.875000    -888.0
# 5280   1.315453  258.564879  3.541470 -8.888800e+04  495.624958    -888.0
#
#        matchTime  matchWidth        oppie          pol1     ...      \
# 13802     -888.0      -888.0    11.626033 -88888.000000     ...
# 8499         0.0      -888.0 -9999.000000     -0.000389     ...
# 12406     -888.0      -888.0    10.989970 -88888.000000     ...
# 14276     -888.0      -888.0    10.733844 -88888.000000     ...
# 5280      -888.0      -888.0    12.087622 -88888.000000     ...
#
#             pca-one       pca-two     pca-three     pca-four    pca-five  \
# 13802 -1.047678e+11 -32394.386536 -54568.302706   800.519896  359.629751
# 8499  -1.047679e+11 -32467.836886 -54560.177488   887.335909  309.454422
# 12406 -1.047680e+11 -34949.540915  71741.779407  -341.587137    1.599231
# 14276 -1.047679e+11 -31253.640748 -54690.357769 -2190.417449  285.397696
# 5280  -1.047679e+11 -32539.963062 -54558.193068   895.166085  292.362109
#
#           pca-six   pca-seven   pca-eight    pca-nine     pca-ten
# 13802 -532.043419 -612.170829 -422.282887  -12.408421   70.287859
# 8499  -632.774983 -648.324703 -428.142055   33.931995  -98.117735
# 12406  -38.398505   -8.810072   -0.147564   33.350364 -197.185726
# 14276 -669.439393 -668.052914 -466.612879 -115.501181  153.738550
# 5280  -551.758037 -657.167281 -417.540083  -27.692050 -119.978475
#
# [5 rows x 29 columns]

# %%
# Draw DF
d = sns.FacetGrid(DF_dev, hue="Truth", size=10)
d.map(plt.scatter, "pca-one", "pca-two").add_legend()

# %%
# Draw DF
d = sns.FacetGrid(DF_dev, hue="Truth", size=10)
d.map(plt.scatter, "pca-two", "pca-three").add_legend()

# %%
# Test to see if this slicing works for dataframes
DF_dev.loc[:,feat_cols].values[:7000].shape

print (DF_dev.loc[:,feat_cols].values[:7000])
print (DF_dev.iloc[:7000,:].values)
# Out:
# [[  1.68834752e+00   2.72497943e+02   3.04052443e+00 ...,   5.35537138e+02
#     7.40117307e+02   1.81412513e+03]
#  [  1.20546074e+00   3.04924517e+02   0.00000000e+00 ...,   6.14237730e+02
#     8.44092512e+02   1.99063665e+03]
#  [  1.30718217e+00   4.27165944e+02   2.86297939e+00 ...,   5.20347165e+02
#     7.27516818e+02   2.41393374e+03]
#  ...,
#  [  2.48543430e+01   4.19660722e+02   3.39398048e+01 ...,   4.06709078e+03
#     3.62253757e+03   2.56356969e+03]
#  [  1.15789782e+00   5.10389280e+02   3.30379488e+00 ...,   5.62904931e+02
#     7.83390798e+02   2.57161208e+03]
#  [  1.24442718e+00   2.87658142e+02   3.31079648e+00 ...,   5.46849871e+02
#     7.79302643e+02   1.87796213e+03]]
# [[1.6883475249998852 272.497943432283 3.0405244254825883 ...,
#   -422.28288714507573 -12.408420810940372 70.28785938258042]
#  [1.205460743950583 304.9245171048582 0.0 ..., -428.14205532412836
#   33.93199450636708 -98.11773513448796]
#  [1.3071821687145107 427.16594367604444 2.8629793876448626 ...,
#   -0.1475643678803615 33.35036386505495 -197.1857257892006]
#  ...,
#  [24.854343034466776 419.66072175509254 33.93980477161181 ...,
#   -1.7016866070170487 22.459379124613218 -137.7695036187427]
#  [1.1578978163494984 510.3892801038894 3.3037948828594486 ...,
#   -228.9373779181362 105.84219443181476 -49.62501978348821]
#  [1.2444271810997223 287.65814245797765 3.3107964792699254 ...,
#   -466.8109852222258 -7.505652546256057 358.4194709020787]]

# %%
# Try TSNE by itself
import time
from sklearn.manifold import TSNE

# Limit the number of events to process for now
n_sne = 15000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=2, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(DF_dev.loc[:,feat_cols].values[:n_sne])

print 't-SNE done! Time elapsed: %.3f seconds'%(time.time()-time_start)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# [t-SNE] Computed conditional probabilities for sample 5000 / 15000
# [t-SNE] Computed conditional probabilities for sample 6000 / 15000
# [t-SNE] Computed conditional probabilities for sample 7000 / 15000
# [t-SNE] Computed conditional probabilities for sample 8000 / 15000
# [t-SNE] Computed conditional probabilities for sample 9000 / 15000
# [t-SNE] Computed conditional probabilities for sample 10000 / 15000
# [t-SNE] Computed conditional probabilities for sample 11000 / 15000
# [t-SNE] Computed conditional probabilities for sample 12000 / 15000
# [t-SNE] Computed conditional probabilities for sample 13000 / 15000
# [t-SNE] Computed conditional probabilities for sample 14000 / 15000
# [t-SNE] Computed conditional probabilities for sample 15000 / 15000
# [t-SNE] Mean sigma: 26.255373
# [t-SNE] Iteration 25: error = 1.0857316, gradient norm = 0.0001336
# [t-SNE] Iteration 25: gradient norm 0.000134. Finished.
# [t-SNE] Iteration 50: error = 1.0760597, gradient norm = 0.0047960
# [t-SNE] Iteration 75: error = 1.0662972, gradient norm = 0.0033898
# [t-SNE] Iteration 100: error = 1.0639385, gradient norm = 0.0032092
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.063938
# [t-SNE] Iteration 125: error = 1.0448194, gradient norm = 0.0023259
# [t-SNE] Iteration 150: error = 1.0372828, gradient norm = 0.0021321
# [t-SNE] Iteration 175: error = 1.0352522, gradient norm = 0.0020861
# [t-SNE] Iteration 200: error = 1.0346904, gradient norm = 0.0020742
# [t-SNE] Iteration 225: error = 1.0345322, gradient norm = 0.0020712
# [t-SNE] Iteration 250: error = 1.0344858, gradient norm = 0.0020703
# [t-SNE] Iteration 275: error = 1.0344743, gradient norm = 0.0020701
# [t-SNE] Iteration 300: error = 1.0344712, gradient norm = 0.0020700
# [t-SNE] Iteration 300: error difference 0.000000. Finished.
# [t-SNE] Error after 300 iterations: 1.063938
# t-SNE done! Time elapsed: 456.081 seconds

# %%
# Copy TSNE result into new dataframe
df_tsne = DF_dev.iloc[:n_sne,:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

# Plot stuff
d2 = sns.FacetGrid(df_tsne, hue="Truth", size=10)
d2.map(plt.scatter, "x-tsne", "y-tsne").add_legend()
plt.subplots_adjust(top=0.9)
d2.fig.suptitle('C1P6D3', fontsize=10) # can also get the figure from plt.gcf()

# %%
# Try PCA + TSNE 
# pca_50 = PCA(n_components=50)
# pca_result_50 = pca_50.fit_transform(df[feat_cols].values)

# print 'Explained variation per principal component (PCA): %.3f'% (np.sum(pca_50.explained_variance_ratio_))


# # Limit the number of events to process for now
# n_sne = 10000


# time_start = time.time()
# tsne = TSNE(n_components=2, verbose=2, perplexity=40, n_iter=300)
# tsne_results = tsne.fit_transform(DF_dev.loc[:,feat_cols].values[:n_sne])

# print 't-SNE done! Time elapsed: %.3f seconds'%(time.time()-time_start)
