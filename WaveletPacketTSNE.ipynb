# %%
import numpy as np
import pandas as pd
import glob

# Set print options so Pandas shows a lot of stuff!
# pd.options.display.width = 999
# pd.options.display.max_rows = 999
# pd.options.display.max_columns = 999

# visualization
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid') # Style style so background is white

# %%
# Read in files
extDir = '/Users/brianzhu/project/Pandas/skim'
sigFiles = glob.glob('%s/waveSkimDS1_*.h5' % extDir)
dfSigFull = pd.DataFrame()
sigList = []
for file in sigFiles:
    print(file)
    dfDummy = pd.read_hdf(file,'skimTree')
    sigList.append(dfDummy)

dfSigFull = pd.concat(sigList)
dfSigFull.head()
# Out:
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_0.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_1.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_10.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_11.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_12.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_13.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_14.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_15.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_16.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_17.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_18.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_19.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_2.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_20.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_21.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_22.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_23.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_24.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_25.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_26.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_27.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_28.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_29.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_3.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_30.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_31.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_32.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_33.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_34.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_35.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_36.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_37.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_38.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_39.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_4.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_40.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_41.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_42.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_43.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_44.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_45.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_46.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_47.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_48.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_49.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_5.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_50.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_51.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_6.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_7.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_8.h5
# /Users/brianzhu/project/Pandas/skim/waveSkimDS1_9.h5
#      C  channel  mHL     run  trapENFCal  triggerTrapt0     wp0_0     wp0_1  \
# 0  1.0    610.0  1.0  9422.0    1.006189    3871.874616  6.014827  5.986666
# 1  1.0    664.0  1.0  9422.0  144.066708    6188.388670  4.553571  4.366291
# 2  1.0    610.0  1.0  9422.0    1.079852    3245.197293  1.796075  2.271170
# 3  1.0    610.0  1.0  9422.0    1.199417    4078.976218  7.348190  7.338644
# 4  1.0    610.0  1.0  9422.0  808.271610    6280.255255  1.854243  1.822140
#
#      wp0_10      wp0_100    ...       wp9_90    wp9_91    wp9_92    wp9_93  \
# 0  1.511337    11.268748    ...     0.135522  0.047231  1.257602  0.697531
# 1  0.725756  1289.552308    ...     0.030148  2.271374  0.869186  0.151783
# 2  1.938270     9.976411    ...     0.563957  2.360807  1.337860  0.933158
# 3  0.597048    11.559330    ...     0.316667  1.606495  0.509836  2.011213
# 4  0.293603  7257.272053    ...     1.311598  0.283474  0.487350  1.103685
#
#      wp9_94    wp9_95    wp9_96    wp9_97    wp9_98    wp9_99
# 0  0.498072  1.809976  1.679407  1.174133  0.518915  0.551172
# 1  0.352890  0.943624  1.274880  3.413626  0.774629  1.718334
# 2  0.846809  1.152043  1.015324  1.383483  0.280333  0.042538
# 3  0.758463  0.359615  0.568725  1.240840  0.940955  0.458604
# 4  1.686393  0.205909  0.423257  0.161839  2.237174  0.813692
#
# [5 rows x 2054 columns]

# %%
# Clearly some indices are repeated in the data
print dfSigFull.shape
dfSigFull.tail()
# Out:
# (19536, 2054)
#        C  channel  mHL     run  trapENFCal  triggerTrapt0      wp0_0  \
# 343  1.0    692.0  1.0  9952.0  305.634534    6323.798875   0.786975
# 344  1.0    610.0  1.0  9952.0    1.083037    3990.545602   7.139485
# 345  1.0    672.0  1.0  9952.0  391.264030    6305.387876   1.268678
# 346  1.0    664.0  1.0  9952.0  870.129434    6332.147375  11.544233
# 347  1.0    608.0  1.0  9952.0  794.511806    6277.956807   5.950051
#
#          wp0_1    wp0_10      wp0_100    ...       wp9_90    wp9_91    wp9_92  \
# 343   1.470678  0.189929  2817.801280    ...     0.990054  1.192022  0.759605
# 344   6.455099  0.238219     9.586416    ...     1.753004  2.126622  0.126622
# 345   1.097830  5.031427  3559.323980    ...     1.271564  2.093649  0.750821
# 346  10.312822  0.272248  7825.687423    ...     0.951202  0.632006  2.696970
# 347   6.141311  0.277844  7297.552170    ...     0.549604  1.037360  0.689163
#
#        wp9_93    wp9_94    wp9_95    wp9_96    wp9_97    wp9_98    wp9_99
# 343  1.085171  1.227309  1.484731  0.714803  0.345227  0.852589  0.545848
# 344  0.870302  0.576723  0.163857  0.178641  1.065935  0.776633  3.693324
# 345  0.810031  1.532201  0.274724  1.664187  1.516126  0.692623  0.440374
# 346  0.593990  0.556125  0.881705  0.793284  1.047566  0.369110  2.913977
# 347  1.344866  0.087655  2.620247  2.085276  1.076803  2.729978  0.321770
#
# [5 rows x 2054 columns]

# %%
# Make a cut (select only one channel)
dfSig = dfSig.query('channel==626')

# Reset indices
DF_dev = dfSig.reset_index()

print DF_dev.shape[0]
DF_dev.tail()
# Out:
# 715
#      level_0  index    C  channel  mHL     run   trapENFCal  triggerTrapt0  \
# 710    19462    274  1.0    626.0  1.0  9952.0   523.618160    6332.433545
# 711    19479    291  1.0    626.0  1.0  9952.0  1891.787730    6356.938532
# 712    19506    318  1.0    626.0  1.0  9952.0   606.701472    6244.153677
# 713    19516    328  1.0    626.0  1.0  9952.0   802.841433    6234.604885
# 714    19524    336  1.0    626.0  1.0  9952.0   317.166527    6141.923995
#
#         wp0_0     wp0_1    ...       wp9_90    wp9_91    wp9_92    wp9_93  \
# 710  0.272120  0.487820    ...     0.827859  1.457332  1.650280  1.115560
# 711  8.175713  6.981331    ...     0.066857  1.703761  1.167012  1.475175
# 712  1.366025  1.875775    ...     1.124775  0.529622  1.909344  2.299955
# 713  2.964043  2.792819    ...     1.496649  1.314348  1.172922  1.305228
# 714  0.740991  0.453516    ...     1.051542  0.134550  0.003701  0.776743
#
#        wp9_94    wp9_95    wp9_96    wp9_97    wp9_98    wp9_99
# 710  0.088106  0.135727  2.941771  0.554687  0.834475  0.996820
# 711  0.415841  2.403645  1.669426  0.741496  0.864739  0.988952
# 712  0.591471  2.322025  2.429101  2.182397  1.044802  0.541691
# 713  1.500721  0.077098  0.764723  0.840049  2.921884  1.761603
# 714  1.213196  1.430208  0.436343  2.119125  2.488597  0.913952
#
# [5 rows x 2056 columns]

# %%
# Set-up an array for features
feat_cols = ['wp'+str(i)+'_'+str(j) for i in range(0,16) for j in range(0,128)]
print len(feat_cols)
# Out:
# 2048

# %%
rndperm = np.random.permutation(DF_dev.shape[0])
# Plot the graph
fig = plt.figure( figsize=(30,10) )
for i in range(0,30):
    ax = fig.add_subplot(5,6,i+1)
    ax.imshow(DF_dev.loc[i,feat_cols].values.reshape((16,128)).astype(float), interpolation='nearest', aspect='auto', origin='lower', cmap='viridis')
plt.show()

# %%
# Pass data first through PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
pca_result = pca.fit_transform(DF_dev.loc[:,feat_cols].values)

DF_dev.loc[:,'pca-one'] = pd.Series(pca_result[:,0])
DF_dev.loc[:,'pca-two'] = pd.Series(pca_result[:,1])
DF_dev.loc[:,'pca-three'] = pd.Series(pca_result[:,2])
DF_dev.loc[:,'pca-four'] = pd.Series(pca_result[:,3])
DF_dev.loc[:,'pca-five'] = pd.Series(pca_result[:,4])
DF_dev.loc[:,'pca-six'] = pd.Series(pca_result[:,5])
DF_dev.loc[:,'pca-seven'] = pd.Series(pca_result[:,6])
DF_dev.loc[:,'pca-eight'] = pd.Series(pca_result[:,7])
DF_dev.loc[:,'pca-nine'] = pd.Series(pca_result[:,8])
DF_dev.loc[:,'pca-ten'] = pd.Series(pca_result[:,9])

print 'Explained variation per principal component: ',(pca.explained_variance_ratio_)
DF_dev.head()
# Out:
# Explained variation per principal component:  [  9.92146760e-01   6.55363472e-03   9.90020147e-04   2.05307074e-04
#    3.20324175e-05   2.42558817e-05   1.62615546e-05   1.21165430e-05
#    5.70928797e-06   2.91132004e-06]
#    level_0  index    C  channel  mHL     run  trapENFCal  triggerTrapt0  \
# 0       16     16  1.0    626.0  1.0  9422.0   56.492740    6154.351914
# 1       22     22  1.0    626.0  1.0  9422.0  992.519728    6315.190944
# 2       35     35  1.0    626.0  1.0  9422.0   11.906670    5858.682061
# 3       49     49  1.0    626.0  1.0  9422.0  943.772317    6285.193203
# 4       68     68  1.0    626.0  1.0  9422.0    6.954168    5570.463786
#
#       wp0_0     wp0_1    ...           pca-one      pca-two    pca-three  \
# 0  8.016190  8.019675    ...     -25773.842585   592.904731   390.692839
# 1  7.020494  6.363157    ...      42535.931817  5882.789382  1429.095555
# 2  9.210941  9.477076    ...     -29063.176618   244.066780   226.746176
# 3  8.364426  7.594669    ...      38887.527508  3674.511975  -751.078710
# 4  4.533377  4.869589    ...     -29412.143323   211.590513   204.038339
#
#      pca-four    pca-five    pca-six   pca-seven   pca-eight    pca-nine  \
# 0  -80.942960 -224.584870 -58.648929   15.025612  -98.519376   79.074606
# 1 -165.323789  214.131416 -46.810902 -111.611765  428.662877  315.987165
# 2   -2.450792  -40.930453 -12.273069   -0.594250   -8.331192    7.614822
# 3  581.460609  472.836225 -15.075284   45.543104 -411.420123  -32.729510
# 4    7.862263  -15.310150  -3.377599   -6.822283    3.052389   -4.788401
#
#      pca-ten
# 0 -53.243617
# 1 -90.441013
# 2  -6.194404
# 3 -73.339150
# 4  -2.923020
#
# [5 rows x 2066 columns]

# %%
# Draw PCA components (only pca-one vs pca-two for now)
# Organize by channels -- I guess we can organize this by energy, etc to see if there's any separation
d = sns.FacetGrid(DF_dev, size=10)
d.map(plt.scatter, "pca-one", "pca-two").add_legend()

# %%
# Try TSNE by itself
import time
from sklearn.manifold import TSNE

# Limit the number of events to process for now
# n_sne = 10000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=2, perplexity=50, n_iter=500)
# tsne_results = tsne.fit_transform(DF_dev.loc[:,feat_cols].values[:n_sne])
tsne_results = tsne.fit_transform(DF_dev.loc[:,feat_cols].values)

print 't-SNE done! Time elapsed: %.3f seconds'%(time.time()-time_start)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 715 / 715
# [t-SNE] Mean sigma: 30.233247
# [t-SNE] Iteration 25: error = 0.6709021, gradient norm = 0.0132144
# [t-SNE] Iteration 50: error = 0.6057243, gradient norm = 0.0134165
# [t-SNE] Iteration 75: error = 0.4029996, gradient norm = 0.0083105
# [t-SNE] Iteration 100: error = 0.4744249, gradient norm = 0.0091542
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 0.474425
# [t-SNE] Iteration 125: error = 0.4048156, gradient norm = 0.0085800
# [t-SNE] Iteration 150: error = 0.4332401, gradient norm = 0.0086421
# [t-SNE] Iteration 175: error = 0.3954496, gradient norm = 0.0092750
# [t-SNE] Iteration 200: error = 0.4272670, gradient norm = 0.0103587
# [t-SNE] Iteration 225: error = 0.4539510, gradient norm = 0.0097128
# [t-SNE] Iteration 225: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 225 iterations: 0.474425
# t-SNE done! Time elapsed: 4.949 seconds

# %%
# Copy TSNE result into new dataframe
# df_tsne = DF_dev.iloc[:n_sne,:].copy()
df_tsne = DF_dev.copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

# Plot stuff
d2 = sns.FacetGrid(df_tsne, hue='trapENFCal', size=10)
# d2.map(plt.scatter, "x-tsne", "y-tsne")
d2.map(plt.scatter, "x-tsne", "y-tsne").add_legend()
plt.subplots_adjust(top=0.9)
d2.fig.suptitle('C1P6D3 (DS1)', fontsize=20) # can also get the figure from plt.gcf()
# d2.fig.suptitle('DS1 background', fontsize=20) # can also get the figure from plt.gcf()
